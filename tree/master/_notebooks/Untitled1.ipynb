# %% [markdown]
# <a href="https://colab.research.google.com/github/miruetoto/yechan/blob/master/tree/master/_notebooks/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # test

# %%
[1,2,3]+[4]
# Out:
# [1, 2, 3, 4]
