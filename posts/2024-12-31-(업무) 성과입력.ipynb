# %% [raw]
# ---
# title: "(업무) 성과입력"
# author: "신록예찬"
# date: "12/31/2024"
# draft: false
# ---

# %% [markdown]
# ## 접속

# %% [markdown]
# <https://ernd.nrf.re.kr>

# %% [markdown]
# - 로그인: tomato0814

# %% [markdown]
# ## 성과 ernd

# %% [markdown]
# ![](attachment:67e3f254-feac-434b-a24d-f16d7a716b0a.png)

# %% [markdown]
# - 오른쪽 아래 성과

# %% [markdown]
# `-` 오래되어서 아이리스로 가라고함

# %% [markdown]
# ## 아이리스

# %% [markdown]
# `-` 아이리스로 가라고 해서 아이리스로옴 // tomato0814

# %% [markdown]
# `-` 과제조회.. -- 지역우수가 여러개 있느데 이공학술연구기반구축으로.. 찾아야하는듯

# %% [markdown]
# ![](attachment:e5d6620a-6c5b-438c-b9c6-c14648404f43.png)

# %% [markdown]
# `-` 과제가 연구비지급탭에서는 검색되는데 성과입력에서는 검색되지 않음.. 문의가 필요해보임

# %% [markdown]
# :::{.callout-note}
#
# 문의해봤는데, 연구개발과제번호에 번호를 직접입력하고 검색하면 잘 됨.
#
# RS-2023-?? 의 ?? 에 해당하는 연구과제를 입력하면 된다.
# :::
