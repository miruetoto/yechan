# %% [markdown]
# ### S1

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ### S2

# %%
df=pd.DataFrame(np.linspace(0,1,100)**2)

# %%
df.plot.line(backend='plotly')

# %%
#!conda install -c damianavila82 rise -y

# %%
R
