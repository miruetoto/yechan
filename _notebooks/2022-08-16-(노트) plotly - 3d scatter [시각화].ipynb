# %% [markdown]
# # (노트) plotly - 3d scatter
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - categories: [시각화]

# %% [markdown]
# ### ref

# %% [markdown]
# - https://plotly.com/python/

# %% [markdown]
# ### imports

# %%
from IPython.display import HTML
import plotly.express as px
import numpy as np
import pandas as pd

# %%
def show(fig): 
    return HTML(fig.to_html(include_plotlyjs='cdn',include_mathjax=False, config=dict({'scrollZoom':False})))

# %% [markdown]
# ### 기본사용

# %% [markdown]
# `-` 방법1: 벡터에서 바로 플랏

# %%
x=np.linspace(0,1,50)
y=np.sin(10*x)
z=2*x

# %%
fig=px.scatter_3d(x=x,y=y,z=z)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 참고로 아래는 동작하지 않음.
#
# ```python
# x=np.linspace(0,1,50)
# y=np.sin(10*x)
# z=2*x
# fig=px.scatter_3d(x,y,z)
# show(fig)
# ```

# %% [markdown]
# 왜냐하면 첫 args가 df임
#
# ```python
# px.scatter_3d(
#     data_frame=None,
#     x=None,
#     y=None,
#     z=None,
#     color=None,
#     symbol=None,
#     size=None,
#     text=None,
#     ...
#     title=None,
#     template=None,
#     width=None,
#     height=None,
# )
# ```

# %% [markdown]
# `-` 방법2: df이용

# %%
df = pd.DataFrame({'x':x,'y':y,'z':z})
df
# Out:
#            x         y         z
# 0   0.000000  0.000000  0.000000
# 1   0.020408  0.202668  0.040816
# 2   0.040816  0.396924  0.081633
# 3   0.061224  0.574706  0.122449
# 4   0.081633  0.728635  0.163265
# 5   0.102041  0.852322  0.204082
# 6   0.122449  0.940633  0.244898
# 7   0.142857  0.989903  0.285714
# 8   0.163265  0.998087  0.326531
# 9   0.183673  0.964846  0.367347
# 10  0.204082  0.891559  0.408163
# 11  0.224490  0.781268  0.448980
# 12  0.244898  0.638550  0.489796
# 13  0.265306  0.469330  0.530612
# 14  0.285714  0.280629  0.571429
# 15  0.306122  0.080282  0.612245
# 16  0.326531 -0.123398  0.653061
# 17  0.346939 -0.321956  0.693878
# 18  0.367347 -0.507152  0.734694
# 19  0.387755 -0.671298  0.775510
# 20  0.408163 -0.807582  0.816327
# 21  0.428571 -0.910347  0.857143
# 22  0.448980 -0.975328  0.897959
# 23  0.469388 -0.999829  0.938776
# 24  0.489796 -0.982831  0.979592
# 25  0.510204 -0.925041  1.020408
# 26  0.530612 -0.828858  1.061224
# ...

# %%
fig = px.scatter_3d(df,x,y,z)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 여러가지 옵션

# %% [markdown]
# `-` 기본옵션들: color, symbol, size, text

# %%
col = ['A']*20 + ['B']*30 
sym = ['A']*30 + ['B']*20 
size = np.random.rand(50) 
text = ['a']*30 + ['b']*20

# %%
df2=df.assign(col=col,sym=sym,size=size,text=text)
df2
# Out:
#            x         y         z col sym      size text
# 0   0.000000  0.000000  0.000000   A   A  0.131388    a
# 1   0.020408  0.202668  0.040816   A   A  0.682016    a
# 2   0.040816  0.396924  0.081633   A   A  0.520532    a
# 3   0.061224  0.574706  0.122449   A   A  0.816777    a
# 4   0.081633  0.728635  0.163265   A   A  0.568708    a
# 5   0.102041  0.852322  0.204082   A   A  0.010100    a
# 6   0.122449  0.940633  0.244898   A   A  0.241719    a
# 7   0.142857  0.989903  0.285714   A   A  0.754550    a
# 8   0.163265  0.998087  0.326531   A   A  0.632915    a
# 9   0.183673  0.964846  0.367347   A   A  0.913163    a
# 10  0.204082  0.891559  0.408163   A   A  0.980820    a
# 11  0.224490  0.781268  0.448980   A   A  0.260891    a
# 12  0.244898  0.638550  0.489796   A   A  0.808537    a
# 13  0.265306  0.469330  0.530612   A   A  0.620547    a
# 14  0.285714  0.280629  0.571429   A   A  0.550625    a
# 15  0.306122  0.080282  0.612245   A   A  0.296079    a
# ...

# %%
fig = px.scatter_3d(df2,x,y,z,col,sym,size,text)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# `-` 몇개의 문자만 표현하고 싶다면?

# %%
text2 = [None]*30 + ['31'] + [None]*18 + ['50']
df3=df2.assign(text2=text2)

# %%
fig = px.scatter_3d(df2,x,y,z,col,sym,size,text2)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# `-` sizemax의 이용!

# %%
fig = px.scatter_3d(df2,x,y,z,col,sym,size,text2,size_max=10)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_3d(df2,x,y,z,col,sym,size,text2,size_max=50)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# `-` 투명도: 여기에서 투명도는 하나의 값으로만 설정가능하다. array로 줄 수 없다.

# %%
fig = px.scatter_3d(df2,x,y,z,col,sym,size,text2,opacity=0.2)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_3d(df2,x,y,z,col,sym,size,text2,opacity=size)
show(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_21033/4143517603.py in <module>
# ----> 1 fig = px.scatter_3d(df2,x,y,z,col,sym,size,text2,opacity=size)
#       2 show(fig)
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/plotly/express/_chart_types.py in scatter_3d(data_frame, x, y, z, color, symbol, size, text, hover_name, hover_data, custom_data, error_x, error_x_minus, error_y, error_y_minus, error_z, error_z_minus, animation_frame, animation_group, category_orders, labels, size_max, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, log_x, log_y, log_z, range_x, range_y, range_z, title, template, width, height)
#     774     symbol mark in 3D space.
#     775     """
# --> 776     return make_figure(args=locals(), constructor=go.Scatter3d)
#     777
# ...

# %% [markdown]
# ### 연산가능

# %%
fig = px.scatter_3d(df2,x,y,np.tan(z),col,sym,size,text2)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_3d(df2,x,y,z,col,sym,size,text2)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_3d(df2,x,y,z,col,sym,size**5,text2)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 기타조정

# %% [markdown]
# https://plotly.com/python/reference/scatter3d/
