# %% [markdown]
# # 파이썬입문 기말고사 (draft)
# > 작성완료
#
# - toc:false
# - branch: master
# - badges: false
# - comments: false
# - author: 최규빈
# - categories: [파이썬입문]

# %% [markdown]
# ### \# 1.
# A사에서 게임유저들에게 여름방학 기념으로 아이템을 선물했다고 하자. 이 아이템은 총 5회에 걸쳐서 강화(upgrade)될 수 있는데 강화의 성공확률은 30%라고 하자. 강화가 5번성공하면 더 이상 강화가 진행되지 않는다고 하자. 아래는 강화를 진행하였을때 각 강화상태를 설명한 예시이다.
#
# |시도횟수|강화성공여부|강화상태|비고|
# |:-:|:-:|:-:|:-|
# |1|강화실패|+0 $\to$ +0|강화실패로 인하여 강화상태 변화없음 |
# |2|강화성공|+0 $\to$ +1|강화성공으로 인한 강화상태 변화|
# |3|강화실패|+1 $\to$ +1|강화실패로 인하여 강화상태 변화없음 |
# |4|강화성공|+1 $\to$ +2|강화성공으로 인한 강화상태 변화|
# |5|강화성공|+2 $\to$ +3|강화성공으로 인한 강화상태 변화|
# |6|강화성공|+3 $\to$ +4|강화성공으로 인한 강화상태 변화|
# |7|강화실패|+4 $\to$ +4|강화실패로 인하여 강화상태 변화없음 |
# |8|강화성공|+4 $\to$ +5|모든 강화 성공|
# |9|-|+5 $\to$ +5|더 이상 강화시도 하지 않음|
# |10|$\dots$|$\dots$|$\dots$|
#
#
# 강화는 하루에 한 번씩만 시도할 수 있으며 시도가능한 기간은 7월1일부터 8월31일까지로 한정되어 있다고 하자. 따라서 방학동안 유저들은 총 62번 시도를 할 수 있다. 방학이 끝난이후 100명 유저중 대략 몇명정도 강화에 성공하겠는가? 파이썬을 통한 시뮬레이션을 활용하여 추론하라. (단 모든 유저가 62번의 강화시도를 하였다고 가정하자)

# %% [markdown]
# ### \# 2.
#
# 강화성공확률을 70%로 수정하고 강화에 누적 2회 실패하면 강화상태가 초기화 된다고 하자. 단, 강화성공여부가 +0인 경우는 실패하여도 누적횟수가 추가되지 않는다.
#
# |시도횟수|강화성공여부|강화상태|강화실패누적|비고|
# |:-:|:-:|:-:|:-:|:-|
# |1|강화성공|+0 $\to$ +1| 0 $\to$ 0|- |
# |2|강화성공|+1 $\to$ +2|0 $\to$ 0 |-|
# |3|강화실패|+2 $\to$ +2 |0 $\to$ 1|-|
# |4|강화성공|+2 $\to$ +3 |1 $\to$ 1|-|
# |5|강화실패|+3 $\to$ +0 |1 $\to$ 0| 강화실패로 인한 초기화|
# |6|강화실패|+0 $\to$ +0|0 $\to$ 0| 강화실패하였으나 현재강화상태가 +0 이므로 강화실패 누적횟수는 증가하지 않음|
# |7|강화성공|+0 $\to$ +1 |0 $\to$ 0|-|
# |8|강화성공|+1 $\to$ +2|0 $\to$ 0|-|
# |9|강화성공|+2 $\to$ +3|0 $\to$ 0|-|
# |10|강화성공|+3 $\to$ +4|0 $\to$ 0|-|
# |11|강화성공|+4 $\to$ +5|0 $\to$ 0|모든 강화 성공|
# |12|-|+5 $\to$ +5|0 $\to$ 0|더 이상 강화시도 하지 않음|
# |13|$\dots$|$\dots$|$\dots$|$\dots$|

# %% [markdown]
# `(1)` 이 경우 62일의 방학뒤에 100명의 유저중 대략 몇명정도 강화에 성공하겠는가? 파이썬을 통한 시뮬레이션을 활용하여 추론하라. (단 모든 유저가 62번의 강화시도를 하였다고 가정하자)

# %% [markdown]
# `(2)` 31번째 시도이후 몇명의 유저가 강화에 성공하였는가?

# %% [markdown]
# ### \# 3.
#
# 50%이상의 유저가 +5강화에 성공하였다면
#
# |시도횟수|강화성공여부|강화상태|강화실패누적|비고|
# |:-:|:-:|:-:|:-:|:-|
# |1|강화성공|+0 $\to$ +1| 0 $\to$ 0|- |
# |2|강화성공|+1 $\to$ +2|0 $\to$ 0 |-|
# |3|강화실패|+2 $\to$ +2 |0 $\to$ 1|-|
# |4|강화성공|+2 $\to$ +3 |1 $\to$ 1|-|
# |5|강화실패|+3 $\to$ +0 |1 $\to$ 0| 강화실패로 인한 초기화|
# |6|강화실패|+0 $\to$ +0|0 $\to$ 0| 강화실패하였으나 현재강화상태가 +0 이므로 강화실패 누적횟수는 증가하지 않음|
# |7|강화성공|+0 $\to$ +1 |0 $\to$ 0|-|
# |8|강화성공|+1 $\to$ +2|0 $\to$ 0|-|
# |9|강화성공|+2 $\to$ +3|0 $\to$ 0|-|
# |10|강화성공|+3 $\to$ +4|0 $\to$ 0|-|
# |11|강화성공|+4 $\to$ +5|0 $\to$ 0|모든 강화 성공|

# %% [markdown]
# ### Hint

# %% [markdown]
# 필요하다면 아래의 코드를 활용하라.

# %% [markdown]
# p의 확률로 0 혹은 1을 뽑는 함수

# %% [markdown]
# ```python
# import numpy as np
# np.random.binomial(n=1, p=0.3) # 0.3 의 확률로 0 혹은 1을 추출
# np.random.binomial(n=1, p=0.7) # 0.7 의 확률로 0 혹은 1을 추출
# np.random.binomial(n=1, p=0.9) # 0.9 의 확률로 0 혹은 1을 추출
# ```
