# %% [markdown]
# # (노트) plotly 설치
# > 작성완료
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - categories: [주피터]

# %% [markdown]
# ### plotly 설치 (conda 이용 X)
#
# `-` `plotly`를 설치하기 위해서는 아래를 순서대로 설치해야 한다.
# ```
# (py38r40) pip install plotly==4.8.0
# (py38r40) pip install dash==1.13.3
# (py38r40) pip install jupyter-dash
# (py38r40) conda install nodejs
# (py38r40) jupyter lab build
# (py38r40) pip install jupyterlab "ipywidgets>=7.5"
# (py38r40) jupyter labextension install jupyterlab-plotly@4.8.2
# ```

# %% [markdown]
# ### plotly 설치 (conda)

# %% [markdown]
# ```
# (py38r40) conda install -c conda-forge plotly
# ```

# %%
import plotly

# %%
import plotly.express as px
fig = px.scatter(x=[0, 1, 2, 3, 4], y=[0, 1, 4, 9, 16])

# %%
fig

# %% [markdown]
# ???
