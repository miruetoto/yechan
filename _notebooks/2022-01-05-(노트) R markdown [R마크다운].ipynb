# %% [markdown]
# # (노트) R markdown
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - categories: [R마크다운]

# %% [markdown]
# ### 셋팅

# %% [markdown]
# ```
# ---
# title: "Rmarkdown을 이용한 기술문서작성"
# author: "최규빈"
# date: "12/14/2021"
# institute: 전북대학교 통계학과
# fontsize: 10pt # 10, 11, 12
# output:
#   #pdf_document:
#   beamer_presentation:
#     theme: CambridgeUS
#     includes:
#       in_header: header.tex
# ---
#
# ```

# %% [markdown]
# ### 코드

# %% [markdown]
# `-` 결과없이 코드만 보여주고 싶다면? ` ```{r, eval=FALSE}`
#
# ```{r, eval=FALSE}
# x=1:1000
# x
# ```
#
# `-` 코드없이 결과만 보여주고 싶다면? ` ```{r, echo=FALSE}`
#
# ```{r, echo=FALSE}
# x=1:1000/100
# y1=sin(x)
# y2=sin(2*x)
# plot(x,y1,type='l',col='red')
# lines(x,y2,col='blue',lty=2)
# ```
#
# `-` 그림의 크기를 조정하고 싶을 경우 ` ```{r, echo=FALSE, fig.width=5,fig.height=3}`
#
# ```{r, echo=FALSE, fig.width=5,fig.height=3}
# x=1:1000/100
# y1=sin(x)
# y2=sin(2*x)
# plot(x,y1,type='l',col='red')
# lines(x,y2,col='blue',lty=2)
# ```
