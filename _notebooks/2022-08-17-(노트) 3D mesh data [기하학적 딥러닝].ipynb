# %% [markdown]
# # (노트) 3D mesh data
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - categories: [기하학적 딥러닝]

# %% [markdown]
# ### ref

# %% [markdown]
# https://github.com/plotly/datasets/tree/master/ply

# %% [markdown]
# ### imports

# %%
import pandas as pd
import plotly.graph_objects as go
from IPython.display import HTML

# %%
def show(fig): 
    return HTML(fig.to_html(include_plotlyjs='cdn',include_mathjax=False, config=dict({'scrollZoom':False})))

# %% [markdown]
# ### sandal

# %%
base_url = "https://raw.githubusercontent.com/plotly/datasets/master/ply/"
df1 = pd.read_csv(base_url + 'sandal-ply.csv') 
df1.head(10)
# Out:
#          x        y         z        facecolor   i   j   k
# 0 -2.42561 -1.47236  0.132523  rgb(31,151,139)   0   1   2
# 1 -2.08997 -1.88351  0.097943  rgb(31,151,139)   2   3   0
# 2 -2.23897 -1.89583  0.088308  rgb(31,150,139)   0   3   4
# 3 -2.44966 -1.87043  0.076921  rgb(31,150,139)   4   5   0
# 4 -2.66959 -1.81592  0.066715  rgb(31,150,139)   0   5   6
# 5 -2.78814 -1.74609  0.064723  rgb(31,150,139)   6   7   0
# 6 -2.87093 -1.66050  0.068444  rgb(31,151,139)   0   7   8
# 7 -2.92860 -1.56412  0.078269  rgb(31,152,139)   0   9   1
# 8 -2.95846 -1.41873  0.104414  rgb(31,152,139)  10   9   0
# 9 -2.00182 -1.83191  0.107028  rgb(31,153,138)   0  11  10

# %%
fig1 = go.Figure()
fig1.add_trace(go.Mesh3d(
        x=df1['x'], y=df1['y'], z=df1['z'], 
        i=df1['i'], j=df1['j'], k=df1['k'], 
        facecolor=df1['facecolor'] 
))
show(fig1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### scissors

# %%
df2 = pd.read_csv(base_url + 'scissors-ply.csv') 
fig2 = go.Figure()
fig2.add_trace(go.Mesh3d(
        x=df2['x'], y=df2['y'], z=df2['z'], 
        i=df2['i'], j=df2['j'], k=df2['k'], 
        facecolor=df2['facecolor'] 
))
show(fig2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### shark

# %%
df3 = pd.read_csv(base_url + 'shark-ply.csv') 
fig3 = go.Figure()
fig3.add_trace(go.Mesh3d(
        x=df3['x'], y=df3['y'], z=df3['z'], 
        i=df3['i'], j=df3['j'], k=df3['k'], 
        facecolor=df3['facecolor'] 
))
show(fig3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### sphere

# %%
df4 = pd.read_csv(base_url + 'sphere-ply.csv') 
fig4 = go.Figure()
fig4.add_trace(go.Mesh3d(
        x=df4['x'], y=df4['y'], z=df4['z'], 
        i=df4['i'], j=df4['j'], k=df4['k'], 
        facecolor=df4['facecolor'] 
))
show(fig4)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### steeringweel

# %%
df5 = pd.read_csv(base_url + 'steeringweel-ply.csv') 
fig5 = go.Figure()
fig5.add_trace(go.Mesh3d(
        x=df5['x'], y=df5['y'], z=df5['z'], 
        i=df5['i'], j=df5['j'], k=df5['k'], 
        facecolor=df5['facecolor'] 
))
show(fig5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### teapot

# %%
df6 = pd.read_csv(base_url + 'teapot-ply.csv') 
fig6 = go.Figure()
fig6.add_trace(go.Mesh3d(
        x=df6['x'], y=df6['y'], z=df6['z'], 
        i=df6['i'], j=df6['j'], k=df6['k'], 
        facecolor=df6['facecolor'] 
))
show(fig6)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### walkman

# %%
df7 = pd.read_csv(base_url + 'walkman-ply.csv') 
fig7 = go.Figure()
fig7.add_trace(go.Mesh3d(
        x=df7['x'], y=df7['y'], z=df7['z'], 
        i=df7['i'], j=df7['j'], k=df7['k'], 
        facecolor=df7['facecolor'] 
))
show(fig7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
