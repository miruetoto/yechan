# %% [markdown]
# # (노트) Folium
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - hide: false
# - categories: [시각화]

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
from IPython.display import HTML
import folium

# %% [markdown]
# ### folium.Map

# %%
#!conda install -c conda-forge folium -y 
m = folium.Map(zoom_start=10,scrollWheelZoom=False)
#HTML(m.get_root().render())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e5c91e2c3f8a4d20a1a277e5c8ece50b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e5c91e2c3f8a4d20a1a277e5c8ece50b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e5c91e2c3f8a4d20a1a277e5c8ece50b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e5c91e2c3f8a4d20a1a277e5c8ece50b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# - world_map는 map object

# %% [markdown]
# `-` location 지정

# %%
# create a Stamen Toner map of the world centered around North America
m = folium.Map(location=[35.836603154469884, 127.11406532500682],
               zoom_start=15,scrollWheelZoom=False)
m
# display map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_68bb9fe966e7490b8c3951419c136a63%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_68bb9fe966e7490b8c3951419c136a63%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_68bb9fe966e7490b8c3951419c136a63%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_68bb9fe966e7490b8c3951419c136a63%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.836603154469884%2C%20127.11406532500682%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# `-` `tiles` 옵션
# - "OpenStreetMap"
# - "Stamen Terrain", "Stamen Toner", "Stamen Watercolor"
# - "CartoDB positron", "CartoDB dark_matter"

# %%
m = folium.Map(location=[35.836603154469884, 127.11406532500682], 
               tiles='CartoDB positron', 
               zoom_start=15 ,
               scrollWheelZoom=False)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ce5bbd74c7364813938b060892510204%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ce5bbd74c7364813938b060892510204%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ce5bbd74c7364813938b060892510204%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ce5bbd74c7364813938b060892510204%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.836603154469884%2C%20127.11406532500682%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### folium.Marker

# %%
# from folium import FeatureGroup, LayerControl, Map, Marker
# Start by creating a Feature Group Map Base
m = folium.Map(
    location=[35.836603154469884, 127.11406532500682],
    zoom_start=14,
    scrollWheelZoom=False,
    tiles='CartoDB positron'
)
folium.Marker(
    location=[35.836603154469884, 127.11406532500682],
    popup='Home').add_to(m)

m

folium.Marker(
    location=[35.84694109945701, 127.12941011336521],
    icon=folium.Icon(color='red', # 배경색
                     icon_color='black', # 아이콘색 
                     icon='fa-university', 
                     angle=0,
                     prefix='fa'), # 이걸 써야지 아이콘이 보인다. 
    popup='JBNU').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a627e50c599e4048a61145072b64eafe%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a627e50c599e4048a61145072b64eafe%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a627e50c599e4048a61145072b64eafe%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a627e50c599e4048a61145072b64eafe%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.836603154469884%2C%20127.11406532500682%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# `-` 조금 더 다양한 아이콘들을 추가하여 보자.

# %%
m = folium.Map(
    location=[35.836603154469884, 127.11406532500682],
    zoom_start=14,
    scrollWheelZoom=False,
    tiles='CartoDB positron'
)
folium.Marker(
    location=[35.836603154469884, 127.11406532500682],
    popup='Home').add_to(m)
folium.Marker(
    location=[35.84694109945701, 127.12941011336521],
    icon=folium.Icon(color='red', # 배경색
                     icon_color='white', # 아이콘색 
                     icon='flag', 
                     angle=0,
                     prefix='fa'), # 이걸 써야지 아이콘이 보인다. 
    popup='JBNU').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_16ae8666500d451ebc3e2cf2398969e5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_16ae8666500d451ebc3e2cf2398969e5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_16ae8666500d451ebc3e2cf2398969e5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_16ae8666500d451ebc3e2cf2398969e5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.836603154469884%2C%20127.11406532500682%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# `-` `icon = 'university'` 대신에 쓸만한 옵션들

# %% [markdown]
# - icon='street-view'
# - icon='tree'
# - icon='plane'
# - icon='bell'
# - ...
#
# **https://getbootstrap.com/docs/3.3/components/**

# %% [markdown]
# `-` Circle Maker

# %% [markdown]
# `-` DataFrame 넣기

# %%
df=pd.DataFrame(data=[[2019,35],[2020,35],[2021,30]],columns=['Year','Enrollment'])
df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Year</th>\n      <th>Enrollment</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>2019</td>\n      <td>35</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>2020</td>\n      <td>35</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2021</td>\n      <td>30</td>\n    </tr>\n  </tbody>\n</table>'

# %%
m = folium.Map(
    location=[35.836603154469884, 127.11406532500682],
    zoom_start=14,
    scrollWheelZoom=False,
    tiles='CartoDB positron'
)
folium.Marker(
    location=[35.836603154469884, 127.11406532500682],
    popup='Home').add_to(m)
folium.Marker(
    location=[35.84694109945701, 127.12941011336521],
    icon=folium.Icon(color='red', # 배경색
                     icon_color='white', # 아이콘색 
                     icon='flag', 
                     angle=0,
                     prefix='fa'), # 이걸 써야지 아이콘이 보인다. 
    popup="<h2> JBNU </h2><br>"+df.to_html()).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1bb7dc3742ce4a11b99a5f7d74282b5e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1bb7dc3742ce4a11b99a5f7d74282b5e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1bb7dc3742ce4a11b99a5f7d74282b5e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1bb7dc3742ce4a11b99a5f7d74282b5e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.836603154469884%2C%20127.11406532500682%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# `-` 논리구조상 HTML오브젝트를 아무거나 넣을 수 있다.

# %%
import base64
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
plt.plot([1,2,3],[2,3,4])
fig.savefig('temp.png')

# %%
_encoded = base64.b64encode(open('temp.png', 'rb').read())
_myhtml = '<img src="data:image/png;base64,{}">'.format
_iframe = folium.IFrame(_myhtml(_encoded.decode('UTF-8')), width=400, height=300)
_popup = folium.Popup(_iframe, max_width=2650)

# %%
m = folium.Map(
    location=[35.836603154469884, 127.11406532500682],
    zoom_start=14,
    scrollWheelZoom=False,
    tiles='CartoDB positron'
)
folium.Marker(
    location=[35.836603154469884, 127.11406532500682],
    popup='Home').add_to(m)
folium.Marker(
    location=[35.84694109945701, 127.12941011336521],
    icon=folium.Icon(color='red', # 배경색
                     icon_color='white', # 아이콘색 
                     icon='flag', 
                     angle=0,
                     prefix='fa'), # 이걸 써야지 아이콘이 보인다. 
    popup=_popup).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3bc541af8b4045b084a2f243cb3db767%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3bc541af8b4045b084a2f243cb3db767%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3bc541af8b4045b084a2f243cb3db767%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3bc541af8b4045b084a2f243cb3db767%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.836603154469884%2C%20127.11406532500682%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### folium.CircleMarker

# %%
m = folium.Map(
    location=[35.836603154469884, 127.11406532500682],
    zoom_start=14,
    scrollWheelZoom=False,
    tiles='CartoDB positron'
)
folium.CircleMarker(
    [35.84694109945701, 127.12941011336521],
    popup='JNBU',
    radius=40,
    color=None,
    fill=True,
    fill_color='red',
    
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_cd6d61f8a2bd47b68691f088c794874d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cd6d61f8a2bd47b68691f088c794874d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_cd6d61f8a2bd47b68691f088c794874d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_cd6d61f8a2bd47b68691f088c794874d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.836603154469884%2C%20127.11406532500682%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# `-` 그냥 지옴처럼 생각해도 괜찮아보임

# %% [markdown]
# ### folium.LineMarker

# %% [markdown]
# ### folium.plugins.MeasureControl()

# %%
from folium.plugins import MeasureControl
m = folium.Map([35.84694109945701, 127.12941011336521],
               zoom_start=17,
               scrollWheelZoom=False)
m.add_child(folium.plugins.MeasureControl())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3f66600e4dd442c981627d3c218ddfb6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/ljagis/leaflet-measure%402.1.7/dist/leaflet-measure.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/ljagis/leaflet-measure%402.1.7/dist/leaflet-measure.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3f66600e4dd442c981627d3c218ddfb6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3f66600e4dd442c981627d3c218ddfb6%20%3D%20L.map%28%0A%20%20%20%2 ...

# %% [markdown]
# ### folium.plugins.TimestampedGeoJson

# %%
m = folium.Map([35.84694109945701, 127.12941011336521],
               zoom_start=17,
               scrollWheelZoom=False)
a1=[35.847336682624395, 127.13066143667929]
a2=[35.847163718642705, 127.12985784659246]
a3=[35.8466227437543, 127.13004852898592]
a4=[35.845842555784095, 127.13032547246222]
a5=[35.84567326870173, 127.13185547166708]
a1.reverse()
a2.reverse()
a3.reverse()
a4.reverse()
a5.reverse()
t1='2021-11-21 12:00:00'
t2='2021-11-21 12:05:00'
t3='2021-11-21 12:10:00'
t4='2021-11-21 12:15:00'
t5='2021-11-21 12:20:00'
points=[{'coordinates':a1, 'time': t1},
       {'coordinates':a2, 'time': t2},
       {'coordinates':a3, 'time': t3},
       {'coordinates':a4, 'time': t4},
       {'coordinates':a4, 'time': t5}]
           
features=[{'type':'Feature',
           'geometry':{
               'type':'Point',
               'coordinates':point['coordinates'],
               },
           'properties':{
               'times':point['time'],
               'iconstyle':{
                   'iconSize':[20,20]}
               }
          } for point in points
         ]

features.append(
    {
        'type': 'Feature',
        'geometry': {
            'type': 'LineString',
            'coordinates': [a1,a2,a3,a4,a5],
        },
        'properties': {
            'times': [t1,t2,t3,t4,t5],
            'icon': 'circle',
            'iconstyle': {
                'fillColor': 'green',
                'fillOpacity': 0.6,
                'stroke': 'false',
                'radius': 13
            },
            'style': {'weight': 0},
            'id': 'man'
        }
    }
)

folium.plugins.TimestampedGeoJson({
    'type':'FeatureCollection',
    'features':features,
}, period='PT30S', add_last_point=True).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3430602701654ca3b905b8d9751d56b3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/jquery/2.0.0/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/iso8601-js-period%400.2.1/iso8601.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-timedimension%401.1.1/dist/leaflet.timedimension.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22s ...

# %%
from folium.plugins import MeasureControl
m = folium.Map([35.84694109945701, 127.12941011336521],
               zoom_start=17,
               scrollWheelZoom=False)
m.add_child(MeasureControl())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2328f29685884261854730197e1a705d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/ljagis/leaflet-measure%402.1.7/dist/leaflet-measure.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/ljagis/leaflet-measure%402.1.7/dist/leaflet-measure.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2328f29685884261854730197e1a705d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2328f29685884261854730197e1a705d%20%3D%20L.map%28%0A%20%20%20%2 ...

# %%
m = folium.Map([35.84694109945701, 127.12941011336521],
               zoom_start=17,
               scrollWheelZoom=False)
a1=[35.847336682624395, 127.13066143667929]
a2=[35.847163718642705, 127.12985784659246]
a3=[35.8466227437543, 127.13004852898592]
a4=[35.845842555784095, 127.13032547246222]
a5=[35.84567326870173, 127.13185547166708]
a1.reverse()
a2.reverse()
a3.reverse()
a4.reverse()
a5.reverse()
t1='2021-11-21 12:00:00'
t2='2021-11-21 12:05:00'
t3='2021-11-21 12:10:00'
t4='2021-11-21 12:15:00'
t5='2021-11-21 12:20:00'
lines=[{'coordinates':[a1,a2], 'dates': [t1,t2],'color':'red','weight':10},
       {'coordinates':[a2,a3], 'dates': [t2,t3],'color':'red','weight':9},
       {'coordinates':[a3,a4], 'dates': [t3,t4],'color':'red','weight':8},
       {'coordinates':[a4,a5], 'dates': [t4,t5],'color':'red','weight':7}]
           
features=[{'type':'Feature',
           'geometry':{'type':'LineString',
                       'coordinates':line['coordinates'],
                      },
           'properties':{'times':line['dates'],
                         'style':{
                             'color':line['color'],
                             'weight':line['weight']
                         }
                        }
          } for line in lines]

folium.plugins.TimestampedGeoJson({
    'type':'FeatureCollection',
    'features':features,
}, period='PT30S', add_last_point=True).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a178783374334b448bd6372b38c57ea6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/jquery/2.0.0/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/iso8601-js-period%400.2.1/iso8601.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-timedimension%401.1.1/dist/leaflet.timedimension.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22s ...

# %% [markdown]
# ### 기후자료

# %% [markdown]
# #### Step1: Pandas

# %%
fnames=['202101.csv','202102.csv','202103.csv','202104.csv','202105.csv','202106.csv','202107.csv','202108.csv','202109.csv','202110.csv']
dfs=[pd.read_csv('https://raw.githubusercontent.com/guebin/2021DV/master/_notebooks/'+fnames[i]) for i in range(len(fnames))]

# %%
ks=['2021-'+str(i) for i in range(1,11)] 
ks
# Out:
# ['2021-1',
#  '2021-2',
#  '2021-3',
#  '2021-4',
#  '2021-5',
#  '2021-6',
#  '2021-7',
#  '2021-8',
#  '2021-9',
#  '2021-10']

# %%
df=pd.concat(dfs,keys=ks).reset_index().rename(columns={'level_0':'month','level_1':'dindex'}).dropna()
df
# Out:
#        month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
# 0     2021-1       0   속초(90)  128.56473  38.25085      -1.2      -5.5
# 1     2021-1       1  북춘천(93)  127.75443  37.94738      -5.7     -11.8
# 2     2021-1       2   철원(95)  127.30420  38.14787      -5.9     -12.6
# 3     2021-1       3  동두천(98)  127.06070  37.90188      -4.2      -9.9
# 4     2021-1       4   파주(99)  126.76648  37.88589      -5.1     -11.4
# ..       ...     ...      ...        ...       ...       ...       ...
# 945  2021-10      90  합천(285)  128.16994  35.56505      15.4      10.3
# 946  2021-10      91  밀양(288)  128.74412  35.49147      16.5      11.2
# 947  2021-10      92  산청(289)  127.87910  35.41300      14.9       9.4
# 948  2021-10      93  거제(294)  128.60459  34.88818      17.4      13.5
# 949  2021-10      94  남해(295)  127.92641  34.81662      17.2      13.5
#
#      최고기온(°C)
# 0         2.9
# 1         0.7
# 2         0.7
# 3         2.1
# 4         1.5
# ..        ...
# 945      22.6
# 946      23.4
# 947      22.3
# 948      22.4
# 949      22.3
#
# [949 rows x 8 columns]

# %%
df.assign(color=list(map(lambda x: 'red' if x > 0 else 'blue',df.iloc[:,5])))
# Out:
#        month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
# 0     2021-1       0   속초(90)  128.56473  38.25085      -1.2      -5.5
# 1     2021-1       1  북춘천(93)  127.75443  37.94738      -5.7     -11.8
# 2     2021-1       2   철원(95)  127.30420  38.14787      -5.9     -12.6
# 3     2021-1       3  동두천(98)  127.06070  37.90188      -4.2      -9.9
# 4     2021-1       4   파주(99)  126.76648  37.88589      -5.1     -11.4
# ..       ...     ...      ...        ...       ...       ...       ...
# 945  2021-10      90  합천(285)  128.16994  35.56505      15.4      10.3
# 946  2021-10      91  밀양(288)  128.74412  35.49147      16.5      11.2
# 947  2021-10      92  산청(289)  127.87910  35.41300      14.9       9.4
# 948  2021-10      93  거제(294)  128.60459  34.88818      17.4      13.5
# 949  2021-10      94  남해(295)  127.92641  34.81662      17.2      13.5
#
#      최고기온(°C) color
# 0         2.9  blue
# 1         0.7  blue
# 2         0.7  blue
# 3         2.1  blue
# 4         1.5  blue
# ..        ...   ...
# 945      22.6   red
# 946      23.4   red
# 947      22.3   red
# 948      22.4   red
# 949      22.3   red
#
# [949 rows x 9 columns]

# %%
df.\
assign(color=list(map(lambda x: 'red' if x > 0 else 'blue',df.iloc[:,5]))).\
groupby('month').\
pipe(list)
# Out:
# [('2021-1',
#        month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
#   0   2021-1       0   속초(90)  128.56473  38.25085      -1.2      -5.5
#   1   2021-1       1  북춘천(93)  127.75443  37.94738      -5.7     -11.8
#   2   2021-1       2   철원(95)  127.30420  38.14787      -5.9     -12.6
#   3   2021-1       3  동두천(98)  127.06070  37.90188      -4.2      -9.9
#   4   2021-1       4   파주(99)  126.76648  37.88589      -5.1     -11.4
#   ..     ...     ...      ...        ...       ...       ...       ...
#   90  2021-1      90  합천(285)  128.16994  35.56505       0.1      -5.8
#   91  2021-1      91  밀양(288)  128.74412  35.49147       0.4      -5.3
#   92  2021-1      92  산청(289)  127.87910  35.41300      -0.2      -5.5
#   93  2021-1      93  거제(294)  128.60459  34.88818       2.9      -1.3
#   94  2021-1      94  남해(295)  127.92641  34.81662       2.3      -2.2
#
#       최고기온(°C) color
#   0        2.9  blue
#   1        0.7  blue
#   2        0.7  blue
#   3        2.1  blue
#   4        1.5  blue
#   ..       ...   ...
#   90       7.1   red
#   91       7.0   red
#   92       6.1  blue
#   93       7.2   red
#   94       7.1   red
#
#   [95 rows x 9 columns]),
#  ('2021-10',
#          month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
#   855  2021-10       0   속초(90)  128.56473  38.25085      15.5      11.6
#   856  2021-10       1  북춘천(93)  127.75443  37.94738      13.1       7.9
#   857  2021-10       2   철원(95)  127.30420  38.14787      12.7       7.3
#   858  2021-10       3  동두천(98)  127.06070  37.90188      13.7       8.5
#   859  2021-10       4   파주(99)  126.76648  37.88589      13.0       7.6
#   ..       ...     ...      ...        ...       ...       ...       ...
#   945  2021-10      90  합천(285)  128.16994  35.56505      15.4      10.3
#   946  2021-10      91  밀양(288)  128.74412  35.49147      16.5      11.2
#   947  2021-10      92  산청(289)  127.87910  35.41300      14.9       9.4
#   948  2021-10      93  거제(294)  128.60459  34.88818      17.4      13.5
#   949  2021-10      94  남해(295)  127.92641  34.81662      17.2      13.5
#
#        최고기온(°C) color
#   855      20.0   red
#   856      19.6   red
#   857      19.2   red
#   858      19.9   red
#   859      19.8   red
#   ..        ...   ...
#   945      22.6   red
#   946      23.4   red
#   947      22.3   red
#   948      22.4   red
#   949      22.3   red
#
#   [95 rows x 9 columns]),
#  ('2021-2',
#         month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
#   95   2021-2       0   속초(90)  128.56473  38.25085       3.1      -1.5
#   96   2021-2       1  북춘천(93)  127.75443  37.94738       0.4      -6.3
#   97   2021-2       2   철원(95)  127.30420  38.14787       0.1      -6.7
#   98   2021-2       3  동두천(98)  127.06070  37.90188       1.3      -5.0
#   99   2021-2       4   파주(99)  126.76648  37.88589       0.5      -6.1
#   ..      ...     ...      ...        ...       ...       ...       ...
#   185  2021-2      90  합천(285)  128.16994  35.56505       4.3      -2.4
#   186  2021-2      91  밀양(288)  128.74412  35.49147       4.3      -2.4
#   187  2021-2      92  산청(289)  127.87910  35.41300       3.7      -2.3
#   188  2021-2      93  거제(294)  128.60459  34.88818       6.6       2.2
#   189  2021-2      94  남해(295)  127.92641  34.81662       6.1       1.1
#
#        최고기온(°C) color
#   95        7.7   red
#   96        7.6   red
#   97        6.8   red
#   98        8.4   red
#   99        7.2   red
#   ..        ...   ...
#   185      12.1   red
#   186      11.7   red
#   187      11.0   red
#   188      11.3   red
#   189      11.3   red
#
#   [95 rows x 9 columns]),
#  ('2021-3',
#         month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
#   190  2021-3       0   속초(90)  128.56473  38.25085       8.0       3.7
#   191  2021-3       1  북춘천(93)  127.75443  37.94738       7.1       0.5
#   192  2021-3       2   철원(95)  127.30420  38.14787       6.2      -0.3
#   193  2021-3       3  동두천(98)  127.06070  37.90188       7.7       1.6
#   194  2021-3       4   파주(99)  126.76648  37.88589       6.7       0.4
#   ..      ...     ...      ...        ...       ...       ...       ...
#   280  2021-3      90  합천(285)  128.16994  35.56505       9.7       3.4
#   281  2021-3      91  밀양(288)  128.74412  35.49147      10.1       3.9
#   282  2021-3      92  산청(289)  127.87910  35.41300       9.5       3.1
#   283  2021-3      93  거제(294)  128.60459  34.88818      10.8       6.4
#   284  2021-3      94  남해(295)  127.92641  34.81662      10.6       6.0
#
#        최고기온(°C) color
#   190      12.6   red
#   191      14.3   red
#   192      13.4   red
#   193      15.5   red
#   194      14.0   red
#   ..        ...   ...
#   280      16.4   red
#   281      16.9   red
#   282      16.2   red
#   283      15.6   red
#   284      15.8   red
#
#   [95 rows x 9 columns]),
#  ('2021-4',
#         month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
#   285  2021-4       0   속초(90)  128.56473  38.25085      12.3       7.8
#   286  2021-4       1  북춘천(93)  127.75443  37.94738      12.4       5.5
#   287  2021-4       2   철원(95)  127.30420  38.14787      12.0       5.2
#   288  2021-4       3  동두천(98)  127.06070  37.90188      13.0       6.7
#   289  2021-4       4   파주(99)  126.76648  37.88589      12.2       5.8
#   ..      ...     ...      ...        ...       ...       ...       ...
#   375  2021-4      90  합천(285)  128.16994  35.56505      14.0       6.8
#   376  2021-4      91  밀양(288)  128.74412  35.49147      14.0       7.1
#   377  2021-4      92  산청(289)  127.87910  35.41300      13.8       7.0
#   378  2021-4      93  거제(294)  128.60459  34.88818      14.3       9.4
#   379  2021-4      94  남해(295)  127.92641  34.81662      14.3       9.3
#
#        최고기온(°C) color
#   285      16.6   red
#   286      19.5   red
#   287      18.7   red
#   288      20.3   red
#   289      19.0   red
#   ..        ...   ...
#   375      21.2   red
#   376      21.2   red
#   377      20.5   red
#   378      19.7   red
#   379      20.0   red
#
#   [95 rows x 9 columns]),
#  ('2021-5',
#         month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
#   380  2021-5       0   속초(90)  128.56473  38.25085      16.7      12.1
#   381  2021-5       1  북춘천(93)  127.75443  37.94738      15.6       9.8
#   382  2021-5       2   철원(95)  127.30420  38.14787      15.5       9.7
#   383  2021-5       3  동두천(98)  127.06070  37.90188      15.8      10.2
#   384  2021-5       4   파주(99)  126.76648  37.88589      15.5      10.1
#   ..      ...     ...      ...        ...       ...       ...       ...
#   470  2021-5      90  합천(285)  128.16994  35.56505      17.7      11.7
#   471  2021-5      91  밀양(288)  128.74412  35.49147      18.2      12.3
#   472  2021-5      92  산청(289)  127.87910  35.41300      17.2      11.2
#   473  2021-5      93  거제(294)  128.60459  34.88818      17.8      13.7
#   474  2021-5      94  남해(295)  127.92641  34.81662      18.3      13.7
#
#        최고기온(°C) color
#   380      21.5   red
#   381      22.1   red
#   382      21.8   red
#   383      22.2   red
#   384      21.9   red
#   ..        ...   ...
#   470      24.1   red
#   471      24.5   red
#   472      23.7   red
#   473      22.2   red
#   474      23.1   red
#
#   [95 rows x 9 columns]),
#  ('2021-6',
#         month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
#   475  2021-6       0   속초(90)  128.56473  38.25085      20.3      17.1
#   476  2021-6       1  북춘천(93)  127.75443  37.94738      21.6      16.7
#   477  2021-6       2   철원(95)  127.30420  38.14787      21.2      16.4
#   478  2021-6       3  동두천(98)  127.06070  37.90188      21.3      16.8
#   479  2021-6       4   파주(99)  126.76648  37.88589      21.1      16.7
#   ..      ...     ...      ...        ...       ...       ...       ...
#   565  2021-6      90  합천(285)  128.16994  35.56505      22.5      17.7
#   566  2021-6      91  밀양(288)  128.74412  35.49147      23.2      18.6
#   567  2021-6      92  산청(289)  127.87910  35.41300      22.1      17.4
#   568  2021-6      93  거제(294)  128.60459  34.88818      21.7      18.3
#   569  2021-6      94  남해(295)  127.92641  34.81662      22.1      18.4
#
#        최고기온(°C) color
#   475      23.8   red
#   476      27.5   red
#   477      26.8   red
#   478      27.0   red
#   479      26.7   red
#   ..        ...   ...
#   565      28.0   red
#   566      28.7   red
#   567      27.7   red
#   568      25.8   red
#   569      26.6   red
#
#   [94 rows x 9 columns]),
#  ('2021-7',
#         month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
#   570  2021-7       0   속초(90)  128.56473  38.25085      25.5      22.3
#   571  2021-7       1  북춘천(93)  127.75443  37.94738      26.7      22.0
#   572  2021-7       2   철원(95)  127.30420  38.14787      26.1      21.2
#   573  2021-7       3  동두천(98)  127.06070  37.90188      26.4      22.1
#   574  2021-7       4   파주(99)  126.76648  37.88589      26.1      22.0
#   ..      ...     ...      ...        ...       ...       ...       ...
#   660  2021-7      90  합천(285)  128.16994  35.56505      25.9      21.7
#   661  2021-7      91  밀양(288)  128.74412  35.49147      26.7      22.5
#   662  2021-7      92  산청(289)  127.87910  35.41300      25.8      21.9
#   663  2021-7      93  거제(294)  128.60459  34.88818      26.1      23.4
#   664  2021-7      94  남해(295)  127.92641  34.81662      26.1      22.9
#
#        최고기온(°C) color
#   570      29.3   red
#   571      32.7   red
#   572      31.7   red
#   573      31.7   red
#   574      31.4   red
#   ..        ...   ...
#   660      31.5   red
#   661      32.5   red
#   662      30.9   red
#   663      29.5   red
#   664      30.3   red
#
#   [95 rows x 9 columns]),
#  ('2021-8',
#         month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
#   665  2021-8       0   속초(90)  128.56473  38.25085      24.4      21.5
#   666  2021-8       1  북춘천(93)  127.75443  37.94738      24.3      20.5
#   667  2021-8       2   철원(95)  127.30420  38.14787      23.6      19.7
#   668  2021-8       3  동두천(98)  127.06070  37.90188      24.3      20.6
#   669  2021-8       4   파주(99)  126.76648  37.88589      24.1      20.1
#   ..      ...     ...      ...        ...       ...       ...       ...
#   755  2021-8      90  합천(285)  128.16994  35.56505      25.0      21.4
#   756  2021-8      91  밀양(288)  128.74412  35.49147      26.2      22.7
#   757  2021-8      92  산청(289)  127.87910  35.41300      25.1      21.6
#   758  2021-8      93  거제(294)  128.60459  34.88818      25.8      23.0
#   759  2021-8      94  남해(295)  127.92641  34.81662      26.1      23.0
#
#        최고기온(°C) color
#   665      28.0   red
#   666      29.3   red
#   667      28.7   red
#   668      29.2   red
#   669      29.3   red
#   ..        ...   ...
#   755      30.3   red
#   756      31.3   red
#   757      30.4   red
#   758      29.2   red
#   759      30.3   red
#
#   [95 rows x 9 columns]),
#  ('2021-9',
#         month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
#   760  2021-9       0   속초(90)  128.56473  38.25085      20.9      17.6
#   761  2021-9       1  북춘천(93)  127.75443  37.94738      20.7      15.7
#   762  2021-9       2   철원(95)  127.30420  38.14787      20.3      15.1
#   763  2021-9       3  동두천(98)  127.06070  37.90188      20.8      16.2
#   764  2021-9       4   파주(99)  126.76648  37.88589      20.6      16.0
#   ..      ...     ...      ...        ...       ...       ...       ...
#   850  2021-9      90  합천(285)  128.16994  35.56505      21.3      17.7
#   851  2021-9      91  밀양(288)  128.74412  35.49147      22.7      18.9
#   852  2021-9      92  산청(289)  127.87910  35.41300      21.0      17.4
#   853  2021-9      93  거제(294)  128.60459  34.88818      22.3      19.6
#   854  2021-9      94  남해(295)  127.92641  34.81662      22.2      19.5
#
#        최고기온(°C) color
#   760      24.7   red
#   761      26.4   red
#   762      26.0   red
#   763      26.3   red
#   764      26.5   red
#   ..        ...   ...
#   850      26.1   red
#   851      27.4   red
#   852      25.9   red
#   853      25.6   red
#   854      25.7   red
#
#   [95 rows x 9 columns])]

# %%
df.\
assign(color=list(map(lambda x: 'red' if x > 0 else 'blue',df.iloc[:,5]))).\
groupby('month').\
pipe(list)[0]
# Out:
# ('2021-1',
#       month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
#  0   2021-1       0   속초(90)  128.56473  38.25085      -1.2      -5.5
#  1   2021-1       1  북춘천(93)  127.75443  37.94738      -5.7     -11.8
#  2   2021-1       2   철원(95)  127.30420  38.14787      -5.9     -12.6
#  3   2021-1       3  동두천(98)  127.06070  37.90188      -4.2      -9.9
#  4   2021-1       4   파주(99)  126.76648  37.88589      -5.1     -11.4
#  ..     ...     ...      ...        ...       ...       ...       ...
#  90  2021-1      90  합천(285)  128.16994  35.56505       0.1      -5.8
#  91  2021-1      91  밀양(288)  128.74412  35.49147       0.4      -5.3
#  92  2021-1      92  산청(289)  127.87910  35.41300      -0.2      -5.5
#  93  2021-1      93  거제(294)  128.60459  34.88818       2.9      -1.3
#  94  2021-1      94  남해(295)  127.92641  34.81662       2.3      -2.2
#
#      최고기온(°C) color
#  0        2.9  blue
#  1        0.7  blue
#  2        0.7  blue
#  3        2.1  blue
#  4        1.5  blue
#  ..       ...   ...
#  90       7.1   red
#  91       7.0   red
#  92       6.1  blue
#  93       7.2   red
#  94       7.1   red
#
#  [95 rows x 9 columns])

# %%
df.\
assign(color=list(map(lambda x: 'red' if x > 0 else 'blue',df.iloc[:,5]))).\
groupby('month').\
pipe(list)[0][1]
# Out:
#      month  dindex     지점정보         경도        위도  평균기온(°C)  최저기온(°C)  \
# 0   2021-1       0   속초(90)  128.56473  38.25085      -1.2      -5.5
# 1   2021-1       1  북춘천(93)  127.75443  37.94738      -5.7     -11.8
# 2   2021-1       2   철원(95)  127.30420  38.14787      -5.9     -12.6
# 3   2021-1       3  동두천(98)  127.06070  37.90188      -4.2      -9.9
# 4   2021-1       4   파주(99)  126.76648  37.88589      -5.1     -11.4
# ..     ...     ...      ...        ...       ...       ...       ...
# 90  2021-1      90  합천(285)  128.16994  35.56505       0.1      -5.8
# 91  2021-1      91  밀양(288)  128.74412  35.49147       0.4      -5.3
# 92  2021-1      92  산청(289)  127.87910  35.41300      -0.2      -5.5
# 93  2021-1      93  거제(294)  128.60459  34.88818       2.9      -1.3
# 94  2021-1      94  남해(295)  127.92641  34.81662       2.3      -2.2
#
#     최고기온(°C) color
# 0        2.9  blue
# 1        0.7  blue
# 2        0.7  blue
# 3        2.1  blue
# 4        1.5  blue
# ..       ...   ...
# 90       7.1   red
# 91       7.0   red
# 92       6.1  blue
# 93       7.2   red
# 94       7.1   red
#
# [95 rows x 9 columns]

# %%
df.\
assign(color=list(map(lambda x: 'red' if x > 0 else 'blue',df.iloc[:,5]))).\
groupby('month').\
pipe(list)[0][1].iloc[:,[4,3,5,8]].to_numpy().tolist()
# Out:
# [[38.25085, 128.56473, -1.2, 'blue'],
#  [37.94738, 127.75443, -5.7, 'blue'],
#  [38.14787, 127.3042, -5.9, 'blue'],
#  [37.90188, 127.0607, -4.2, 'blue'],
#  [37.88589, 126.76648, -5.1, 'blue'],
#  [37.67713, 128.71834, -7.3, 'blue'],
#  [37.90262, 127.7357, -4.7, 'blue'],
#  [37.97396, 124.71237, -1.0, 'blue'],
#  [37.80456, 128.85535, -0.6, 'blue'],
#  [37.75147, 128.89099, 0.6, 'red'],
#  [37.50709, 129.12433, 0.6, 'red'],
#  [37.57142, 126.9658, -2.4, 'blue'],
#  [37.47772, 126.6249, -2.0, 'blue'],
#  [37.33749, 127.94659, -2.9, 'blue'],
#  [37.48129, 130.89863, 1.3, 'red'],
#  [37.25746, 126.983, -2.4, 'blue'],
#  [37.18126, 128.45743, -3.0, 'blue'],
#  [36.97045, 127.9525, -3.6, 'blue'],
#  [36.77658, 126.4939, -1.8, 'blue'],
#  [36.99176, 129.41278, 0.6, 'red'],
#  [36.63924, 127.44066, -1.4, 'blue'],
#  [36.37198, 127.37211, -1.0, 'blue'],
#  [36.22025, 127.99458, -2.3, 'blue'],
#  [36.57293, 128.70733, -2.2, 'blue'],
#  [36.40837, 128.15741, -1.8, 'blue'],
#  [36.03201, 129.38002, 1.8, 'red'],
#  [36.0053, 126.76135, 0.0, 'blue'],
#  [35.87797, 128.65296, 0.5, 'red'],
#  [35.84092, 127.11718, 0.5, 'red'],
#  [35.58237, 129.33469, 2.1, 'red'],
#  [35.17019, 128.57282, 1.4, 'red'],
#  [35.17294, 126.89156, 1.4, 'red'],
#  [35.10468, 129.03203, 3.3, 'red'],
#  [34.84541, 128.43561, 3.2, 'red'],
#  [34.81732, 126.38151, 2.0, 'red'],
#  [34.73929, 127.74063, 2.9, 'red'],
#  [34.68719, 125.45105, 4.5, 'red'],
#  [34.3959, 126.70182, 3.3, 'red'],
#  [35.34824, 126.599, 0.0, 'blue'],
#  [35.0204, 127.3694, 0.0, 'blue'],
#  [36.65759, 126.68772, -1.9, 'blue'],
#  [33.51411, 126.52969, 6.8, 'red'],
#  [33.29382, 126.16283, 6.9, 'red'],
#  [33.38677, 126.8802, 5.9, 'red'],
#  [33.24616, 126.5653, 7.2, 'red'],
#  [35.16378, 128.04004, 0.6, 'red'],
#  [37.70739, 126.44634, -3.3, 'blue'],
#  [37.48863, 127.49446, -3.3, 'blue'],
#  [37.26399, 127.48421, -3.4, 'blue'],
#  [38.05986, 128.16714, -4.5, 'blue'],
#  [37.6836, 127.88043, -4.8, 'blue'],
#  [37.17038, 128.98929, -4.4, 'blue'],
#  [37.38149, 128.6459, -4.3, 'blue'],
#  [37.15928, 128.19433, -4.6, 'blue'],
#  [36.48761, 127.73415, -3.1, 'blue'],
#  [36.76217, 127.29282, -2.8, 'blue'],
#  [36.32724, 126.55744, -0.2, 'blue'],
#  [36.27242, 126.92079, -1.9, 'blue'],
#  [36.10563, 127.48175, -2.0, 'blue'],
#  [36.48522, 127.24438, -1.7, 'blue'],
#  [35.72961, 126.71657, 0.0, 'blue'],
#  [35.61203, 127.28556, -2.0, 'blue'],
#  [35.56337, 126.83904, -0.4, 'blue'],
#  [35.4213, 127.39652, -0.8, 'blue'],
#  [35.65696, 127.52031, -2.8, 'blue'],
#  [35.42661, 126.697, 0.0, 'blue'],
#  [35.28366, 126.47784, 0.2, 'red'],
#  [35.22981, 128.89075, 1.8, 'red'],
#  [35.37131, 127.1286, -0.9, 'blue'],
#  [35.22655, 128.6726, 2.8, 'red'],
#  [35.30737, 129.02009, 2.3, 'red'],
#  [34.76335, 127.21226, 2.0, 'red'],
#  [34.6289, 126.76715, 1.4, 'red'],
#  [34.68886, 126.91951, 1.0, 'red'],
#  [34.55375, 126.56907, 0.9, 'red'],
#  [34.61826, 127.27572, 1.4, 'red'],
#  [35.32258, 128.28812, 0.6, 'red'],
#  [35.51138, 127.74538, -0.5, 'blue'],
#  [34.9434, 127.6914, 2.5, 'red'],
#  [34.47296, 126.25846, 2.7, 'red'],
#  [36.94361, 128.91449, -4.5, 'blue'],
#  [36.87183, 128.51687, -3.0, 'blue'],
#  [36.62727, 128.14879, -2.2, 'blue'],
#  [36.4351, 129.04005, -3.1, 'blue'],
#  [36.53337, 129.40926, 0.6, 'red'],
#  [36.3561, 128.68864, -2.9, 'blue'],
#  [36.13055, 128.32055, -0.4, 'blue'],
#  [35.97742, 128.9514, -0.5, 'blue'],
#  [35.8174, 129.2009, 0.0, 'blue'],
#  [35.66739, 127.9099, -1.0, 'blue'],
#  [35.56505, 128.16994, 0.1, 'red'],
#  [35.49147, 128.74412, 0.4, 'red'],
#  [35.413, 127.8791, -0.2, 'blue'],
#  [34.88818, 128.60459, 2.9, 'red'],
#  [34.81662, 127.92641, 2.3, 'red']]

# %%
lst=[df.\
     assign(color=list(map(lambda x: 'red' if x > 0 else 'blue',df.iloc[:,5]))).\
     groupby('month').\
     pipe(list)[i][1].iloc[:,[4,3,5,8]].\
     to_numpy().tolist()
     for i in range(10)]

# %% [markdown]
# #### Step2: folium

# %%
m = folium.Map([35, 127],
               zoom_start=6,
               scrollWheelZoom=False)
m
# a1=[35.847336682624395, 127.13066143667929]
# a2=[35.847163718642705, 127.12985784659246]
# a3=[35.8466227437543, 127.13004852898592]
# a4=[35.845842555784095, 127.13032547246222]
# a5=[35.84567326870173, 127.13185547166708]
# a1.reverse()
# a2.reverse()
# a3.reverse()
# a4.reverse()
# a5.reverse()
# t1='2021-11-21 12:00:00'
# t2='2021-11-21 12:05:00'
# t3='2021-11-21 12:10:00'
# t4='2021-11-21 12:15:00'
# t5='2021-11-21 12:20:00'
# lines=[{'coordinates':[a1,a2], 'dates': [t1,t2],'color':'red','weight':10},
#        {'coordinates':[a2,a3], 'dates': [t2,t3],'color':'red','weight':9},
#        {'coordinates':[a3,a4], 'dates': [t3,t4],'color':'red','weight':8},
#        {'coordinates':[a4,a5], 'dates': [t4,t5],'color':'red','weight':7}]
           
# features=[{'type':'Feature',
#            'geometry':{'type':'LineString',
#                        'coordinates':line['coordinates'],
#                       },
#            'properties':{'times':line['dates'],
#                          'style':{
#                              'color':line['color'],
#                              'weight':line['weight']
#                          }
#                         }
#           } for line in lines]

# folium.plugins.TimestampedGeoJson({
#     'type':'FeatureCollection',
#     'features':features,
# }, period='PT30S', add_last_point=True).add_to(m)
# m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_18b3f998dc7a4100b558c68c877a7d06%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_18b3f998dc7a4100b558c68c877a7d06%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_18b3f998dc7a4100b558c68c877a7d06%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_18b3f998dc7a4100b558c68c877a7d06%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.0%2C%20127.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20c ...

# %% [markdown]
# ### heatmap (바이러스)

# %%
folium.plugins.HeatMapWithTime?

# %%
hm = folium.Map([35.836603154469884, 127.11406532500682], tiles='CartoDB positron', zoom_start=7,scrollWheelZoom=False,)
hm_plugin = folium.plugins.HeatMapWithTime(lst,radius=20,min_opacity=0.5,gradient=False)
hm_plugin.add_to(hm)
hm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5422fe0d8b1646649ceb8e46ab6d0d62%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/iso8601-js-period%400.2.1/iso8601.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-timedimension%401.1.1/dist/leaflet.timedimension.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/pa7_hm.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/pa7_leaflet_hm.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-timedimension%401. ...

# %%
folium.plugins.HeatMapWithTime?

# %%
#import folium.plugins as plugins
#import numpy as np
np.random.seed(3141592)
#Generate random data around latitude = 23 (Tropic of Cancer) longitude of 77
initial_data = (
    np.random.normal(size=(100, 2)) * 0.0001 +
    np.array([[35.836603154469884, 127.11406532500682]])
)
#Generate Heatmap movement dataset
move_data = np.random.normal(size=(100, 2)) * 0.0001 
data = [(initial_data + move_data * i).tolist() for i in range(100)]
weight = 1  # default value
for time_entry in data:
    for row in time_entry:
        #row.append(weight)
        row.append(np.random.randn())

# %%
np.array(data[0:10]).shape
# Out:
# (10, 100, 3)

# %%
np.array(lst).shape
# Out:
# /tmp/ipykernel_54438/4031523607.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array(lst).shape
# (10,)

# %%
#Define the Folium Map
hm = folium.Map([35.836603154469884, 127.11406532500682], tiles='OpenStreetMap', zoom_start=15,scrollWheelZoom=False)
#Add the Heatmap data to HeatMapWithTime plugin        
hmwtPlugin = folium.plugins.HeatMapWithTime(data[0:10],radius=40)
hmwtPlugin.add_to(hm)
#Render the Finished Map
hm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5d548d88261045fc899ee01ed2101388%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/iso8601-js-period%400.2.1/iso8601.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-timedimension%401.1.1/dist/leaflet.timedimension.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/pa7_hm.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/pa7_leaflet_hm.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-timedimension%401. ...

# %%
from folium.plugins import HeatMap
import numpy as np
data = (
    np.random.normal(size=(100, 3)) *
    np.array([[1, 1, 1]]) +
    np.array([[28, 77, 1]])
).tolist()
SimpleHmDataMap = folium.Map(tiles='OpenStreetMap', zoom_start=6,scrollWheelZoom=False)
HeatMap(lst[0]).add_to(SimpleHmDataMap)
SimpleHmDataMap
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_54438/3164087122.py in <module>
#       7 ).tolist()
#       8 SimpleHmDataMap = folium.Map(tiles='OpenStreetMap', zoom_start=6,scrollWheelZoom=False)
# ----> 9 HeatMap(lst[0]).add_to(SimpleHmDataMap)
#      10 SimpleHmDataMap
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/folium/plugins/heat_map.py in __init__(self, data, name, min_opacity, max_zoom, radius, blur, gradient, overlay, control, show, **kwargs)
#      70         self.data = [[*validate_location(line[:2]), *line[2:]]  # noqa: E999
#      71                      for line in data]
# ---> 72         if np.any(np.isnan(self.data)):
#      73             raise ValueError('data may not contain NaNs.')
#      74         if kwargs.pop('max_val', None):
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# ### 부동산 + 시세정보

# %%
import numpy as np
size = 1000
lons = np.random.randint(74, 89, size=size) + np.random.randint(0, 1000, size=size)/1000
lats = np.random.randint(10, 33, size=size) + np.random.randint(0, 1000, size=size)/1000
locations = list(zip(lats, lons))
popups = ['lon:{}<br>lat:{}'.format(lon, lat) for (lat, lon) in locations]

# %%
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
fmClusterMap = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    scrollWheelZoom=False,
    zoom_start=5
)
FastMarkerCluster(data=list(zip(lats, lons))).add_to(fmClusterMap)
folium.LayerControl().add_to(fmClusterMap)
fmClusterMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ce1f25e02ed9495282446e1aa8538099%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ce1f25e02ed9495282446e1aa8538099%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %% [markdown]
# ### 이거 좋다..

# %%
N = 100 #Number of Popups
#Generate Random Datasets
data = np.array(
    [
        np.random.uniform(low=11, high=33, size=N),  
        np.random.uniform(low=70, high=88, size=N),  
    ]
).T
popups = [str(i) for i in range(N)] # Popups texts are simple numbers.
#Create a Map
randomPopupMarker_Map = folium.Map([27, 77], zoom_start=4,scrollWheelZoom=False)
plugins.MarkerCluster(data, popups=popups).add_to(randomPopupMarker_Map)
randomPopupMarker_Map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_54438/30987224.py in <module>
#      10 #Create a Map
#      11 randomPopupMarker_Map = folium.Map([27, 77], zoom_start=4,scrollWheelZoom=False)
# ---> 12 plugins.MarkerCluster(data, popups=popups).add_to(randomPopupMarker_Map)
#      13 randomPopupMarker_Map
#
# NameError: name 'plugins' is not defined

# %% [markdown]
# ### 전주여행 가볼만한곳

# %% [markdown]
# `-` 전동성당 (35.81325957796508, 127.1492877845946)
#
# `-` 오목대 (35.81601233748957, 127.15464802956764)
#
# `-` 객리단길 (35.819915980165995, 127.14449439808683)
#
# `-` 막걸리골목 (35.797428476068575, 127.1228218269223)

# %%
import folium.plugins as plugins
title= '''<h3 align="center">전주여행</h3>'''
#Define the map
IndiaTourMap = folium.Map(location=[35.81, 127.145], zoom_start=14, tiles="cartodbpositron",scrollWheelZoom=False)
#Define the coordinates
coords = [
    [35.812654484847336, 127.14712754226657],
    [35.81325957796508, 127.1492877845946],
    [35.81601233748957, 127.15464802956764],
    [35.819915980165995, 127.14449439808683],
    [35.797428476068575, 127.1228218269223]
]
#Let us add color code connects for each coordinates
plugins.PolyLineOffset(
    coords, weight=2, dash_array="5,10", color="red", opacity=1
).add_to(IndiaTourMap)
plugins.PolyLineOffset(coords, color="#00f", opacity=0.5, offset=-5).add_to(IndiaTourMap)
plugins.PolyLineOffset(coords, color="#00f", opacity=0.5, offset=5).add_to(IndiaTourMap)
#Let us show the map
IndiaTourMap.get_root().html.add_child(folium.Element(title_html))
IndiaTourMap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_54438/740927235.py in <module>
#      18 plugins.PolyLineOffset(coords, color="#00f", opacity=0.5, offset=5).add_to(IndiaTourMap)
#      19 #Let us show the map
# ---> 20 IndiaTourMap.get_root().html.add_child(folium.Element(title_html))
#      21 IndiaTourMap
#
# NameError: name 'title_html' is not defined

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
import folium
from folium import FeatureGroup, LayerControl, Map, Marker, features
import folium.plugins as plugins 
from folium.plugins import FloatImage, HeatMap, MarkerCluster, FastMarkerCluster, MeasureControl, MousePosition
from folium.features import DivIcon


loc = 'Continental USA Tour traversal in a Folium Map in a non-overlapping manner'
title_html = '''
             <h2 align="center" style="font-size:18px"><b>{}</b></h2>
             '''.format(loc)   
# Let us define a map with the US in the center and a reasonable Zool level with an Open StreetMap 
ContinentalUSTourMap = folium.Map(location=[40.0, -100], zoom_start=4, tiles="OpenStreetMap",scrollWheelZoom=False)

# Let us define Locations of the states to traverse in sequence. 
# These states are as per US Map. We can also use an algorithm on Latitude & Longitude for this as well
#

Locations = ['WA', 'OR', 'CA','NV','AZ','UT','ID','MT','WY','CO',
             'NM','TX','OK','KS','NE','SD','ND','MN','IA','MO',
             'AR','LA','MS','AL','TN','IL','WI','MI','IN','KY','OH',
             'WV','PA','NY','VT','ME','NH','MA','RI','CT','NJ','DE',
             'DC','MD','VA','NC','SC','GA','FL',
            ]

#Let us define the corresponding Latitudes and Longitudes for the capital cities of these states 
coords = [
    [47.042418,-122.893077],[44.931109,-123.029159],
    [38.555605,-121.468926],[39.160949,-119.753877],
    [33.448457,-112.073844],[40.7547,-111.892622],
    [43.613739,-116.237651],[46.595805,-112.027031],
    [41.145548,-104.802042],[39.7391667,-104.984167],
    [35.667231,-105.964575],[30.266667,-97.75],
    [35.482309,-97.534994],[39.04,-95.69],
    [40.809868,-96.675345],[44.367966,-100.336378],
    [46.8083,-100.7837],[44.95,-93.094],
    [41.590939,-93.620866],[38.572954,-92.189283],
    [34.736009,-92.331122],[30.4515, -91.1871],
    [32.320,-90.207],[32.361538,-86.279118],
    [36.165,-86.784],[39.783250,-89.650373],
    [43.074722,-89.384444],[42.7335,-84.5467],
    [39.790942,-86.147685],[38.197274,-84.86311],
    [39.962245,-83.000647],[38.349497,-81.633294],
    [40.269789,-76.875613],[42.659829,-73.781339],
    [44.26639,-72.57194], [44.323535,-69.765261],
    [43.220093,-71.549127],[42.2352,-71.0275],
    [41.8240,-71.4128],[41.767,-72.677],
    [40.221741,-74.756138],[39.161921,-75.526755],
    [38.972945,-76.501157],[38.913,-77.013],
    [37.54,-77.46],[35.771,-78.638],
    [34.000,-81.035],[33.76,-84.39],
    [30.4518,-84.27277],
]

Capitals = ['Olympia','Salem','Sacramento','Carson City','Phoenix','Salt Lake City','Boise','Helena',
            'Cheyenne','Denver','Santa Fe','Austin','Oklahoma City','Topeka','Lincoln','Pierre',
            'Bismarck','Saint Paul','Des Moines','Jefferson City','Little Rock','Baton Rouge','Jackson','Montgomery',
            'Nashville','Springfield','Madison','Lansing','Indianapolis','Frankfort','Columbus','Charleston',
            'Harrisburg','Albany','Montpelier','Augusta','Concord','Boston','Providence','Hartford',
            'Trenton','Dover','Washington D.C','Annapolis','Richmond','Raleigh','Columbia','Atlanta','Tallahassee',
]
Population = [46478,174365,513624,55916,1680992,200567,228959,32315,64235,727211,
              84683,978908,655057,125310,289102,13646,73529,308096,214237,42838,
              197312,220236,160628,198525,670820,114230,259680,118210,876384,27679,
              898553,46536,49528,96460,7855,18681,43627,692600,179883,122105,83203,
              38079,39174,230436,474069,131674,506811,194500,32113,345064,
]
tiles = ['stamenwatercolor', 'cartodbpositron', 'openstreetmap', 'stamenterrain','stamentoner']
for tile in tiles:
    folium.TileLayer(tile).add_to(ContinentalUSTourMap)
#feature_group = FeatureGroup(name='Some icons')    
folium.LayerControl().add_to(ContinentalUSTourMap)
#Let us iterate and add the markers for the capital cities of each state we are traversing
iterlength = len(coords)
iteratorno = 0
iconc = folium.Icon(color="red",icon="fa-car", prefix='car',icon_size=(20, 20))
while iteratorno < iterlength:
    my_string = ' 2019 Population  : :<b> {} </b> <br>'.format(Population[iteratorno])
    my_string = my_string + ' State  : :<b> {} </b> <br>'.format(Locations[iteratorno])
    tootip_str = " Capital City <b>" + Capitals[iteratorno] + "</b><br>" + my_string
    ContinentalUSTourMap.add_child(
        folium.Marker(
            location=[coords[iteratorno][0], coords[iteratorno][1]],
            popup=my_string,
            icon=DivIcon(icon_size=(50,50),html='<div style="font-size: 6pt; color : blue">' + str(iteratorno+1) + '</div>',),
            tooltip = tootip_str,
            radius=10+Population[iteratorno]/100000, 
            color='black',
            fill=True,
            fill_color='yellow',
            fill_opacity=0.2,
        )
    )
    ContinentalUSTourMap.add_child(
           folium.CircleMarker(
            location=[coords[iteratorno][0], coords[iteratorno][1]],
            radius=10+Population[iteratorno]/100000, 
            color='black',
            fill=True,
            fill_color='yellow',
            fill_opacity=0.2,
        )
    )
    iteratorno = iteratorno + 1
 
#feature_group.add_to(ContinentalUSTourMap)
LayerControl().add_to(ContinentalUSTourMap)
plugins.PolyLineOffset(
    coords, weight=2, dash_array="5,10", color="red", opacity=1
).add_to(ContinentalUSTourMap)
plugins.PolyLineOffset(coords, color="#00f", opacity=1, offset=-3).add_to(ContinentalUSTourMap)
plugins.PolyLineOffset(coords, color="#080", opacity=1, offset=3).add_to(ContinentalUSTourMap)
ContinentalUSTourMap.get_root().html.add_child(folium.Element(title_html))
ContinentalUSTourMap.save("Continental_US_Tour_Map.html")
ContinentalUSTourMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0abef4ebf6aa445aa992204e3079014d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-polylineoffset%401.1.1/leaflet.polylineoffset.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%3Ch2%20align%3D%22center%22%20style%3D%22font-size%3A18px%22%3E%3Cb%3EContinental%20USA%20Tour%20traversal%20in%20a%20Folium%20Map%20in%20a%20non-overlapping%20manner%3C/b%3E%3C/h2%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0abef4ebf6aa445aa992204e3079014d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20 ...

# %%
import pandas as pd
import numpy as np
import folium
district_wise_census = pd.read_csv("https://raw.githubusercontent.com/kalilurrahman/datasets/main/district%20wise%20population%20and%20centroids.csv")
state_wise_centroid = pd.read_csv("https://raw.githubusercontent.com/kalilurrahman/datasets/main/state%20wise%20centroids_2011.csv")
state_wise_census = district_wise_census.groupby(by="State").sum()[["Population in 2001","Population in 2011"]].reset_index()
state_wise_census = state_wise_centroid.merge(state_wise_census, left_on="State", right_on="State")
#state_wise_census.head()
#district_wise_census.head()
tn_districts = district_wise_census[district_wise_census["State"]=="Tamil Nadu"]
center_lat = tn_districts.mean().Latitude
center_long = tn_districts.mean().Longitude
TNMap = folium.Map(location=[center_lat, center_long], zoom_start=6.5, tiles="stamenterrain",scrollWheelZoom=False)
tiles = ['stamenwatercolor', 'cartodbpositron', 'openstreetmap', 'stamenterrain','stamentoner']
for tile in tiles:
    folium.TileLayer(tile).add_to(TNMap)
folium.LayerControl().add_to(TNMap)
for district in tn_districts["District"].unique():
    district_census = tn_districts[tn_districts["District"]==district]
    str_2011_Pop = district_census["Population in 2011"].values[0]
    str_2001_Pop = district_census["Population in 2001"].values[0]     
    my_string = 'Population 2011 : :<b> {} </b>, <br> Population 2001 :<b> {} </b> <br>'.format(str_2011_Pop,str_2001_Pop)
    tootip_str = " District <b>" + district_census.District.values[0] + "</b><br>" + my_string
    folium.Marker(
        location=[district_census.Latitude.values[0], district_census.Longitude.values[0]],
        popup=my_string,
        tooltip = tootip_str,
        icon=folium.Icon(icon='info-sign', color="red"),
        draggable=False
    ).add_to(TNMap)
for district in tn_districts["District"].unique():
    district_census = tn_districts[tn_districts["District"]==district]
    str_2011_Pop = district_census["Population in 2011"].values[0]
    str_2001_Pop = district_census["Population in 2001"].values[0]     
    my_string = 'Population 2011 : :<b> {} </b>, <br> Population 2001 :<b> {} </b> <br>'.format(str_2011_Pop,str_2001_Pop)
    tootip_str = " District <b>" + district_census.District.values[0] + "</b><br>" + my_string
    folium.Marker(
        location=[district_census.Latitude.values[0], district_census.Longitude.values[0]],
        popup=my_string,
        tooltip = tootip_str,
        icon=folium.Icon(icon='cloud', color="blue")
    ).add_to(TNMap)
folium.Polygon(
    locations=list(zip(tn_districts.Latitude, tn_districts.Longitude))[1:22],
    popup="Path",
    tooltip = "Path",
    color="violet",
    fill_color="green"
).add_to(TNMap)
folium.Polygon(
    locations=list(zip(tn_districts.Latitude, tn_districts.Longitude))[1:12],
    popup="Path",
    tooltip = "Path",
    color="black",
    fill_color="yellow"
).add_to(TNMap)
TNMap
# Out:
# /tmp/ipykernel_54438/1049724470.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   center_lat = tn_districts.mean().Latitude
# /tmp/ipykernel_54438/1049724470.py:12: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   center_long = tn_districts.mean().Longitude
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d46664a89ca04fbc8ebd89b3c8ac2b35%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d46664a89ca04fbc8ebd89b3c8ac2b35%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d46664a89ca04fbc8ebd89b3c8ac2b35%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d46664a89ca04fbc8ebd89b3c8ac2b35%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B10.987884792582799%2C%2078.57984930389416%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
tn_districts = district_wise_census[district_wise_census["State"]=="Tamil Nadu"]
center_lat = tn_districts.mean().Latitude
center_long = tn_districts.mean().Longitude
TNPopMap = folium.Map(location=[center_lat, center_long], zoom_start=6.5,scrollWheelZoom=False)
tiles = ['stamenwatercolor', 'cartodbpositron', 'openstreetmap', 'stamenterrain']
for tile in tiles:
    folium.TileLayer(tile).add_to(TNPopMap)
for district in tn_districts["District"].unique():
    district_census = tn_districts[tn_districts["District"]==district]
    str_2011_Pop = district_census["Population in 2011"].values[0]
    str_2001_Pop = district_census["Population in 2001"].values[0]     
    my_string = 'Population 2011 : :<b> {} </b>, <br> Population 2001 :<b> {} </b> <br>'.format(str_2011_Pop,str_2001_Pop)
    tootip_str = " District <b>" + district_census.District.values[0] + "</b><br>" + my_string
    folium.RegularPolygonMarker(
        location=[district_census.Latitude.values[0], district_census.Longitude.values[0]],
        radius = float(district_census["Population in 2011"].values[0]/200000),
        rotation=0,
        color="green",
        popup=my_string,
        tooltip = tootip_str,
        fill_color="purple",
        fill_opacity=0.6,
        line_opacity=0.8,
    ).add_to(TNPopMap)
folium.LayerControl().add_to(TNPopMap)
TNPopMap
# Out:
# /tmp/ipykernel_54438/1802376945.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   center_lat = tn_districts.mean().Latitude
# /tmp/ipykernel_54438/1802376945.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   center_long = tn_districts.mean().Longitude
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ca6bcdc3c84b4246bd57f9f250fc976f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ca6bcdc3c84b4246bd57f9f250fc976f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ca6bcdc3c84b4246bd57f9f250fc976f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ca6bcdc3c84b4246bd57f9f250fc976f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%2 ...

# %%
center_lat = state_wise_census.mean().Latitude-1.4
center_long = state_wise_census.mean().Longitude

m = folium.Map(location=[center_lat, center_long], zoom_start=5.3,scrollWheelZoom=False)

tiles = ['stamenwatercolor', 'cartodbpositron', 'openstreetmap', 'stamenterrain']
for tile in tiles:
    folium.TileLayer(tile).add_to(m)

for state in state_wise_census["State"].unique():
    state_census = state_wise_census[state_wise_census["State"]==state]
    lat, lon = state_census.Latitude.values[0], state_census.Longitude.values[0]
    population = state_census["Population in 2011"].values[0]
    str_2011_Pop = state_census["Population in 2011"].values[0]
    str_2001_Pop = state_census["Population in 2001"].values[0]     
    my_string = 'Population 2011 : :<b> {} </b>, <br> Population 2001 :<b> {} </b> <br>'.format(str_2011_Pop,str_2001_Pop)
    tootip_str = " State <b>" + state_census.State.values[0] + "</b><br>" + my_string
   
    folium.Rectangle(
        bounds=[(lat, lon), (lat+(population/7e7), lon+(population/7e7))],
        popup=my_string,
        tooltip = tootip_str,
        color="green",
        fill_color="blue"
    ).add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# /tmp/ipykernel_54438/2959965093.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   center_lat = state_wise_census.mean().Latitude-1.4
# /tmp/ipykernel_54438/2959965093.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   center_long = state_wise_census.mean().Longitude
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_993d8ea015f244b3b12bd0abcd9c3dc3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_993d8ea015f244b3b12bd0abcd9c3dc3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_993d8ea015f244b3b12bd0abcd9c3dc3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_993d8ea015f244b3b12bd0abcd9c3dc3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B21.851221186530204%2C%2082.59845449360176%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### 예제2: geo_json

# %%
# import numpy as np
# #Generate a Random Array of values around lat / long - Here we are using 74-80 as longitude and 16-28 as latitude
# data = (
#     np.random.normal(size=(5000, 3)) *
#     np.array([[74, 80, 1]]) +
#     np.array([[16, 28, 1]])
# ).tolist()

# %%
import json
import requests
#Load the United States JSON file
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
us_states = f'{url}/us-states.json'
#Load the data
geo_json_data = json.loads(requests.get(us_states).text)
#Create a Stamen Toner US Folium Map
JSON_US_Map = folium.Map([43, -100], zoom_start=4, tiles="stamentoner",scrollWheelZoom=False)
#Add the GeoJSON data to the map and Show
folium.GeoJson(geo_json_data).add_to(JSON_US_Map)
JSON_US_Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2367caf36c574e57877f72bb3ac801bb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2367caf36c574e57877f72bb3ac801bb%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2367caf36c574e57877f72bb3ac801bb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2367caf36c574e57877f72bb3ac801bb%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.0%2C%20-100.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...
