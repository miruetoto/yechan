# %%
x=seq(10,5,-0.5)
a=rep(1:456,each=10)
b=rep(1:10)
c=rep(0,times=4560)
d=cbind(a,b,c)
for (j in seq(1,4560,by=10)){
  for (i in 1:9){
    d[j,3]=d[j,1]/100
    d[j+i,3]=d[j+i-1,3]+d[j+i-1,3]+1
  }
}
# Out:
#   File "<ipython-input-1-547b5a4cfd60>", line 2
#     a=rep(1:456,each=10)
#            ^
# SyntaxError: invalid syntax
