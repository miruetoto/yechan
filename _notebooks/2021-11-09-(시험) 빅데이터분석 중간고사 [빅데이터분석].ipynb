# %% [markdown]
# # (시험) 빅데이터분석
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 최규빈
# - hide: true
# - categories: [빅데이터분석]

# %% [markdown]
# ## asdf

# %%
import torch

# %%
net = torch.nn.Linear(in_features=1,out_features=1,bias=False)

# %%
X=torch.tensor([1.5])

# %%
X
# Out:
# tensor([1.5000])

# %%
net.weight
# Out:
# Parameter containing:
# tensor([[0.3609]], requires_grad=True)

# %%
net(X)
# Out:
# tensor([0.5413], grad_fn=<SqueezeBackward3>)

# %%
1.5*0.3609
# Out:
# 0.54135
