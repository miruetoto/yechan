# %% [markdown]
# # (노트) 주피터 혹은 마크다운문서에 그림삽입
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - categories: [주피터, R마크다운]

# %% [markdown]
# ### 마크다운

# %% [markdown]
# `-` 기본 : `![](2021-08-25-Hani01.jpeg)`
# - 주피터: 그림잘보임
# - RMD: 그림잘보임
# - fastpage: 그림잘보임

# %% [markdown]
# `-` 크기조정(1)

# %% [markdown]
# `-` 크기조정(2)

# %% [markdown]
# #### HTML

# %% [markdown]
# `-` 기본: `<img src = 2021-08-25-Hani01.jpeg>`
# - 주피터: 그림잘보임
# - RMD: 그림잘보임
# - fastpages: 그림잘보임

# %% [markdown]
# `-` 크기조정(1): `<img src = 2021-08-25-Hani01.jpeg width=20%>`
# - 주피터: 그림잘보임 + 크기조정잘됨
# - RMD: 그림잘보임 + 크기조정잘됨
# - fastpages: 그림잘보임 + 크기조정잘됨 + 알아서 가운데로 보임

# %% [markdown]
# `-` 크기조정(2): `<img src = 2021-08-25-Hani01.jpeg width=150>`
# - 주피터: 그림잘보임 + 크기조정잘됨
# - RMD: 그림잘보임 + 크기조정잘됨
# - fastpages: 그림잘보임 + 크기조정잘됨 + 가운데로 보임

# %% [markdown]
# `-` 크기조정이후 가운데정렬: `<center><img src = 2021-08-25-Hani01.jpeg width=20%><center/>`

# %% [markdown]
# - 주피터: 그림잘보임 + 크기조정잘됨 + 가운데로 보임
# - RMD: 그림잘보임 + 크기조정잘됨 + 가운데로 보임
# - fastpages: 그림안보임
