# %% [markdown]
# # (노트) 판다스 백엔드 플랏
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - hide: false
# - categories: [시각화]

# %% [markdown]
# ### imports

# %%
import numpy as np
import pandas as pd
import pandas.plotting 
import matplotlib.pyplot as plt
import matplotlib
import warnings
from IPython.display import HTML

# %%
from pandas_datareader import data as pdr

# %%
def show(fig): 
    return HTML(fig.to_html(include_plotlyjs='cdn', include_mathjax=False))

# %% [markdown]
# ### theme

# %%
import mplcyberpunk
plt.style.use("seaborn-dark")
#plt.style.use("cyberpunk")
matplotlib.pyplot.xkcd(scale=0, length=200)

# %% [markdown]
# ### line

# %% [markdown]
# #### 예제1 (matplotlib)

# %%
symbols = ['AMZN','AAPL', 'GOOG', 'FB', 'MSFT', 'NFLX', 'NVDA','TSLA']
start = '2020-01-01'
end = '2021-11-25'
df = pdr.get_data_yahoo(symbols, start, end)['Adj Close']
df
# Out:
# Symbols            AMZN        AAPL         GOOG          FB        MSFT  \
# Date
# 2019-12-31  1847.839966   72.337982  1337.020020  205.250000  154.749725
# 2020-01-02  1898.010010   73.988472  1367.369995  209.779999  157.615112
# 2020-01-03  1874.969971   73.269157  1360.660034  208.669998  155.652481
# 2020-01-06  1902.880005   73.852974  1394.209961  212.600006  156.054871
# 2020-01-07  1906.859985   73.505646  1393.339966  213.059998  154.632004
# ...                 ...         ...          ...         ...         ...
# 2021-11-18  3696.060059  157.869995  3014.179932  338.690002  341.269989
# 2021-11-19  3676.570068  160.550003  2999.050049  345.299988  343.109985
# 2021-11-22  3572.570068  161.020004  2941.570068  341.010010  339.829987
# 2021-11-23  3580.040039  161.410004  2935.139893  337.250000  337.679993
# 2021-11-24  3580.409912  161.940002  2934.350098  341.059998  337.910004
#
# Symbols           NFLX        NVDA         TSLA
# Date
# ...

# %%
df.reset_index()
# Out:
# Symbols       Date         AMZN        AAPL         GOOG          FB  \
# 0       2019-12-31  1847.839966   72.337982  1337.020020  205.250000
# 1       2020-01-02  1898.010010   73.988472  1367.369995  209.779999
# 2       2020-01-03  1874.969971   73.269157  1360.660034  208.669998
# 3       2020-01-06  1902.880005   73.852974  1394.209961  212.600006
# 4       2020-01-07  1906.859985   73.505646  1393.339966  213.059998
# ..             ...          ...         ...          ...         ...
# 476     2021-11-18  3696.060059  157.869995  3014.179932  338.690002
# 477     2021-11-19  3676.570068  160.550003  2999.050049  345.299988
# 478     2021-11-22  3572.570068  161.020004  2941.570068  341.010010
# 479     2021-11-23  3580.040039  161.410004  2935.139893  337.250000
# 480     2021-11-24  3580.409912  161.940002  2934.350098  341.059998
#
# Symbols        MSFT        NFLX        NVDA         TSLA
# 0        154.749725  323.570007   58.676846    83.666000
# ...

# %%
df.stack().reset_index().rename(columns={0:'value'})
# Out:
#            Date Symbols        value
# 0    2019-12-31    AMZN  1847.839966
# 1    2019-12-31    AAPL    72.337982
# 2    2019-12-31    GOOG  1337.020020
# 3    2019-12-31      FB   205.250000
# 4    2019-12-31    MSFT   154.749725
# ...         ...     ...          ...
# 3843 2021-11-24      FB   341.059998
# 3844 2021-11-24    MSFT   337.910004
# 3845 2021-11-24    NFLX   658.289978
# 3846 2021-11-24    NVDA   326.699982
# 3847 2021-11-24    TSLA  1116.000000
#
# [3848 rows x 3 columns]

# %%
df.plot.line(y='AMZN')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot.line(y=['AMZN','TSLA'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot.line()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot.line(figsize=(12,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot.line(figsize=(6,12),subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
df.plot.line(figsize=(15,6),subplots=True,layout=(2,4))
# Out:
# array([[<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>]],
#       dtype=object)

# %%
df.plot.line(figsize=(15,6),subplots=True,layout=(2,4),fontsize=10)
# Out:
# array([[<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>]],
#       dtype=object)

# %%
df.plot.line(figsize=(15,6),subplots=True,layout=(2,4),fontsize=10,alpha=0.5)
# Out:
# array([[<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>]],
#       dtype=object)

# %%
df.plot.line(figsize=(15,6),subplots=True,layout=(2,4),legend=False)
# Out:
# array([[<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#        [<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#         <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>]],
#       dtype=object)

# %% [markdown]
# ### bar, barh

# %% [markdown]
# #### 예제1 (matplotlib)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/kalilurrahman/datasets/main/mobilephonemktshare2020.csv') 
df
# Out:
#        Date  Samsung  Apple  Huawei  Xiaomi  Oppo  Mobicel  Motorola    LG  \
# 0   2019-10    31.49  22.09   10.02    7.79  4.10     3.15      2.41  2.40
# 1   2019-11    31.36  22.90   10.18    8.16  4.42     3.41      2.40  2.40
# 2   2019-12    31.37  24.79    9.95    7.73  4.23     3.19      2.50  2.54
# 3   2020-01    31.29  24.76   10.61    8.10  4.25     3.02      2.42  2.40
# 4   2020-02    30.91  25.89   10.98    7.80  4.31     2.89      2.36  2.34
# 5   2020-03    30.80  27.03   10.70    7.70  4.30     2.87      2.35  2.28
# 6   2020-04    30.41  28.79   10.28    7.60  4.20     2.75      2.51  2.28
# 7   2020-05    30.18  26.72   10.39    8.36  4.70     3.12      2.46  2.19
# 8   2020-06    31.06  25.26   10.69    8.55  4.65     3.18      2.57  2.11
# 9   2020-07    30.95  24.82   10.75    8.94  4.69     3.46      2.45  2.03
# 10  2020-08    31.04  25.15   10.73    8.90  4.69     3.38      2.39  1.96
# ...

# %%
df.plot.bar(x='Date', y=['Samsung','Apple'],figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot.bar(x='Date', y=['Samsung','Apple'],figsize=(10,5),width=0.7)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot.barh(x='Date', y=['Samsung','Apple'],figsize=(5,10),width=0.7)
# Out:
# <AxesSubplot:ylabel='Date'>

# %%
df.plot.bar(x='Date',figsize=(30,20),subplots=True,layout=(4,4),legend=False)
# Out:
# array([[<AxesSubplot:title={'center':'Samsung'}, xlabel='Date'>,
#         <AxesSubplot:title={'center':'Apple'}, xlabel='Date'>,
#         <AxesSubplot:title={'center':'Huawei'}, xlabel='Date'>,
#         <AxesSubplot:title={'center':'Xiaomi'}, xlabel='Date'>],
#        [<AxesSubplot:title={'center':'Oppo'}, xlabel='Date'>,
#         <AxesSubplot:title={'center':'Mobicel'}, xlabel='Date'>,
#         <AxesSubplot:title={'center':'Motorola'}, xlabel='Date'>,
#         <AxesSubplot:title={'center':'LG'}, xlabel='Date'>],
#        [<AxesSubplot:title={'center':'Others'}, xlabel='Date'>,
#         <AxesSubplot:title={'center':'Realme'}, xlabel='Date'>,
#         <AxesSubplot:title={'center':'Google'}, xlabel='Date'>,
#         <AxesSubplot:title={'center':'Nokia'}, xlabel='Date'>],
#        [<AxesSubplot:title={'center':'Lenovo'}, xlabel='Date'>,
#         <AxesSubplot:title={'center':'OnePlus'}, xlabel='Date'>,
#         <AxesSubplot:title={'center':'Sony'}, xlabel='Date'>,
# ...

# %% [markdown]
# - 이건 사실 라인플랏으로 그리는게 더 좋음

# %%
df.melt(id_vars='Date').groupby('variable').agg(np.mean).plot.bar()
# Out:
# <AxesSubplot:xlabel='variable'>

# %%
df.melt(id_vars='Date').groupby('variable').agg(np.mean).sort_values('value',ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='variable'>

# %% [markdown]
# #### 예제1 (plotly)

# %%
fig = df.melt(id_vars='Date').groupby('variable').agg(np.mean).sort_values('value',ascending=False).plot.bar(backend='plotly')
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = df.melt(id_vars='Date').plot.bar(x='Date',y='value',color='variable',backend='plotly')
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = df.melt(id_vars='Date').query('variable=="Samsung" or variable=="Apple" or variable=="Huawei" or variable=="Xiaomi"').\
plot.bar(x='Date',y='value',color='variable',barmode='group',backend='plotly')
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = df.melt(id_vars='Date').query('variable=="Samsung" or variable=="Apple" or variable=="Huawei" or variable=="Xiaomi"').\
plot.bar(x='Date',y='value',color='variable',barmode='group',backend='plotly',text='value')
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = df.melt(id_vars='Date').query('variable=="Samsung" or variable=="Apple" or variable=="Huawei" or variable=="Xiaomi"').\
plot.bar(x='Date',y='value',color='variable',facet_col='variable',backend='plotly')
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = df.melt(id_vars='Date').query('variable=="Samsung" or variable=="Apple" or variable=="Huawei" or variable=="Xiaomi"').\
plot.bar(x='value',y='Date',color='variable',facet_row='variable',backend='plotly',height=700)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### pie

# %% [markdown]
# #### 예제1 (matplotlib)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/kalilurrahman/datasets/main/mobilephonemktshare2020.csv') 
df
# Out:
#        Date  Samsung  Apple  Huawei  Xiaomi  Oppo  Mobicel  Motorola    LG  \
# 0   2019-10    31.49  22.09   10.02    7.79  4.10     3.15      2.41  2.40
# 1   2019-11    31.36  22.90   10.18    8.16  4.42     3.41      2.40  2.40
# 2   2019-12    31.37  24.79    9.95    7.73  4.23     3.19      2.50  2.54
# 3   2020-01    31.29  24.76   10.61    8.10  4.25     3.02      2.42  2.40
# 4   2020-02    30.91  25.89   10.98    7.80  4.31     2.89      2.36  2.34
# 5   2020-03    30.80  27.03   10.70    7.70  4.30     2.87      2.35  2.28
# 6   2020-04    30.41  28.79   10.28    7.60  4.20     2.75      2.51  2.28
# 7   2020-05    30.18  26.72   10.39    8.36  4.70     3.12      2.46  2.19
# 8   2020-06    31.06  25.26   10.69    8.55  4.65     3.18      2.57  2.11
# 9   2020-07    30.95  24.82   10.75    8.94  4.69     3.46      2.45  2.03
# 10  2020-08    31.04  25.15   10.73    8.90  4.69     3.38      2.39  1.96
# ...

# %% [markdown]
# `-` 하나의 파이차트를 만들어보자.

# %%
df.plot.pie(y='Samsung')
# Out:
# <AxesSubplot:ylabel='Samsung'>

# %% [markdown]
# - $0,1,2,3, \dots, 12$ 는 뭐지? $\to$ 인덱스
# - 놀라울정도로 쓸모없는 차트.. 머 어쩌란 건지 설명자체가 불가능한 차트

# %% [markdown]
# `-` 0~12를 Date칼럼의 값들로 하는게 의미가 있다. $\to$ Date 칼럼을 인덱스로 하자!

# %%
df.set_index('Date').plot.pie(y='Samsung')
# Out:
# <AxesSubplot:ylabel='Samsung'>

# %% [markdown]
# - 훨씬나음, 레전드를 제거해도 될듯

# %%
df.set_index('Date').plot.pie(y='Samsung',legend=False)
# Out:
# <AxesSubplot:ylabel='Samsung'>

# %% [markdown]
# `-` 여러개의 파이차트를 만들어보자. (별 생각없이!!)

# %%
df.set_index('Date').loc[:,['Samsung','Apple','Huawei','Xiaomi']].plot.pie(subplots=True,layout=(2,2),legend=False,figsize=(10,10))
# Out:
# array([[<AxesSubplot:ylabel='Samsung'>, <AxesSubplot:ylabel='Apple'>],
#        [<AxesSubplot:ylabel='Huawei'>, <AxesSubplot:ylabel='Xiaomi'>]],
#       dtype=object)

# %% [markdown]
# `-` 성공했는데 왠지 쓸모없음
# - 디자인: 날짜를 왜 색으로 표현해요? // 색으로 표현해야하는건 회사들 아닌가?

# %% [markdown]
# `-` 데이터의 구조자체가 틀려먹음

# %%
df
# Out:
#        Date  Samsung  Apple  Huawei  Xiaomi  Oppo  Mobicel  Motorola    LG  \
# 0   2019-10    31.49  22.09   10.02    7.79  4.10     3.15      2.41  2.40
# 1   2019-11    31.36  22.90   10.18    8.16  4.42     3.41      2.40  2.40
# 2   2019-12    31.37  24.79    9.95    7.73  4.23     3.19      2.50  2.54
# 3   2020-01    31.29  24.76   10.61    8.10  4.25     3.02      2.42  2.40
# 4   2020-02    30.91  25.89   10.98    7.80  4.31     2.89      2.36  2.34
# 5   2020-03    30.80  27.03   10.70    7.70  4.30     2.87      2.35  2.28
# 6   2020-04    30.41  28.79   10.28    7.60  4.20     2.75      2.51  2.28
# 7   2020-05    30.18  26.72   10.39    8.36  4.70     3.12      2.46  2.19
# 8   2020-06    31.06  25.26   10.69    8.55  4.65     3.18      2.57  2.11
# 9   2020-07    30.95  24.82   10.75    8.94  4.69     3.46      2.45  2.03
# 10  2020-08    31.04  25.15   10.73    8.90  4.69     3.38      2.39  1.96
# ...

# %%
df.T
# Out:
#                0        1        2        3        4        5        6   \
# Date      2019-10  2019-11  2019-12  2020-01  2020-02  2020-03  2020-04
# Samsung     31.49    31.36    31.37    31.29    30.91     30.8    30.41
# Apple       22.09     22.9    24.79    24.76    25.89    27.03    28.79
# Huawei      10.02    10.18     9.95    10.61    10.98     10.7    10.28
# Xiaomi       7.79     8.16     7.73      8.1      7.8      7.7      7.6
# Oppo          4.1     4.42     4.23     4.25     4.31      4.3      4.2
# Mobicel      3.15     3.41     3.19     3.02     2.89     2.87     2.75
# Motorola     2.41      2.4      2.5     2.42     2.36     2.35     2.51
# LG            2.4      2.4     2.54      2.4     2.34     2.28     2.28
# Others       9.51      9.1     8.13     7.55     7.06     6.63     5.84
# Realme       0.54     0.78     0.84     0.88     0.89     0.93      0.9
# Google       2.35     0.66     0.75     0.69      0.7     0.73     0.75
# ...

# %% [markdown]
# - 이런느낌이어야함.

# %% [markdown]
# `-` Date를 index로 선정하고 transpose하면 될것 같음

# %%
df.set_index('Date').T
# Out:
# Date      2019-10  2019-11  2019-12  2020-01  2020-02  2020-03  2020-04  \
# Samsung     31.49    31.36    31.37    31.29    30.91    30.80    30.41
# Apple       22.09    22.90    24.79    24.76    25.89    27.03    28.79
# Huawei      10.02    10.18     9.95    10.61    10.98    10.70    10.28
# Xiaomi       7.79     8.16     7.73     8.10     7.80     7.70     7.60
# Oppo         4.10     4.42     4.23     4.25     4.31     4.30     4.20
# Mobicel      3.15     3.41     3.19     3.02     2.89     2.87     2.75
# Motorola     2.41     2.40     2.50     2.42     2.36     2.35     2.51
# LG           2.40     2.40     2.54     2.40     2.34     2.28     2.28
# Others       9.51     9.10     8.13     7.55     7.06     6.63     5.84
# Realme       0.54     0.78     0.84     0.88     0.89     0.93     0.90
# Google       2.35     0.66     0.75     0.69     0.70     0.73     0.75
# Nokia        0.95     0.97     0.90     0.88     0.81     0.72     0.69
# ...

# %%
df.set_index('Date').T.plot.pie(subplots=True,layout=(4,4),figsize=(30,30),legend=False)
# Out:
# array([[<AxesSubplot:ylabel='2019-10'>, <AxesSubplot:ylabel='2019-11'>,
#         <AxesSubplot:ylabel='2019-12'>, <AxesSubplot:ylabel='2020-01'>],
#        [<AxesSubplot:ylabel='2020-02'>, <AxesSubplot:ylabel='2020-03'>,
#         <AxesSubplot:ylabel='2020-04'>, <AxesSubplot:ylabel='2020-05'>],
#        [<AxesSubplot:ylabel='2020-06'>, <AxesSubplot:ylabel='2020-07'>,
#         <AxesSubplot:ylabel='2020-08'>, <AxesSubplot:ylabel='2020-09'>],
#        [<AxesSubplot:ylabel='2020-10'>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# `-` 아래도 가능함.

# %%
df.set_index('Date').stack().swaplevel().unstack().plot.pie(subplots=True,figsize=(30,30),layout=(4,4),legend=False)
# Out:
# array([[<AxesSubplot:ylabel='2019-10'>, <AxesSubplot:ylabel='2019-11'>,
#         <AxesSubplot:ylabel='2019-12'>, <AxesSubplot:ylabel='2020-01'>],
#        [<AxesSubplot:ylabel='2020-02'>, <AxesSubplot:ylabel='2020-03'>,
#         <AxesSubplot:ylabel='2020-04'>, <AxesSubplot:ylabel='2020-05'>],
#        [<AxesSubplot:ylabel='2020-06'>, <AxesSubplot:ylabel='2020-07'>,
#         <AxesSubplot:ylabel='2020-08'>, <AxesSubplot:ylabel='2020-09'>],
#        [<AxesSubplot:ylabel='2020-10'>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ### boxplot

# %% [markdown]
# `-` plotly, matplotlib 백엔드 모두 지원

# %% [markdown]
# #### 예제1 (matplotlib)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/kalilurrahman/datasets/main/mobilephonemktshare2020.csv') 
df
# Out:
#        Date  Samsung  Apple  Huawei  Xiaomi  Oppo  Mobicel  Motorola    LG  \
# 0   2019-10    31.49  22.09   10.02    7.79  4.10     3.15      2.41  2.40
# 1   2019-11    31.36  22.90   10.18    8.16  4.42     3.41      2.40  2.40
# 2   2019-12    31.37  24.79    9.95    7.73  4.23     3.19      2.50  2.54
# 3   2020-01    31.29  24.76   10.61    8.10  4.25     3.02      2.42  2.40
# 4   2020-02    30.91  25.89   10.98    7.80  4.31     2.89      2.36  2.34
# 5   2020-03    30.80  27.03   10.70    7.70  4.30     2.87      2.35  2.28
# 6   2020-04    30.41  28.79   10.28    7.60  4.20     2.75      2.51  2.28
# 7   2020-05    30.18  26.72   10.39    8.36  4.70     3.12      2.46  2.19
# 8   2020-06    31.06  25.26   10.69    8.55  4.65     3.18      2.57  2.11
# 9   2020-07    30.95  24.82   10.75    8.94  4.69     3.46      2.45  2.03
# 10  2020-08    31.04  25.15   10.73    8.90  4.69     3.38      2.39  1.96
# ...

# %% [markdown]
# `-` 시계열 자료의 차분

# %%
df.set_index('Date').diff()
# Out:
#          Samsung  Apple  Huawei  Xiaomi  Oppo  Mobicel  Motorola    LG  \
# Date
# 2019-10      NaN    NaN     NaN     NaN   NaN      NaN       NaN   NaN
# 2019-11    -0.13   0.81    0.16    0.37  0.32     0.26     -0.01  0.00
# 2019-12     0.01   1.89   -0.23   -0.43 -0.19    -0.22      0.10  0.14
# 2020-01    -0.08  -0.03    0.66    0.37  0.02    -0.17     -0.08 -0.14
# 2020-02    -0.38   1.13    0.37   -0.30  0.06    -0.13     -0.06 -0.06
# 2020-03    -0.11   1.14   -0.28   -0.10 -0.01    -0.02     -0.01 -0.06
# 2020-04    -0.39   1.76   -0.42   -0.10 -0.10    -0.12      0.16  0.00
# 2020-05    -0.23  -2.07    0.11    0.76  0.50     0.37     -0.05 -0.09
# 2020-06     0.88  -1.46    0.30    0.19 -0.05     0.06      0.11 -0.08
# 2020-07    -0.11  -0.44    0.06    0.39  0.04     0.28     -0.12 -0.08
# 2020-08     0.09   0.33   -0.02   -0.04  0.00    -0.08     -0.06 -0.07
# 2020-09    -0.47  -0.17   -0.15    0.59  0.25     0.12     -0.12 -0.08
# ...

# %% [markdown]
# `-` 차분의 박스플랏

# %%
df.set_index('Date').diff().dropna().boxplot(figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# `-` 전월대비 몇프로 오르고 내렸는지 계산

# %%
df.set_index('Date').pct_change()
# Out:
#           Samsung     Apple    Huawei    Xiaomi      Oppo   Mobicel  Motorola  \
# Date
# 2019-10       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-11 -0.004128  0.036668  0.015968  0.047497  0.078049  0.082540 -0.004149
# 2019-12  0.000319  0.082533 -0.022593 -0.052696 -0.042986 -0.064516  0.041667
# 2020-01 -0.002550 -0.001210  0.066332  0.047865  0.004728 -0.053292 -0.032000
# 2020-02 -0.012144  0.045638  0.034873 -0.037037  0.014118 -0.043046 -0.024793
# 2020-03 -0.003559  0.044032 -0.025501 -0.012821 -0.002320 -0.006920 -0.004237
# 2020-04 -0.012662  0.065113 -0.039252 -0.012987 -0.023256 -0.041812  0.068085
# 2020-05 -0.007563 -0.071900  0.010700  0.100000  0.119048  0.134545 -0.019920
# 2020-06  0.029158 -0.054641  0.028874  0.022727 -0.010638  0.019231  0.044715
# 2020-07 -0.003542 -0.017419  0.005613  0.045614  0.008602  0.088050 -0.046693
# 2020-08  0.002908  0.013296 -0.001860 -0.004474  0.000000 -0.023121 -0.024490
# ...

# %% [markdown]
# `-` 박스플랏

# %%
df.set_index('Date').pct_change().dropna().plot.box(figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 예제1 (plotly)

# %% [markdown]
# `-` plotly로 tidy하지 않은 자료를 그릴수 있음

# %%
df.set_index('Date').pct_change().dropna()
# Out:
#           Samsung     Apple    Huawei    Xiaomi      Oppo   Mobicel  Motorola  \
# Date
# 2019-11 -0.004128  0.036668  0.015968  0.047497  0.078049  0.082540 -0.004149
# 2019-12  0.000319  0.082533 -0.022593 -0.052696 -0.042986 -0.064516  0.041667
# 2020-01 -0.002550 -0.001210  0.066332  0.047865  0.004728 -0.053292 -0.032000
# 2020-02 -0.012144  0.045638  0.034873 -0.037037  0.014118 -0.043046 -0.024793
# 2020-03 -0.003559  0.044032 -0.025501 -0.012821 -0.002320 -0.006920 -0.004237
# 2020-04 -0.012662  0.065113 -0.039252 -0.012987 -0.023256 -0.041812  0.068085
# 2020-05 -0.007563 -0.071900  0.010700  0.100000  0.119048  0.134545 -0.019920
# 2020-06  0.029158 -0.054641  0.028874  0.022727 -0.010638  0.019231  0.044715
# 2020-07 -0.003542 -0.017419  0.005613  0.045614  0.008602  0.088050 -0.046693
# 2020-08  0.002908  0.013296 -0.001860 -0.004474  0.000000 -0.023121 -0.024490
# 2020-09 -0.015142 -0.006759 -0.013979  0.066292  0.053305  0.035503 -0.050209
# ...

# %%
fig = df.set_index('Date').pct_change().dropna().plot.box(backend='plotly')
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - plotly가 약간 융통성있는 편임

# %% [markdown]
# `-` 회사를 색깔별로 구분하여 범주를 만들고 싶다면 여전히 tidydata를 활용해야함

# %%
df.set_index('Date').pct_change().dropna().melt()
# Out:
#     variable     value
# 0    Samsung -0.004128
# 1    Samsung  0.000319
# 2    Samsung -0.002550
# 3    Samsung -0.012144
# 4    Samsung -0.003559
# ..       ...       ...
# 187     Asus -0.013158
# 188     Asus -0.040000
# 189     Asus -0.027778
# 190     Asus -0.042857
# 191     Asus -0.044776
#
# [192 rows x 2 columns]

# %%
fig = df.set_index('Date').pct_change().dropna().melt().plot.box(x='variable',y='value',color='variable',backend='plotly')
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 범주 만들면 머가 좋냐고요? 범주를 클릭해보세요!!

# %%
df.set_index('Date').pct_change().dropna().melt().plot.box(x='variable',y='value',color='variable')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-2dbd94b8c868> in <module>
# ----> 1 df.set_index('Date').pct_change().dropna().melt().plot.box(x='variable',y='value',color='variable')
#
# ~/anaconda3/envs/py39r41/lib/python3.9/site-packages/pandas/plotting/_core.py in box(self, by, **kwargs)
#    1264             >>> ax = df.plot.box()
#    1265         """
# -> 1266         return self(kind="box", by=by, **kwargs)
#    1267
#    1268     def hist(self, by=None, bins=10, **kwargs):
#
# ~/anaconda3/envs/py39r41/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ...

# %% [markdown]
# - 똑같은 코드가 matplotlib에서 돌아가는건 아님. matplotlib 백엔드는 타이디자료를 처리하지 않음

# %% [markdown]
# #### 예제2 (plotly)

# %% [markdown]
# `-` wide form 으로 정리가 불가능한 자료

# %%
import plotly.express as px
df = px.data.tips()
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# - 성별, 식사금액, 금연여부, 요일, 점심/저녁에 따른 팁

# %% [markdown]
# `-` 팁은 대체로 어느정도씩 받는지?

# %%
fig = df.plot.box(y='total_bill',backend='plotly',height=500,width=500)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# `-` 점심/저녁에 따라 팁의 분포가 다를까?

# %%
fig = df.plot.box(x='time',y='total_bill',backend='plotly',height=500,width=500)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 저녁에 좀더 중앙값과 레인지가 커요

# %% [markdown]
# `-` 성별에 따라서도 팁을 주는것이 다를까?

# %%
fig = df.plot.box(x='time',y='total_bill',color='sex',backend='plotly',height=500,width=500)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# `-` 분포를 같이보는 기법

# %%
fig = df.plot.box(x='time',y='total_bill',color='sex',backend='plotly',height=500,width=500,points='all')
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - boxplot에서의 아웃라이어는 사라짐

# %% [markdown]
# `-` 요일에 따라서도 다를까?

# %%
fig = df.plot.box(x='time',y='total_bill',color='sex',backend='plotly',height=500,width=1000,points='all',facet_col='day',facet_row='smoker')
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - tidydata로 한번만들어 두니까 너무너무 쉽게 생각하는대로 구현가능

# %% [markdown]
# `-` tidydata의 위력: 위와 같은 자료를 matplotlib backend로는 위의 그림을 그리는것 자체가! 불가능함

# %%
df.plot.box(y='total_bill')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - `df.plot.box(x='time',y='total_bill',backend='plotly',height=500,width=500)` 와 같은 그림은 그릴 수 없다. (자료를 wide form으로 나타낼 수 없기 때문)

# %% [markdown]
# ### hist, kde, density

# %% [markdown]
# #### 예제1 (matplotlib)

# %% [markdown]
# `-` 시뮬레이션 예제: 정규분포를 만들어서 제곱한뒤에 3개씩,4개씩,...,10개씩 더함 $\to$ 카이제곱분포

# %% [markdown]
# `-` 일단3개부터 시작해보자.

# %%
X=np.random.normal(size=(1000,3),loc=0,scale=1)
X
# Out:
# array([[-1.63653253, -0.65625481,  1.11236588],
#        [ 0.46460242,  0.11688344,  0.36095441],
#        [ 1.48887296,  0.52955171,  0.30344685],
#        ...,
#        [ 0.97363802, -0.98445539, -0.81037974],
#        [-0.62923164, -1.22343611,  1.38135751],
#        [-0.71047452, -0.94117692, -0.05067565]])

# %%
X**2
# Out:
# array([[2.67823871e+00, 4.30670377e-01, 1.23735786e+00],
#        [2.15855411e-01, 1.36617384e-02, 1.30288089e-01],
#        [2.21674270e+00, 2.80425012e-01, 9.20799912e-02],
#        ...,
#        [9.47971001e-01, 9.69152421e-01, 6.56715324e-01],
#        [3.95932460e-01, 1.49679590e+00, 1.90814858e+00],
#        [5.04774046e-01, 8.85814002e-01, 2.56802124e-03]])

# %%
(X**2).sum()
# Out:
# 3092.3384415386936

# %%
8.87295628e-01+1.80485800e+00+2.54597648e+00
# Out:
# 5.238130108

# %%
(X**2).sum(axis=1)
# Out:
# array([ 4.34626695,  0.35980524,  2.5892477 , 10.59658533,  3.14096958,
#         1.99644125,  1.77481282,  1.11092633,  0.57401241,  1.29859831,
#         0.70512108,  1.04202886,  5.0778072 ,  0.83414918,  2.96700958,
#         2.73542394,  1.67982818,  2.23269106,  0.90577089,  2.46638624,
#        11.38735841,  1.03122889,  9.58376022,  4.85812232,  5.24480749,
#         2.75376911,  3.704829  ,  7.59774178,  5.04027437,  0.14418786,
#         4.55858444,  5.76834991,  8.33448707,  4.5117772 , 14.89328223,
#         1.59825866,  2.13095817,  5.50631514,  5.70066624,  2.14673194,
#         0.32190034,  0.15104072,  2.29558578,  0.64577246,  9.856246  ,
#         1.35437512,  1.80011385,  5.33814845,  1.00354255,  2.07268496,
#         3.90551004,  0.85212066,  1.76693637,  5.65488929,  1.23166677,
#         7.08031568,  1.12706414,  1.67074656,  1.92684182,  0.84178262,
#         1.15186971,  1.28255058,  5.99615369,  1.46291864,  3.12078158,
# ...

# %% [markdown]
# `-` 요약하면

# %%
(np.random.normal(size=(1000,3),loc=0,scale=1)**2).sum(axis=1)
# Out:
# array([ 2.07322248,  0.94564855,  1.98450007,  2.80105385,  1.03054882,
#         5.61786151,  2.48114824,  3.42896406,  1.78389586,  4.71850582,
#         1.68910349,  0.40907173,  1.83169356,  3.36003086,  3.79505029,
#         6.61942992,  2.71013163,  3.64187573,  4.00659765,  1.27213329,
#         2.0720972 ,  1.76296195,  1.36574843,  4.37707025,  1.48939982,
#         2.5833341 ,  1.42002321,  4.2659001 ,  0.65769875,  0.56826075,
#         4.16834499,  1.79268805,  8.58669252,  0.40825868,  5.19396191,
#         6.99268109,  1.35826753,  1.1689369 ,  0.98193482, 10.3418492 ,
#         1.14706172,  0.81618676,  1.10799847,  2.30755461,  0.67674757,
#         0.81914865,  7.9038104 ,  0.41522433,  5.22992959,  1.45595223,
#         2.64924596,  0.15819364, 10.77695768,  1.96805932,  3.6457421 ,
#         0.0503483 ,  0.53433246,  2.61576616,  2.1185257 ,  2.29653056,
#         6.52442548,  3.36478206,  2.3195743 ,  1.15813029,  9.34955452,
# ...

# %% [markdown]
# `-` 정리하면

# %% [markdown]
# ```python
# i = 0 부터 range(len(_arr))
# _arr = [3,4,5,6,7,8,9,10]
# (np.random.normal(size=(1000,_arr[i]),loc=0,scale=1)**2).sum(axis=1)
# ```

# %% [markdown]
# 이런모양으로 만들면 된다.

# %%
_arr = [3,4,5,6,7,8,9,10]

# %%
df=pd.DataFrame([(np.random.normal(size=(1000,_arr[i]),loc=0,scale=1)**2).sum(axis=1) for i in range(len(_arr))]).T
df
# Out:
#             0         1         2          3         4          5          6  \
# 0    8.949678  3.002342  6.187975   9.474935  0.913186   9.097366   8.260158
# 1    0.619267  5.524355  5.517155   5.434355  5.276852   2.637997  10.833930
# 2    1.332302  4.539894  3.786024   3.656804  6.539706   6.431715  10.822569
# 3    0.606461  3.805059  5.228360  18.135776  8.957762   5.866802   3.316292
# 4    2.832875  1.410567  4.696151  10.881347  5.365004  15.037858   7.564235
# ..        ...       ...       ...        ...       ...        ...        ...
# 995  0.267954  2.503159  6.761257  12.053076  9.050944  11.460281   5.369423
# 996  3.696410  2.989597  6.274945   5.757931  6.257299  12.151118   8.863375
# 997  0.863954  3.807895  2.722971   9.568143  5.890769   3.018592  24.156562
# 998  3.325009  1.799675  2.331538   8.612413  6.514026   9.724632  10.250660
# 999  2.958120  0.686899  2.615888   8.578522  5.189941   3.051065   8.470776
#
#              7
# 0    10.263511
# ...

# %% [markdown]
# - 첫번째 컬럼은 정규분포를 제곱하여 3개씩 더하여 나온값이고, 두번째 칼럼은 정규분포를 제곱하여 4개씩 더해서 나온값임 $\to$ 열의 이름을 지어주자.

# %%
df.columns = _arr

# %%
df
# Out:
#            3         4         5          6         7          8          9   \
# 0    8.949678  3.002342  6.187975   9.474935  0.913186   9.097366   8.260158
# 1    0.619267  5.524355  5.517155   5.434355  5.276852   2.637997  10.833930
# 2    1.332302  4.539894  3.786024   3.656804  6.539706   6.431715  10.822569
# 3    0.606461  3.805059  5.228360  18.135776  8.957762   5.866802   3.316292
# 4    2.832875  1.410567  4.696151  10.881347  5.365004  15.037858   7.564235
# ..        ...       ...       ...        ...       ...        ...        ...
# 995  0.267954  2.503159  6.761257  12.053076  9.050944  11.460281   5.369423
# 996  3.696410  2.989597  6.274945   5.757931  6.257299  12.151118   8.863375
# 997  0.863954  3.807895  2.722971   9.568143  5.890769   3.018592  24.156562
# 998  3.325009  1.799675  2.331538   8.612413  6.514026   9.724632  10.250660
# 999  2.958120  0.686899  2.615888   8.578522  5.189941   3.051065   8.470776
#
#             10
# 0    10.263511
# ...

# %% [markdown]
# `-` 분포를 그려보자.

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# - 알수가없다..

# %% [markdown]
# `-` bins와 투명도 조절

# %%
df.plot.hist(bins=50,alpha=0.2)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# - 조금 나아지긴했으나..

# %% [markdown]
# `-` 서브플랏

# %%
df.plot.hist(bins=50,subplots=True,layout=(2,4),figsize=(12,5),alpha=0.5)
plt.tight_layout()

# %% [markdown]
# - 많이 더할수록 비대칭성이 완화되고 종모양에 가까워지는것 같다?

# %% [markdown]
# `-` kde 플랏

# %%
df.plot.kde(subplots=True,layout=(2,4),figsize=(12,5))
plt.tight_layout()

# %% [markdown]
# `-` bw_method를 조정하면?

# %%
df.plot.kde(subplots=True,layout=(2,4),bw_method=0.05,figsize=(12,5))
plt.tight_layout()

# %%
df.plot.kde(subplots=True,bw_method=5,layout=(2,4),figsize=(12,5))
plt.tight_layout()

# %% [markdown]
# - bw_method를 크게할수록 극단적으로 스무딩한다.

# %% [markdown]
# `-` 점선으로 그리고싶다면?

# %%
df.plot.density(subplots=True,bw_method=2,layout=(2,4),figsize=(12,5),ls='--')
plt.tight_layout()

# %% [markdown]
# #### 예제2 (plotly)

# %% [markdown]
# `-` 다시 tips예제로 돌아오자.

# %%
df = px.data.tips()
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# `-` 성별에 따라서 팁을 주는게다른지? (박스플랏대신에 히스토그램그램을 그려도 분포를 잘 볼 수 있다.)

# %%
fig = df.plot.hist(x='total_bill',backend='plotly',color='sex',facet_col='sex',width=1000,height=600)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 빈도 자체도 보여서 (남성이 더 횟수자체가 많음) 더 유익한플랏

# %% [markdown]
# `-` 시간에 따라서도 다른지?

# %%
fig = df.plot.hist(x='total_bill',backend='plotly',facet_row='sex',facet_col='time',color='sex',width=1000,height=600)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - tidydata가 확실히 한번 만들어두면 그리기 편리함

# %% [markdown]
# ### area

# %% [markdown]
# `-` 주류플랏은 아님

# %% [markdown]
# `-` 그래도 그려달라는 사람이 있었음

# %% [markdown]
# #### 예제1 (matplotlib)

# %% [markdown]
# `-` 다시 핸드폰예제

# %%
df = pd.read_csv('https://raw.githubusercontent.com/kalilurrahman/datasets/main/mobilephonemktshare2020.csv') 
df
# Out:
#        Date  Samsung  Apple  Huawei  Xiaomi  Oppo  Mobicel  Motorola    LG  \
# 0   2019-10    31.49  22.09   10.02    7.79  4.10     3.15      2.41  2.40
# 1   2019-11    31.36  22.90   10.18    8.16  4.42     3.41      2.40  2.40
# 2   2019-12    31.37  24.79    9.95    7.73  4.23     3.19      2.50  2.54
# 3   2020-01    31.29  24.76   10.61    8.10  4.25     3.02      2.42  2.40
# 4   2020-02    30.91  25.89   10.98    7.80  4.31     2.89      2.36  2.34
# 5   2020-03    30.80  27.03   10.70    7.70  4.30     2.87      2.35  2.28
# 6   2020-04    30.41  28.79   10.28    7.60  4.20     2.75      2.51  2.28
# 7   2020-05    30.18  26.72   10.39    8.36  4.70     3.12      2.46  2.19
# 8   2020-06    31.06  25.26   10.69    8.55  4.65     3.18      2.57  2.11
# 9   2020-07    30.95  24.82   10.75    8.94  4.69     3.46      2.45  2.03
# 10  2020-08    31.04  25.15   10.73    8.90  4.69     3.38      2.39  1.96
# ...

# %% [markdown]
# `-` 점유율을 에어리어 플랏으로

# %%
df.plot.area(x='Date',figsize=(20,10),alpha=0.6)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# - stacked version의 박스플랏보다는 좋은것 같다.

# %% [markdown]
# #### 예제1 (plotly)

# %% [markdown]
# `-` plotly를 쓰기 위해서 tidydata로 바꾸자.

# %%
df.melt(id_vars='Date')
# Out:
#         Date variable  value
# 0    2019-10  Samsung  31.49
# 1    2019-11  Samsung  31.36
# 2    2019-12  Samsung  31.37
# 3    2020-01  Samsung  31.29
# 4    2020-02  Samsung  30.91
# ..       ...      ...    ...
# 203  2020-06     Asus   0.75
# 204  2020-07     Asus   0.72
# 205  2020-08     Asus   0.70
# 206  2020-09     Asus   0.67
# 207  2020-10     Asus   0.64
#
# [208 rows x 3 columns]

# %%
fig= df.melt(id_vars='Date').plot.area(x='Date',y='value',color='variable',backend='plotly',width=600,height=500)
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 사실 범주클릭기능이 진짜 좋아요
# - 내가 시각화를 잘하는 이유:
#     - 먹고살기 위해서 외웠어요.
#     - 발표를 위해서 시각화하여 슬라이드로 발표했는데 발표자료에 없는 시각화를 요구할때가 많았음.
#     - 예를들어 2020년에 무슨 삼성에서 신제품이 나왔다면 그때 이전과 이후로 나누어서 점유율을 시각화 해달라든지?
#     - --> 빨리그려줘야했는데 tidydata / untidydata 를 모두 잘쓰고 (대부분 이 개념조차 없음) 데이터프레임을 빨리 변형할 수 있는 사람이 없었음
#     - --> 저도 잘 못했는데 배웠어요 (항상외우고다니진 않음 발표전에만 몇개 연습해보면서 외움)
#     - --> 젤 큰 무기는 판다스 백엔드 + 플롯틀리 + 지지플랏
# - 시각화 잘하면 예쁨받음
#     - 순간적으로 빠르게 그리는게 생각보다 쉽지 않음
#     - 시각화는 분석의 주인공보다 서포트하는 역할.
#     - 처음에 갑자기 분석의 주인공이 되는게 좀 부담스러웠음.
#     - 시각화를 잘하면 여기저기서 인기 많았음

# %% [markdown]
# #### 예제2 (matplotlib)

# %% [markdown]
# `-` 위키의 테이블 크롤링. 검색어 "대한민국의 인구수"

# %%
df=pd.read_html('https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EC%9D%B8%EA%B5%AC')[19]
df
# Out:
#       행정구역별 2021. 06           2015           2010           2005           \
#       행정구역별       비율       인구    비율       인구    비율       인구    비율       인구
# 0        전국     16.7  8652198  13.1  6775101  10.9  5506352   8.9  4324524
# 1     서울특별시     16.4  1568769  12.6  1262436   9.7  1002770   7.2   731349
# 2     부산광역시     19.8   666644  14.6   514630  11.3   401784   8.3   302784
# 3     대구광역시     17.0   408235  12.7   316122  10.0   252084   7.8   195419
# 4     인천광역시     14.4   422658  10.7   312905   8.6   237805   6.9   178602
# 5     광주광역시     14.5   208879  11.3   166389   9.0   130457   7.1    99389
# 6     대전광역시     14.8   215997  10.9   165528   8.7   130245   6.9    99811
# 7     울산광역시     13.1   147811   8.8   103205   6.8    76800   5.3    57797
# 8   세종특별자치시     10.0    36194  10.6    22399     -        -     -        -
# 9       경기도     13.5  1825846  10.5  1318882   8.7  1022456   7.1   755511
# ...

# %% [markdown]
# - 페이지에서 19번째 테이블
# - 끔직할 정도로 타이디하지 않은 자료

# %% [markdown]
# `-` 첫번째 row는 일단 제외해야겠음

# %%
df.iloc[1:]
# Out:
#       행정구역별 2021. 06           2015           2010           2005          \
#       행정구역별       비율       인구    비율       인구    비율       인구    비율      인구
# 1     서울특별시     16.4  1568769  12.6  1262436   9.7  1002770   7.2  731349
# 2     부산광역시     19.8   666644  14.6   514630  11.3   401784   8.3  302784
# 3     대구광역시     17.0   408235  12.7   316122  10.0   252084   7.8  195419
# 4     인천광역시     14.4   422658  10.7   312905   8.6   237805   6.9  178602
# 5     광주광역시     14.5   208879  11.3   166389   9.0   130457   7.1   99389
# 6     대전광역시     14.8   215997  10.9   165528   8.7   130245   6.9   99811
# 7     울산광역시     13.1   147811   8.8   103205   6.8    76800   5.3   57797
# 8   세종특별자치시     10.0    36194  10.6    22399     -        -     -       -
# 9       경기도     13.5  1825846  10.5  1318882   8.7  1022456   7.1  755511
# 10      강원도     21.2   325579  16.9   261671  14.8   226505  12.1  183471
# 11     충청북도     18.4   294530  14.8   234813  13.2   204470  11.3  168670
# ...

# %% [markdown]
# `-` 일단 스택을 해보자.

# %%
df.iloc[1:].stack()
# Out:
#             2000    2005     2010       2015   2021. 06    행정구역별
# 1  비율        5.4     7.2      9.7       12.6       16.4      NaN
#    인구     558566  731349  1002770  1262436.0  1568769.0      NaN
#    행정구역별     NaN     NaN      NaN        NaN        NaN    서울특별시
# 2  비율        6.0     8.3     11.3       14.6       19.8      NaN
#    인구     229075  302784   401784   514630.0   666644.0      NaN
#    행정구역별     NaN     NaN      NaN        NaN        NaN    부산광역시
# 3  비율        5.9     7.8     10.0       12.7       17.0      NaN
#    인구     149045  195419   252084   316122.0   408235.0      NaN
#    행정구역별     NaN     NaN      NaN        NaN        NaN    대구광역시
# 4  비율        5.4     6.9      8.6       10.7       14.4      NaN
#    인구     138316  178602   237805   312905.0   422658.0      NaN
#    행정구역별     NaN     NaN      NaN        NaN        NaN    인천광역시
# 5  비율        5.6     7.1      9.0       11.3       14.5      NaN
# ...

# %% [markdown]
# - 엉망임

# %% [markdown]
# `-` 인덱스를 설정하고 스택하자.

# %%
df.iloc[1:]
# Out:
#       행정구역별 2021. 06           2015           2010           2005          \
#       행정구역별       비율       인구    비율       인구    비율       인구    비율      인구
# 1     서울특별시     16.4  1568769  12.6  1262436   9.7  1002770   7.2  731349
# 2     부산광역시     19.8   666644  14.6   514630  11.3   401784   8.3  302784
# 3     대구광역시     17.0   408235  12.7   316122  10.0   252084   7.8  195419
# 4     인천광역시     14.4   422658  10.7   312905   8.6   237805   6.9  178602
# 5     광주광역시     14.5   208879  11.3   166389   9.0   130457   7.1   99389
# 6     대전광역시     14.8   215997  10.9   165528   8.7   130245   6.9   99811
# 7     울산광역시     13.1   147811   8.8   103205   6.8    76800   5.3   57797
# 8   세종특별자치시     10.0    36194  10.6    22399     -        -     -       -
# 9       경기도     13.5  1825846  10.5  1318882   8.7  1022456   7.1  755511
# 10      강원도     21.2   325579  16.9   261671  14.8   226505  12.1  183471
# 11     충청북도     18.4   294530  14.8   234813  13.2   204470  11.3  168670
# ...

# %% [markdown]
# - 서울특별시~제주특별자치도를 인덱스로해야겠음 $\to$ 칼럼이름이 뭐지?

# %%
df.iloc[1:].columns
# Out:
# MultiIndex([(   '행정구역별', '행정구역별'),
#             ('2021. 06',    '비율'),
#             ('2021. 06',    '인구'),
#             (    '2015',    '비율'),
#             (    '2015',    '인구'),
#             (    '2010',    '비율'),
#             (    '2010',    '인구'),
#             (    '2005',    '비율'),
#             (    '2005',    '인구'),
#             (    '2000',    '비율'),
#             (    '2000',    '인구')],
#            )

# %% [markdown]
# - 칼럼이 멀티인덱스로 되어있음

# %% [markdown]
# `-` 아래와 같이 첫번째 칼럼에 접근가능

# %%
df.iloc[1:].loc[:,('행정구역별','행정구역별')]
# Out:
# 1       서울특별시
# 2       부산광역시
# 3       대구광역시
# 4       인천광역시
# 5       광주광역시
# 6       대전광역시
# 7       울산광역시
# 8     세종특별자치시
# 9         경기도
# 10        강원도
# 11       충청북도
# 12       충청남도
# 13       전라북도
# 14       전라남도
# 15       경상북도
# 16       경상남도
# 17    제주특별자치도
# Name: (행정구역별, 행정구역별), dtype: object

# %% [markdown]
# `-` 저걸 인덱스로 하고 다시 스택해보자.

# %%
df.iloc[1:].set_index(('행정구역별','행정구역별')).stack()
# Out:
#                      2000    2005     2010       2015   2021. 06
# (행정구역별, 행정구역별)
# 서울특별시          비율     5.4     7.2      9.7       12.6       16.4
#                인구  558566  731349  1002770  1262436.0  1568769.0
# 부산광역시          비율     6.0     8.3     11.3       14.6       19.8
#                인구  229075  302784   401784   514630.0   666644.0
# 대구광역시          비율     5.9     7.8     10.0       12.7       17.0
#                인구  149045  195419   252084   316122.0   408235.0
# 인천광역시          비율     5.4     6.9      8.6       10.7       14.4
#                인구  138316  178602   237805   312905.0   422658.0
# 광주광역시          비율     5.6     7.1      9.0       11.3       14.5
#                인구   77325   99389   130457   166389.0   208879.0
# 대전광역시          비율     5.5     6.9      8.7       10.9       14.8
#                인구   75769   99811   130245   165528.0   215997.0
# 울산광역시          비율     4.0     5.3      6.8        8.8       13.1
# ...

# %% [markdown]
# - 나쁘진않음

# %% [markdown]
# `-` 멀티인덱스 제거

# %%
df.iloc[1:].set_index(('행정구역별','행정구역별')).stack().reset_index()
# Out:
#    (행정구역별, 행정구역별) level_1    2000    2005     2010       2015   2021. 06
# 0           서울특별시      비율     5.4     7.2      9.7       12.6       16.4
# 1           서울특별시      인구  558566  731349  1002770  1262436.0  1568769.0
# 2           부산광역시      비율     6.0     8.3     11.3       14.6       19.8
# 3           부산광역시      인구  229075  302784   401784   514630.0   666644.0
# 4           대구광역시      비율     5.9     7.8     10.0       12.7       17.0
# 5           대구광역시      인구  149045  195419   252084   316122.0   408235.0
# 6           인천광역시      비율     5.4     6.9      8.6       10.7       14.4
# 7           인천광역시      인구  138316  178602   237805   312905.0   422658.0
# 8           광주광역시      비율     5.6     7.1      9.0       11.3       14.5
# 9           광주광역시      인구   77325   99389   130457   166389.0   208879.0
# 10          대전광역시      비율     5.5     6.9      8.7       10.9       14.8
# 11          대전광역시      인구   75769   99811   130245   165528.0   215997.0
# ...

# %% [markdown]
# `-` 일단 비율만 선택

# %%
df.iloc[1:].set_index(('행정구역별','행정구역별')).stack().reset_index().query("level_1 == '비율'")
# Out:
#    (행정구역별, 행정구역별) level_1  2000  2005  2010  2015  2021. 06
# 0           서울특별시      비율   5.4   7.2   9.7  12.6      16.4
# 2           부산광역시      비율   6.0   8.3  11.3  14.6      19.8
# 4           대구광역시      비율   5.9   7.8  10.0  12.7      17.0
# 6           인천광역시      비율   5.4   6.9   8.6  10.7      14.4
# 8           광주광역시      비율   5.6   7.1   9.0  11.3      14.5
# 10          대전광역시      비율   5.5   6.9   8.7  10.9      14.8
# 12          울산광역시      비율   4.0   5.3   6.8   8.8      13.1
# 14        세종특별자치시      비율     -     -     -  10.6      10.0
# 16            경기도      비율   5.7   7.1   8.7  10.5      13.5
# 18            강원도      비율   9.3  12.1  14.8  16.9      21.2
# 20           충청북도      비율   9.1  11.3  13.2  14.8      18.4
# 22           충청남도      비율  11.2  13.3  14.9  16.4      19.5
# 24           전라북도      비율  10.3  12.9  15.2  17.8      21.8
# 26           전라남도      비율  11.9  15.6  18.3  20.5      23.9
# 28           경상북도      비율  10.7  13.4  15.6  17.7      22.2
# ...

# %% [markdown]
# `-` 와이드형으로 자료를 정리하자. (matplotlib 백엔드로 area 그릴것임) $\to$ 서울~제주 가 컬럼이름으로 와야겠음

# %%
df.iloc[1:].set_index(('행정구역별','행정구역별')).stack().reset_index().query("level_1 == '비율'").set_index(('행정구역별','행정구역별')).iloc[:,1:].T
# Out:
# ('행정구역별', '행정구역별') 서울특별시 부산광역시 대구광역시 인천광역시 광주광역시 대전광역시 울산광역시 세종특별자치시   경기도  \
# 2000                 5.4   6.0   5.9   5.4   5.6   5.5   4.0       -   5.7
# 2005                 7.2   8.3   7.8   6.9   7.1   6.9   5.3       -   7.1
# 2010                 9.7  11.3  10.0   8.6   9.0   8.7   6.8       -   8.7
# 2015                12.6  14.6  12.7  10.7  11.3  10.9   8.8    10.6  10.5
# 2021. 06            16.4  19.8  17.0  14.4  14.5  14.8  13.1    10.0  13.5
#
# ('행정구역별', '행정구역별')   강원도  충청북도  충청남도  전라북도  전라남도  경상북도  경상남도 제주특별자치도
# 2000                 9.3   9.1  11.2  10.3  11.9  10.7   8.4     8.0
# 2005                12.1  11.3  13.3  12.9  15.6  13.4  10.2    10.0
# 2010                14.8  13.2  14.9  15.2  18.3  15.6  11.8    12.2
# 2015                16.9  14.8  16.4  17.8  20.5  17.7  13.8    13.8
# 2021. 06            21.2  18.4  19.5  21.8  23.9  22.2  17.9    16.0

# %% [markdown]
# `-` 세종시에 - 이 있다? .. 자료형이 이상할것임

# %%
df.iloc[1:].set_index(('행정구역별','행정구역별')).stack().reset_index().query("level_1 == '비율'").set_index(('행정구역별','행정구역별')).iloc[:,1:].T.iloc[0,0]
# Out:
# '5.4'

# %% [markdown]
# - 문자형..

# %% [markdown]
# `-` 데이터프레임에 모든 원소에 변환을 수행하자. (applymap)
# - 문자형을 숫자형으로 바꿔라
# - 그런데 문자가 - 라면 None으로 바꿔라

# %% [markdown]
# (예비학습)

# %%
x=[1,2,None,3,4]
plt.plot(x,'o--')

# %% [markdown]
# (예비학습끝)

# %%
df.iloc[1:].set_index(('행정구역별','행정구역별')).stack().reset_index().query("level_1 == '비율'").set_index(('행정구역별','행정구역별')).iloc[:,1:].T.\
applymap(lambda x: float(x) if x!='-' else None)
# Out:
# ('행정구역별', '행정구역별')  서울특별시  부산광역시  대구광역시  인천광역시  광주광역시  대전광역시  울산광역시  세종특별자치시  \
# 2000                  5.4    6.0    5.9    5.4    5.6    5.5    4.0      NaN
# 2005                  7.2    8.3    7.8    6.9    7.1    6.9    5.3      NaN
# 2010                  9.7   11.3   10.0    8.6    9.0    8.7    6.8      NaN
# 2015                 12.6   14.6   12.7   10.7   11.3   10.9    8.8     10.6
# 2021. 06             16.4   19.8   17.0   14.4   14.5   14.8   13.1     10.0
#
# ('행정구역별', '행정구역별')   경기도   강원도  충청북도  충청남도  전라북도  전라남도  경상북도  경상남도  제주특별자치도
# 2000                 5.7   9.3   9.1  11.2  10.3  11.9  10.7   8.4      8.0
# 2005                 7.1  12.1  11.3  13.3  12.9  15.6  13.4  10.2     10.0
# 2010                 8.7  14.8  13.2  14.9  15.2  18.3  15.6  11.8     12.2
# 2015                10.5  16.9  14.8  16.4  17.8  20.5  17.7  13.8     13.8
# 2021. 06            13.5  21.2  18.4  19.5  21.8  23.9  22.2  17.9     16.0

# %% [markdown]
# 이제 그리자..

# %%
warnings.filterwarnings("ignore")
df.iloc[1:].set_index(('행정구역별','행정구역별')).stack().reset_index().query("level_1 == '비율'").set_index(('행정구역별','행정구역별')).iloc[:,1:].T.\
applymap(lambda x: float(x) if x!='-' else None).\
plot.area(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 한글이 깨져서 나온다 $\to$ 고치는 방법이 있긴한데 그냥 포기함.

# %% [markdown]
# #### 예제2 (plotly)

# %% [markdown]
# `-` plotly로 그려보자. 우선 타이디한 자료까지 만들자.

# %%
df.iloc[1:].set_index(('행정구역별','행정구역별')).stack().applymap(lambda x: float(x) if x!='-' else None).stack().reset_index()
# Out:
#     (행정구역별, 행정구역별) level_1   level_2         0
# 0            서울특별시      비율      2000       5.4
# 1            서울특별시      비율      2005       7.2
# 2            서울특별시      비율      2010       9.7
# 3            서울특별시      비율      2015      12.6
# 4            서울특별시      비율  2021. 06      16.4
# ..             ...     ...       ...       ...
# 159        제주특별자치도      인구      2000   43334.0
# 160        제주특별자치도      인구      2005   55795.0
# 161        제주특별자치도      인구      2010   69641.0
# 162        제주특별자치도      인구      2015   85893.0
# 163        제주특별자치도      인구  2021. 06  108118.0
#
# [164 rows x 4 columns]

# %%
_df = _
_df
# Out:
#     (행정구역별, 행정구역별) level_1   level_2         0
# 0            서울특별시      비율      2000       5.4
# 1            서울특별시      비율      2005       7.2
# 2            서울특별시      비율      2010       9.7
# 3            서울특별시      비율      2015      12.6
# 4            서울특별시      비율  2021. 06      16.4
# ..             ...     ...       ...       ...
# 159        제주특별자치도      인구      2000   43334.0
# 160        제주특별자치도      인구      2005   55795.0
# 161        제주특별자치도      인구      2010   69641.0
# 162        제주특별자치도      인구      2015   85893.0
# 163        제주특별자치도      인구  2021. 06  108118.0
#
# [164 rows x 4 columns]

# %% [markdown]
# `-` 이름을 바꾸자

# %%
_df.columns=['city','type','year','value']
_df
# Out:
#         city type      year     value
# 0      서울특별시   비율      2000       5.4
# 1      서울특별시   비율      2005       7.2
# 2      서울특별시   비율      2010       9.7
# 3      서울특별시   비율      2015      12.6
# 4      서울특별시   비율  2021. 06      16.4
# ..       ...  ...       ...       ...
# 159  제주특별자치도   인구      2000   43334.0
# 160  제주특별자치도   인구      2005   55795.0
# 161  제주특별자치도   인구      2010   69641.0
# 162  제주특별자치도   인구      2015   85893.0
# 163  제주특별자치도   인구  2021. 06  108118.0
#
# [164 rows x 4 columns]

# %% [markdown]
# `-` 더이상 안건드려도 된다.

# %%
fig = _df.query('type == "인구"').plot.area(backend='plotly',x='year',y='value',color='city')
show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 행복함
