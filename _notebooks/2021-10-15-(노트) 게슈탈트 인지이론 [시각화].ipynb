# %% [markdown]
# ### Reference

# %% [markdown]
# `-` ref: Cairo, A. Functional Art, The: An Introduction to Information Graphics and Visualization, New Riders, 2012. San Francisco, US.

# %% [markdown]
# ### 게슈탈트 인지이론
