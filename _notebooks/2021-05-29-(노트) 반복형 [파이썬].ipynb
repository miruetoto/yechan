# %% [markdown]
# # (노트) 반복객체
# > 작성완료
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - categories: [파이썬]

# %% [markdown]
# ### About this doc

# %% [markdown]
# `-` 전북대학교 파이썬입문 강의노트
#
# `-` Sentence 클래스를 통한 반복형

# %% [markdown]
# ### Intro

# %% [markdown]
# `-` 아래의 코드를 살펴보자.

# %%
for x in [1,2,3,4]: 
    print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
for x in (1,2,3,4):
    print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
for x in '1234':
    print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
for x in {1,2,3,4}:
    print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
for x in {'1':1,'2':2,'3':3,'4':4}:
    print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
import re
import reprlib 

class Sentence: 
    def __init__(self,text):
        self.text=text
        self.words= RE_WORD.findall(text)
        
    def __getitem__(self,index):
        return self.words[index]
    
    def __len__(self):
        return len(self.words)

# %%
s=Sentence("나비, 미나리")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-73eba3f21964> in <module>
# ----> 1 s=Sentence("나비, 미나리")
#
# <ipython-input-13-af9bd5eee2d2> in __init__(self, text)
#       5     def __init__(self,text):
#       6         self.text=text
# ----> 7         self.words= RE_WORD.findall(text)
#       8
#       9     def __getitem__(self,index):
#
# NameError: name 'RE_WORD' is not defined

# %%
len(s)
# Out:
# 7

# %%
for word in s: 
    print(word)
# Out:
# a
# b
# c
#
# d
# e
# f

# %%
list(s)
# Out:
# ['a', 'b', 'c', ' ', 'd', 'e', 'f']
