# %% [markdown]
# # (노트) 선형대수학 (2)
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - categories: [선형대수학]

# %% [markdown]
# ### 통계학에서 필요한 선형대수학 개념들..

# %% [markdown]
# `-` 행렬 ${\bf A}$의 역행렬이 존재 $\Longleftrightarrow$  ${\bf A}$가 full-rank matrix

# %% [markdown]
# `-` semi positive definite matrix

# %% [markdown]
# `-` 고유값분해: 실대칭행렬은 고유벡터행렬이 직교행렬이다.

# %% [markdown]
# `-` SVD

# %% [markdown]
# `-` basis, 선형공간
