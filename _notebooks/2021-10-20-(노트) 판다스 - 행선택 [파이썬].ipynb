# %% [markdown]
# # (노트) 판다스 - 행선택
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - hide: false
# - categories: [파이썬]

# %% [markdown]
# ### import

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 첫번째 행을 선택하는 방법

# %%
dic={'X1':np.random.normal(0,1,5), 
     'X2':np.random.normal(0,1,5),
     'X3':np.random.normal(0,1,5),
     'X4':np.random.normal(0,1,5),
     'X5':np.random.normal(0,1,5),  
     'X6':np.random.normal(0,1,5)
    }
df1=pd.DataFrame(dic)
df1
# Out:
#          X1        X2        X3        X4        X5        X6
# 0  0.449326 -1.340404 -0.254330 -0.971849  0.407148 -0.615758
# 1  0.287723  0.445965  1.171644 -1.393476 -0.128202 -0.591189
# 2  0.675554  2.437100 -0.318418  1.221115  1.169011 -0.015953
# 3  0.743230  0.666278  0.821528  0.405328  1.733926 -0.024356
# 4 -0.322457  1.583010  1.661233 -1.814506  0.302469  0.997066

# %% [markdown]
# `-` 방법1

# %%
df1.iloc[0] # 이상해
# Out:
# X1    0.449326
# X2   -1.340404
# X3   -0.254330
# X4   -0.971849
# X5    0.407148
# X6   -0.615758
# Name: 0, dtype: float64

# %% [markdown]
# `-` 방법2

# %%
df1.iloc[0,:]
# Out:
# X1    0.449326
# X2   -1.340404
# X3   -0.254330
# X4   -0.971849
# X5    0.407148
# X6   -0.615758
# Name: 0, dtype: float64

# %% [markdown]
# `-` 방법3

# %%
df1.iloc[[0]]
# Out:
#          X1        X2       X3        X4        X5        X6
# 0  0.449326 -1.340404 -0.25433 -0.971849  0.407148 -0.615758

# %% [markdown]
# `-` 방법4

# %%
df1.iloc[[0],:]
# Out:
#          X1        X2       X3        X4        X5        X6
# 0  0.449326 -1.340404 -0.25433 -0.971849  0.407148 -0.615758

# %% [markdown]
# `-` 방법5

# %%
df1.loc[0]
# Out:
# X1    0.449326
# X2   -1.340404
# X3   -0.254330
# X4   -0.971849
# X5    0.407148
# X6   -0.615758
# Name: 0, dtype: float64

# %% [markdown]
# `-` 방법6

# %%
df1.loc[0,:]
# Out:
# X1    0.449326
# X2   -1.340404
# X3   -0.254330
# X4   -0.971849
# X5    0.407148
# X6   -0.615758
# Name: 0, dtype: float64

# %% [markdown]
# `-` 방법7

# %%
df1.loc[[0]]
# Out:
#          X1        X2       X3        X4        X5        X6
# 0  0.449326 -1.340404 -0.25433 -0.971849  0.407148 -0.615758

# %% [markdown]
# `-` 방법8

# %%
df1.loc[[0],:]
# Out:
#          X1        X2       X3        X4        X5        X6
# 0  0.449326 -1.340404 -0.25433 -0.971849  0.407148 -0.615758

# %% [markdown]
# `-` 방법9

# %%
df1.loc[[True,False,False,False,False],:]
# Out:
#          X1        X2       X3        X4        X5        X6
# 0  0.449326 -1.340404 -0.25433 -0.971849  0.407148 -0.615758

# %% [markdown]
# `-` 방법10

# %%
df1.loc[[True,False,False,False,False]]
# Out:
#          X1        X2       X3        X4        X5        X6
# 0  0.449326 -1.340404 -0.25433 -0.971849  0.407148 -0.615758

# %% [markdown]
# `-` 방법11

# %%
df1.iloc[[True,False,False,False,False],:]
# Out:
#          X1        X2       X3        X4        X5        X6
# 0  0.449326 -1.340404 -0.25433 -0.971849  0.407148 -0.615758

# %% [markdown]
# `-` 방법12

# %%
df1.iloc[[True,False,False,False,False]]
# Out:
#          X1        X2       X3        X4        X5        X6
# 0  0.449326 -1.340404 -0.25433 -0.971849  0.407148 -0.615758

# %% [markdown]
# ### 여러개의 1,3행을 선택하는 방법

# %% [markdown]
# `-` 방법1

# %%
df.loc[[0,2],:]
# Out:
#          X1        X2        X3        X4        X5        X6
# 0 -1.852014  0.470273  0.718961  2.605273 -1.518844  0.303483
# 2 -0.082570  0.252466 -1.755272  0.555258 -0.719960 -1.831031

# %% [markdown]
# `-` 방법2

# %%
df.iloc[[0,2],:]
# Out:
#          X1        X2        X3        X4        X5        X6
# 0 -1.852014  0.470273  0.718961  2.605273 -1.518844  0.303483
# 2 -0.082570  0.252466 -1.755272  0.555258 -0.719960 -1.831031

# %% [markdown]
# `-` 불인덱싱, 슬라이싱도 가능함. (이것들은 생략할게요~)

# %% [markdown]
# #### loc vs iloc ??

# %% [markdown]
# `-` 위의 경우는 row의 인덱스이름이 정수인 경우임

# %% [markdown]
# `-` 정수가 아닌 경우

# %%
_df= pd.DataFrame({'A':[1,2,3],'B':[4,5,6]},index=list('abc'))
_df
# Out:
#    A  B
# a  1  4
# b  2  5
# c  3  6

# %%
_df.loc[['a','b'],:]
# Out:
#    A  B
# a  1  4
# b  2  5

# %%
_df.iloc[[0,1],:]
# Out:
#    A  B
# a  1  4
# b  2  5

# %% [markdown]
# `-` 대부분의 경우 obervatio에 특정한 이름이 있는 경우는 없으므로 loc이 그다지 쓸모 없음

# %% [markdown]
# `-` 그렇지만 특정 경우에는 쓸모 있음

# %%
_df=pd.DataFrame(np.random.randn(20,4),columns=list('ABCD'),index=pd.date_range('20201225',periods=20))
_df
# Out:
#                    A         B         C         D
# 2020-12-25 -0.359752  0.521507  0.280662  0.907407
# 2020-12-26  0.210061  1.285977 -1.540000  0.735020
# 2020-12-27  0.846027  0.693259  1.865635  0.944089
# 2020-12-28  0.747401  1.133861  0.861790  0.559377
# 2020-12-29  0.750016 -1.276119 -1.112284 -0.820795
# 2020-12-30 -0.612230  0.965399  0.849743  0.568011
# 2020-12-31  0.626535 -1.008876  1.385723 -0.280979
# 2021-01-01  0.728509  0.890507 -1.234721 -0.923866
# 2021-01-02 -0.909982 -0.635628 -0.529984  0.463975
# 2021-01-03 -0.543736 -0.625050  0.606186 -0.785445
# 2021-01-04 -0.368165 -1.754367  0.569304 -0.022941
# 2021-01-05 -1.400423 -0.485507  1.066330 -0.336971
# 2021-01-06 -2.783235 -1.850748  0.587250 -1.087506
# 2021-01-07  0.117771 -0.196555  0.554328 -0.628978
# 2021-01-08 -0.667862  0.586774 -0.385894 -0.572318
# 2021-01-09 -0.422079 -1.567576  0.855075 -0.350744
# 2021-01-10  1.544884  2.150816 -0.217486 -0.439209
# 2021-01-11 -0.738083 -2.559839 -0.288263  1.437569
# 2021-01-12 -1.303355 -0.293737  0.817323 -1.925663
# 2021-01-13 -0.687083  0.324115 -0.321932 -0.255650

# %% [markdown]
# `-` 1월5일부터 1월8일까지 자료만 보고 싶다!

# %%
_df.loc['20210105':'20210108']
# Out:
#                    A         B         C         D
# 2021-01-05 -1.400423 -0.485507  1.066330 -0.336971
# 2021-01-06 -2.783235 -1.850748  0.587250 -1.087506
# 2021-01-07  0.117771 -0.196555  0.554328 -0.628978
# 2021-01-08 -0.667862  0.586774 -0.385894 -0.572318

# %% [markdown]
# `-` iloc으로 하려면 힘들다..

# %%
_df.index
# Out:
# DatetimeIndex(['2020-12-25', '2020-12-26', '2020-12-27', '2020-12-28',
#                '2020-12-29', '2020-12-30', '2020-12-31', '2021-01-01',
#                '2021-01-02', '2021-01-03', '2021-01-04', '2021-01-05',
#                '2021-01-06', '2021-01-07', '2021-01-08', '2021-01-09',
#                '2021-01-10', '2021-01-11', '2021-01-12', '2021-01-13'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.Series(_df.index)
# Out:
# 0    2020-12-25
# 1    2020-12-26
# 2    2020-12-27
# 3    2020-12-28
# 4    2020-12-29
# 5    2020-12-30
# 6    2020-12-31
# 7    2021-01-01
# 8    2021-01-02
# 9    2021-01-03
# 10   2021-01-04
# 11   2021-01-05
# 12   2021-01-06
# 13   2021-01-07
# 14   2021-01-08
# 15   2021-01-09
# 16   2021-01-10
# 17   2021-01-11
# 18   2021-01-12
# 19   2021-01-13
# dtype: datetime64[ns]

# %%
_df.iloc[11:15] # 14으로하면 안된다. 마지막 인덱스가 포함되지 않으니까!
# Out:
#                    A         B         C         D
# 2021-01-05 -1.400423 -0.485507  1.066330 -0.336971
# 2021-01-06 -2.783235 -1.850748  0.587250 -1.087506
# 2021-01-07  0.117771 -0.196555  0.554328 -0.628978
# 2021-01-08 -0.667862  0.586774 -0.385894 -0.572318

# %% [markdown]
# #### 자주하는 실수

# %% [markdown]
# `-` 나는 아래와 같은 실수를 많이함

# %%
_df.loc['A']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ValueError: Given date string not likely a datetime.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py in get_loc(self, key, method, tolerance)
#     680             try:
# --> 681                 key = self._maybe_cast_for_get_loc(key)
#     682             except ValueError as err:
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py in _maybe_cast_for_get_loc(self, key)
#     708         # needed to localize naive datetimes or dates (GH 35690)
# --> 709         key = Timestamp(key)
#     710         if key.tzinfo is None:
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# ValueError: could not convert string to Timestamp
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_33682/4015539971.py in <module>
# ----> 1 _df.loc['A']
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py in get_loc(self, key, method, tolerance)
#     681                 key = self._maybe_cast_for_get_loc(key)
#     682             except ValueError as err:
# --> 683                 raise KeyError(key) from err
#     684
#     685         elif isinstance(key, timedelta):
#
# KeyError: 'A'

# %% [markdown]
# `-` 올바른 방법

# %%
_df['A']
# Out:
# 2020-12-25   -0.359752
# 2020-12-26    0.210061
# 2020-12-27    0.846027
# 2020-12-28    0.747401
# 2020-12-29    0.750016
# 2020-12-30   -0.612230
# 2020-12-31    0.626535
# 2021-01-01    0.728509
# 2021-01-02   -0.909982
# 2021-01-03   -0.543736
# 2021-01-04   -0.368165
# 2021-01-05   -1.400423
# 2021-01-06   -2.783235
# 2021-01-07    0.117771
# 2021-01-08   -0.667862
# 2021-01-09   -0.422079
# 2021-01-10    1.544884
# 2021-01-11   -0.738083
# 2021-01-12   -1.303355
# 2021-01-13   -0.687083
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# - 이런방식이 사실 좀 이상해보여서 한번쓰기 시작하면 잘쓰는데 금방까먹고 다시 헷갈림

# %% [markdown]
# `-` 아래의 사실을 기억하자.
# - 기본적으로 loc, iloc은 `[2], [2:]` 처럼 1차원으로 원소를 인덱싱할수도 있고, `[2,3], [:,2]`와 같이 2차원으로 인덱싱 할수도 있다.
# - 1차원으로 인덱싱하는 경우는 기본적으로 행을 인덱싱한다. $\to$ **loc, iloc은 행과 더 친하고 열과 친하지 않다.**
# - 따라서 열을 선택하는 방법에 있어서 loc, iloc이 그렇게 친화적인 방법은 아니다.
# - 그렇지만 달리 열을 선택하는 쉬운 방법이 존재하지 않아서 열을 선택할때에도 loc, iloc이 선호된다.

# %% [markdown]
# ### 슬라이싱응용

# %%
_df=pd.DataFrame(np.random.randn(10,4),columns=list('ABCD'),index=pd.date_range('20210101',periods=10))
_df.iloc[::2]
# Out:
#                    A         B         C         D
# 2021-01-01 -1.361026 -0.522299  0.792276  1.074594
# 2021-01-03  2.813564  1.495976  1.545519 -1.691953
# 2021-01-05 -0.802702 -0.384998 -0.418294 -0.329850
# 2021-01-07 -1.002307  0.010978 -0.096056 -0.992631
# 2021-01-09 -1.531024  0.450450  0.601330  0.169163

# %% [markdown]
# #### 이것은 칼럼에도 적용가능 $\to$ 그런데 잘 쓰지 않음

# %%
_df.iloc[:,::2]
# Out:
#                    A         C
# 2021-01-01 -1.361026  0.792276
# 2021-01-02  0.391679 -0.571396
# 2021-01-03  2.813564  1.545519
# 2021-01-04  1.833291 -0.538719
# 2021-01-05 -0.802702 -0.418294
# 2021-01-06  0.906382  1.068642
# 2021-01-07 -1.002307 -0.096056
# 2021-01-08  0.899889 -1.083999
# 2021-01-09 -1.531024  0.601330
# 2021-01-10 -1.182769 -0.085093

# %% [markdown]
# **잘 쓰지 않는 이유?**
# - row를 특정 간격으로 뽑는 일은 빈번함 (예를들어 일별데이터를 주별데이터로 바꾸고 싶을 경우?)
# - col을 특정 간격으로 뽑아야 하는 일은 없음.

# %% [markdown]
# ### lambda + map

# %%
df2 = pd.DataFrame(np.random.normal(size=(10,4)),columns=list('ABCD'))
df2
# Out:
#           A         B         C         D
# 0  1.847747 -0.135137  0.270376 -0.184955
# 1 -0.752069  1.343118  1.544871  0.174940
# 2 -0.450088 -0.173808 -0.327113  2.152646
# 3  1.704047 -2.370501  0.139030 -0.964231
# 4  1.181108  0.758522 -0.571636 -0.905563
# 5 -0.733437 -0.357610  1.101668 -0.494430
# 6  1.704264 -0.511046 -0.802806 -1.856951
# 7 -1.059690 -1.947002 -1.075315 -0.744245
# 8  1.778361  0.444605  1.515776 -0.388332
# 9 -0.220174 -1.248556  0.999474  1.180490

# %% [markdown]
# #### 컬럼A의 값이 0보다 큰 경우만

# %% [markdown]
# `-` 방법1

# %%
df2.loc[map(lambda x: x>0, df['A']),:]
# Out:
#           A         B         C         D
# 0  1.847747 -0.135137  0.270376 -0.184955
# 5 -0.733437 -0.357610  1.101668 -0.494430
# 7 -1.059690 -1.947002 -1.075315 -0.744245

# %% [markdown]
# `-` 방법2

# %%
df2.loc[lambda df: df['A']>0, : ]
# Out:
#           A         B         C         D
# 0  1.847747 -0.135137  0.270376 -0.184955
# 3  1.704047 -2.370501  0.139030 -0.964231
# 4  1.181108  0.758522 -0.571636 -0.905563
# 6  1.704264 -0.511046 -0.802806 -1.856951
# 8  1.778361  0.444605  1.515776 -0.388332

# %% [markdown]
# - ??
# - map의 기능은 (1) 리스트의 원소별로 (2) 함수를 적용하여 아웃풋을 구하고 (3) 나온 각각의 결과를 다시 하나의 리스트로 묶는 역할
# - 우리는 이중에서 (1), (3)에만 집중했음
# - 하지만 생각해보면 일단 (2) 일단함수를 적용하는 기능이 있었음
# - **그런데 위의 코드를 보면 함수를 적용한 결과가 아니라 함수오브젝트 자체를 전달하여도 동작함**

# %% [markdown]
# ***요약!!***
# - True, False 로 이루어진 벡터를 리스트의 형태로 전달하여 인덱싱하면 당연히 가능 (원래 아는거)
# - True, False 로 이루어진 벡터로 포함된 리스트를 리턴할 수 있는 함수자체를 전달하여도 인덱싱 가능

# %% [markdown]
# `-` 방법3

# %%
df2.iloc[map(lambda x: x>0, df['A']),:]
# Out:
#           A         B         C         D
# 0  1.847747 -0.135137  0.270376 -0.184955
# 5 -0.733437 -0.357610  1.101668 -0.494430
# 7 -1.059690 -1.947002 -1.075315 -0.744245

# %% [markdown]
# `-` 방법4: 실패

# %%
df2.iloc[lambda df: df['A']>0,:]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipykernel_33682/235064012.py in <module>
# ----> 1 df2.iloc[lambda df: df['A']>0,:]
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     752         for i, k in enumerate(key):
#     753             try:
# --> 754                 self._validate_key(k, i)
#     755             except ValueError as err:
#     756                 raise ValueError(
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1393             if hasattr(key, "index") and isinstance(key.index, Index):
#    1394                 if key.index.inferred_type == "integer":
# -> 1395                     raise NotImplementedError(
#    1396                         "iLocation based boolean "
#    1397                         "indexing on an integer type "
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %% [markdown]
# - 위에서.. iloc을 loc으로 바꾸면 되는데..
# - iloc입장에서 조금 서운하다..

# %% [markdown]
# #### 칼럼A>0 이고  칼럼B<0 인 경우

# %% [markdown]
# `-` 방법1

# %%
df2.loc[map(lambda x,y: x>0 and y<0, df['A'],df['B']),:]
# Out:
#           A        B         C        D
# 5 -0.733437 -0.35761  1.101668 -0.49443

# %% [markdown]
# `-` 방법2

# %%
df2.loc[map(lambda x,y: x>0 & y<0, df['A'],df['B']),:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_33682/806720762.py in <module>
# ----> 1 df2.loc[map(lambda x,y: x>0 & y<0, df['A'],df['B']),:]
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     918     def __getitem__(self, key):
#     919         if type(key) is tuple:
# --> 920             key = tuple(list(x) if is_iterator(x) else x for x in key)
#     921             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     922             if self._is_scalar_access(key):
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexing.py in <genexpr>(.0)
#     918     def __getitem__(self, key):
#     919         if type(key) is tuple:
# --> 920             key = tuple(list(x) if is_iterator(x) else x for x in key)
#     921             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     922             if self._is_scalar_access(key):
#
# /tmp/ipykernel_33682/806720762.py in <lambda>(x, y)
# ----> 1 df2.loc[map(lambda x,y: x>0 & y<0, df['A'],df['B']),:]
#
# TypeError: unsupported operand type(s) for &: 'int' and 'float'

# %% [markdown]
# - ??? 아래를 관찰

# %% [markdown]
# ***보충학습***

# %%
0<3.2 & 0<2.2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_33682/3616448715.py in <module>
# ----> 1 0<3.2 & 0<2.2
#
# TypeError: unsupported operand type(s) for &: 'float' and 'int'

# %%
(0<3.2) & (0<2.2)
# Out:
# True

# %% [markdown]
# ***보충학습끝***

# %% [markdown]
# 아래와 같이 수정하면 잘 된다.

# %%
df2.loc[map(lambda x,y: (x>0) & (y<0), df['A'],df['B']),:]
# Out:
#           A        B         C        D
# 5 -0.733437 -0.35761  1.101668 -0.49443

# %% [markdown]
# `-` 방법3: 실패

# %%
df2.loc[lambda df: (df['A']>0) and (df['B']<0),:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_33682/1689658159.py in <module>
# ----> 1 df2.loc[lambda df: (df['A']>0) and (df['B']<0),:]
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     919         if type(key) is tuple:
#     920             key = tuple(list(x) if is_iterator(x) else x for x in key)
# --> 921             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     922             if self._is_scalar_access(key):
#     923                 with suppress(KeyError, IndexError):
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/indexing.py in <genexpr>(.0)
#     919         if type(key) is tuple:
#     920             key = tuple(list(x) if is_iterator(x) else x for x in key)
# --> 921             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     922             if self._is_scalar_access(key):
#     923                 with suppress(KeyError, IndexError):
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     356     """
#     357     if callable(maybe_callable):
# --> 358         return maybe_callable(obj, **kwargs)
#     359
#     360     return maybe_callable
#
# /tmp/ipykernel_33682/1689658159.py in <lambda>(df)
# ----> 1 df2.loc[lambda df: (df['A']>0) and (df['B']<0),:]
#
# ~/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# - and는 벡터연산지원불가능

# %% [markdown]
# ***보충학습***

# %%
np.array([True,False]) and np.array([True,False])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_33682/655393721.py in <module>
# ----> 1 np.array([True,False]) and np.array([True,False])
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
np.array([True,False]) & np.array([True,False])
# Out:
# array([ True, False])

# %% [markdown]
# ***보충학습끝***

# %% [markdown]
# `-` 방법4

# %%
df2.loc[lambda df: (df['A']>0) & (df['B']<0),:]
# Out:
#           A         B         C         D
# 0  1.847747 -0.135137  0.270376 -0.184955
# 3  1.704047 -2.370501  0.139030 -0.964231
# 6  1.704264 -0.511046 -0.802806 -1.856951

# %% [markdown]
# `-` iloc을 이용한 것은 생략

# %% [markdown]
# ### query

# %% [markdown]
# #### 컬럼A>0, 컬럼B<0 인 경우 선택

# %% [markdown]
# `-` 방법1

# %%
df2.query('A>0 & B<0')
# Out:
#           A         B         C         D
# 0  1.847747 -0.135137  0.270376 -0.184955
# 3  1.704047 -2.370501  0.139030 -0.964231
# 6  1.704264 -0.511046 -0.802806 -1.856951

# %% [markdown]
# `-` 방법2

# %%
df2.query('A>0 and B<0')
# Out:
#           A         B         C         D
# 0  1.847747 -0.135137  0.270376 -0.184955
# 3  1.704047 -2.370501  0.139030 -0.964231
# 6  1.704264 -0.511046 -0.802806 -1.856951

# %% [markdown]
# #### A<B<C 를 필터

# %%
df2
# Out:
#           A         B         C         D
# 0  1.847747 -0.135137  0.270376 -0.184955
# 1 -0.752069  1.343118  1.544871  0.174940
# 2 -0.450088 -0.173808 -0.327113  2.152646
# 3  1.704047 -2.370501  0.139030 -0.964231
# 4  1.181108  0.758522 -0.571636 -0.905563
# 5 -0.733437 -0.357610  1.101668 -0.494430
# 6  1.704264 -0.511046 -0.802806 -1.856951
# 7 -1.059690 -1.947002 -1.075315 -0.744245
# 8  1.778361  0.444605  1.515776 -0.388332
# 9 -0.220174 -1.248556  0.999474  1.180490

# %%
df2.query('A<B<C')
# Out:
#           A         B         C        D
# 1 -0.752069  1.343118  1.544871  0.17494
# 5 -0.733437 -0.357610  1.101668 -0.49443

# %% [markdown]
# #### A>mean(A) 선택: query외부변수 사용

# %% [markdown]
# `-` 방법1

# %%
np.mean(df2.A)
# Out:
# 0.5000069099552247

# %%
df2.query('A>0.5000069099552247')
# Out:
#           A         B         C         D
# 0  1.847747 -0.135137  0.270376 -0.184955
# 3  1.704047 -2.370501  0.139030 -0.964231
# 4  1.181108  0.758522 -0.571636 -0.905563
# 6  1.704264 -0.511046 -0.802806 -1.856951
# 8  1.778361  0.444605  1.515776 -0.388332

# %% [markdown]
# `-` 방법2

# %%
mean_of_A=np.mean(df2.A)

# %%
df2.query('A > @mean_of_A')
# Out:
#           A         B         C         D
# 0  1.847747 -0.135137  0.270376 -0.184955
# 3  1.704047 -2.370501  0.139030 -0.964231
# 4  1.181108  0.758522 -0.571636 -0.905563
# 6  1.704264 -0.511046 -0.802806 -1.856951
# 8  1.778361  0.444605  1.515776 -0.388332

# %% [markdown]
# #### A>mean(A) 이고 A<1.8 인것을 선택

# %% [markdown]
# `-` 방법1

# %%
df2.query('A >  @mean_of_A and A<1.8')
# Out:
#           A         B         C         D
# 3  1.704047 -2.370501  0.139030 -0.964231
# 4  1.181108  0.758522 -0.571636 -0.905563
# 6  1.704264 -0.511046 -0.802806 -1.856951
# 8  1.778361  0.444605  1.515776 -0.388332

# %% [markdown]
# `-` 방법2 (가독성)

# %%
df2.query(
    " A >  @mean_of_A" 
    " and A<1.8"
)
# Out:
#           A         B         C         D
# 3  1.704047 -2.370501  0.139030 -0.964231
# 4  1.181108  0.758522 -0.571636 -0.905563
# 6  1.704264 -0.511046 -0.802806 -1.856951
# 8  1.778361  0.444605  1.515776 -0.388332

# %% [markdown]
# `-` 아래는 에러발생 (왜??)

# %%
df2.query(
    "A >  @mean_of_A" 
    "and A<1.8"
)
# Out:
# Traceback (most recent call last):
#
#   File "/home/cgb4/anaconda3/envs/py38r40/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/tmp/ipykernel_33682/2821874783.py", line 1, in <module>
#     df2.query(
#
#   File "/home/cgb4/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/frame.py", line 4060, in query
#     res = self.eval(expr, **kwargs)
#
#   File "/home/cgb4/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/frame.py", line 4191, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "/home/cgb4/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/computation/eval.py", line 348, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "/home/cgb4/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 806, in __init__
#     self.terms = self.parse()
#
#   File "/home/cgb4/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 825, in parse
#     return self._visitor.visit(self.expr)
#
#   File "/home/cgb4/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 407, in visit
#     raise e
#
#   File "/home/cgb4/anaconda3/envs/py38r40/lib/python3.8/site-packages/pandas/core/computation/expr.py", line 403, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#
#   File "/home/cgb4/anaconda3/envs/py38r40/lib/python3.8/ast.py", line 47, in parse
#     return compile(source, filename, mode, flags,
#
#   File "<unknown>", line 1
#     A >__pd_eval_local_mean_of_Aand A <1.8
#                                     ^
# SyntaxError: invalid syntax
