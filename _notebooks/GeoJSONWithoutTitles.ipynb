# %%
import os
import json


us_states = os.path.join("data", "us-states.json")

with open(us_states) as f:
    states = json.load(f)

kw = {"location": [48, -102], "zoom_start": 3}
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-df902658fdfd> in <module>
#       5 us_states = os.path.join("data", "us-states.json")
#       6
# ----> 7 with open(us_states) as f:
#       8     states = json.load(f)
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/us-states.json'

# %%
import folium
from folium import GeoJson


m = folium.Map(tiles=None, **kw)

GeoJson(states).add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d5e78ca85e87> in <module>
#       3
#       4
# ----> 5 m = folium.Map(tiles=None, **kw)
#       6
#       7 GeoJson(states).add_to(m)
#
# NameError: name 'kw' is not defined

# %%
import branca

# Create a white image of 4 pixels, and embed it in a url.
white_tile = branca.utilities.image_to_url([[1, 1], [1, 1]])

# Create a map using this url for each tile.
m = folium.Map(tiles=white_tile, attr="white tile", **kw)

GeoJson(states).add_to(m)

m

# %%
images = [[(-1) ** ((i + j) // 30) for i in range(300)] for j in range(300)]

tiles = branca.utilities.image_to_url(images)

m = folium.Map(tiles=tiles, attr="Just because we can", **kw)

GeoJson(states).add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e7994541ca52> in <module>
#       1 images = [[(-1) ** ((i + j) // 30) for i in range(300)] for j in range(300)]
#       2
# ----> 3 tiles = branca.utilities.image_to_url(images)
#       4
#       5 m = folium.Map(tiles=tiles, attr="Just because we can", **kw)
#
# NameError: name 'branca' is not defined

# %%
images = [[(-1) ** ((i // 30 + j // 30)) for i in range(300)] for j in range(300)]

tiles = branca.utilities.image_to_url(images)

m = folium.Map(tiles=tiles, attr="Just because we can", **kw)

GeoJson(states).add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5d0a314c5ad1> in <module>
#       1 images = [[(-1) ** ((i // 30 + j // 30)) for i in range(300)] for j in range(300)]
#       2
# ----> 3 tiles = branca.utilities.image_to_url(images)
#       4
#       5 m = folium.Map(tiles=tiles, attr="Just because we can", **kw)
#
# NameError: name 'branca' is not defined
