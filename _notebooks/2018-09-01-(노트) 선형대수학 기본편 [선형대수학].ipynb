# %% [markdown]
# # (노트) 선형대수학 기본편
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - categories: [선형대수학]

# %% [markdown]
# ### 행렬곱

# %% [markdown]
# `-` ${\bf X W} = \sum_{j} x_{ij} w_{jk} =\sum_{j} {\tt X[:,j]} @ {\tt W[j,:]} =  $

# %% [markdown]
# `-` ${\bf XW} =\begin{bmatrix}x_1 \\ \dots \\ x_n \end{bmatrix}\Big[W_1\dots W_q\Big] = \begin{bmatrix}
# 		a_{1\cdot}^\top b_1 & \dots & a_{1\cdot}^\top b_n \\ \dots &\dots & \dots \\  a_{n\cdot}^\top b_1 & \dots & a_{n\cdot}^\top b_n\end{bmatrix}$

# %% [markdown]
# `-` ${\bf X W}=\begin{bmatrix}
# 		x_1 \\
# 		\dots \\
# 		x_n
# 	\end{bmatrix}{\bf W}=\begin{bmatrix}
# 	x_1 {\bf W} \\
# 	\dots \\
# 	x_n {\bf W}
# \end{bmatrix}
# $

# %% [markdown]
# `-` ${\bf XW}={\bf X} [W_1 \dots,W_q] = [{\bf X} W_1,\dots,{\bf X} W_q]$

# %% [markdown]
# ### 행렬곱의 예제

# %% [markdown]
# `-` ${\bf X}{\beta}=\begin{bmatrix}x_{1\cdot}^\top{\beta} \\ \dots \\ x_{n\cdot}^\top {\beta}\end{bmatrix}
# $

# %% [markdown]
# `-` ${\bf X}' {\bf X} = [x_{1\cdot}^\top,\dots, x_{n\cdot}^\top]\begin{bmatrix} x_{1\cdot} \\ \dots \\ x_{n\cdot} \end{bmatrix}=\sum_{i=1}^{n} x_{i\cdot}^\top x_{i\cdot}$

# %% [markdown]
# `-` ${\boldsymbol \Psi}{\boldsymbol\Lambda}{\boldsymbol\Psi}^\top= \sum_{i =1}^{p} \psi_i \lambda_i  \psi_i^\top$

# %% [markdown]
# `-` ${\bf U}{\bf D}{\bf V}^\top= \sum_{i =1}^{p} u_i d_i v_i^\top$

# %% [markdown]
# ### 트레이스
#
# `-`  $tr({\bf A})=tr({\bf A}')$
#
# `-`  $tr({\bf A}{\bf B}{\bf C})=tr({\bf B}{\bf C}{\bf A})=tr({\bf C}{\bf A}{\bf B})$
#
# `-` 임의의 col-vector $y$에 대하여 아래식이 성립한다.
# $
# y^\top y=tr(y y^\top)
# $
