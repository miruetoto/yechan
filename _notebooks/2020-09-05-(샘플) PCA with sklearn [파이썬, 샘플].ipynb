# %% [markdown]
# # (샘플) PCA with sklearn
# > 작성완료
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - categories: [파이썬,샘플]

# %%
from sklearn.decomposition import PCA 
import numpy as np
X=np.random.normal(size=(100,5))
pca=PCA(n_components=3)
pca.fit(X) 
Z=pca.transform(X)

# %%
X.shape
# Out:
# (100, 5)

# %%
Z.shape
# Out:
# (100, 3)
