# %% [markdown]
# # (노트) 주피터에 그림삽입
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - categories: [주피터]

# %% [markdown]
# ### 마크다운

# %% [markdown]
# `-` 기본
#
# ```
# ![](2021-08-25-Hani01.jpeg)
# ```

# %% [markdown]
# ![](2021-08-25-Hani01.jpeg)

# %% [markdown]
# `-` 주피터에서는 크기조정 불가능 (Rmd에서는 가능)

# %% [markdown]
# #### HTML

# %% [markdown]
# `-` 기본
# ```
# <img src = 2021-08-25-Hani01.jpeg>
# ```

# %% [markdown]
# <img src = 2021-08-25-Hani01.jpeg>

# %% [markdown]
# `-` 크기조정(1)
#
# ```
# <img src = 2021-08-25-Hani01.jpeg width=20%>
# ```

# %% [markdown]
# <img src = 2021-08-25-Hani01.jpeg width=20%>

# %% [markdown]
# `-` 크기조정(2)
# ```
# <img src = 2021-08-25-Hani01.jpeg width=150>
# ```

# %% [markdown]
# <img src = 2021-08-25-Hani01.jpeg width=150>

# %% [markdown]
# `-` 크기조정이후 가운데정렬

# %% [markdown]
# <center><img src = 2021-08-25-Hani01.jpeg width=20%><center/>

# %% [markdown]
# > Note: 파일이름 대신 이미지 주소를 사용해도 무방함
