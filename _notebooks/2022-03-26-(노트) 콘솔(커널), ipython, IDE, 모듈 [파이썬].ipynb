# %% [markdown]
# ### 개발환경

# %% [markdown]
# `-` 파이썬 배우는 초보자에게 가장 어려운것!
# - 선생님마다 설치하는 방법이 모두 다름

# %% [markdown]
# `-` 왜 저렇게 설치방법이 다른가? 왜 다른 방법으로 각각 파이썬을 실행하는가? 이런것이 너무 어려움
# - [방법1:](https://wikidocs.net/8) 파이썬프로그램 다운로드 -> 시작버튼 눌러서 설치
# - [방법2:](https://wikidocs.net/44) 아나콘다 설치 (그럼 자동으로 파이썬이 설치됨)
# - 방법3: 아나콘다 설치 + 가상환경
# - [방법4:](https://blog.fotogrammer.com/python-%EA%B0%9C%EB%B0%9C-%ED%99%98%EA%B2%BD-%EA%B5%AC%EC%B6%95%EA%B8%B0-on-wsl2/) WSL을 이용한 설치
# - ...

# %% [markdown]
# `-` 심지어 실행하는것도 다름
# - [방법1:](https://goddaehee.tistory.com/286) 파이썬 프롬프트
# - [방법2:](https://goddaehee.tistory.com/286) IDLE
# - [방법3:](https://ddolcat.tistory.com/691) 아나콘다 네비게이터
# - 방법4: 주피터
#     - 가상환경을 만들어서 해라..
#     - 아나콘다 네비게이터에 주피터가 있다..
# - [방법5:](https://tariat.tistory.com/73) 파이참
# - [방법6:](https://shlee1990.tistory.com/963) 스파이더
# - [방법7:](https://www.codingfactory.net/11337) Visual Studio Code
# - ...

# %% [markdown]
# `-` 심지어 버전도 다름
# - 어떤책은 파이썬 3.7을 기반으로 코드작성했고 그 외의 파이썬에서는 실행되지 않을수도 있다고 위협을 가함..

# %% [markdown]
# `-` 머리아프니까 collab을 쓰라는 사람도 있음. 아니면 도커이미지를 줄테니까 그걸 쓰라는 사람도 있음. AWS를 쓰라는 사람도 있음.. $\to$ 이게 더 머리아픔

# %% [markdown]
# `-` 핵심: 그냥 (1) 컴퓨터에 (2) 파이썬을 깔아서 (3) 실행하는것임

# %% [markdown]
# `-` 의문: 그럼 왜 엑셀처럼 프로그램설치하고 아이콘 더블클릭하면 끝나는 식으로 만들지 않는가? 왜 이렇게 힘들어야 하는가?

# %% [markdown]
# ### 개발환경 구축

# %% [markdown]
# `-` 파이썬 개발환경 구축은 수많은 방법이 있다. (검색하면 진짜 무수히 많이 나옴)
#
# `-` 이는 마치 라면의 레시피를 검색했을때 수많은 방법이 나오는것과 유사함.
# - 방법1: 스프를 먼저 넣고 끓인다음에 라면을 넣어야 합니다.
# - 방법2: 양은냄비에 물넣고 물 끓으면 스프넣고 라면 넣고 마지막에 계란을 넣는다.
# - 방법3: 웤에 물을 조금 넣고 라면과 스프를 넣고 자글자글 끓이다가 마지막에 참기름을 넣어요
# - 방법4: 먹다남은 삼겹살을 후라이팬에 볶은뒤에 물을 붓고 라면을 먹는다.
# - 방법5: 용기에 라면과 스프와 뜨거운물을 넣고 랩을 쒸운뒤에 젓가락으로 구멍을 뚫는다. 그 다음에 전자렌지로 돌린다.
# - ...

# %% [markdown]
# `-` 우리는 모든 방법을 나열할 순 없지만 모든방법을 이해할 수 있다. 왜냐하면 라면을 끓이는 어떤한 공통맥락을 우리는 파악하고 있기 때문.

# %% [markdown]
# `-` 파이썬의 개발환경 구축 역시 사실 비슷하다. 공통맥락을 파악하면 쉽다.

# %% [markdown]
# `-` 제 목적: 가장 맛있는 라면을 끓이는 하나의 레시피가 아니라 라면을 끓이는 레시피를 이해할 수 있는 공통맥락을 설명하고 싶어요

# %% [markdown]
# ### python커널 (기본라면)

# %% [markdown]
# `-` 윈도우에서 anaconda prompt실행 -> conda activate py39 -> python

# %% [markdown]
# `-` 2개를 실행할 수도 있음. (두 환경은 서로 독립적이며 변수이름등이 공유되지 않음)

# %% [markdown]
# ### ipython커널 (업그레이드된 기본라면, 이제 업계표준)

# %% [markdown]
# `-`
