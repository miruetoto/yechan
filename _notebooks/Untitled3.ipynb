# %%
#hide
options(jupyter.plot_scale=3)
#options(jupyter.display_mimetypes=c("text/html"))
options(jupyter.rich_display=FALSE)
options(repr.plot.width=6,repr.plot.height=6,repr.plot.res=300)
options(max.print=200)

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# `-` 길이가 50인 벡터생성

# %%
A = rnorm(10*5)
A ## 길이가 50인 벡터에 정규분포에 추출한 값
# Out:
#  [1]  1.060903671 -1.050525685 -1.029060417  0.105570300  3.191296693
#  [6]  1.484966210  0.417302338  0.534368824 -0.578862453  0.217849930
# [11]  0.277640652  0.959482038  0.599124995 -1.369148841 -0.184630375
# [16]  1.737383374  0.101137345  0.004699876  0.614463660  0.474925638
# [21] -0.374634455 -0.943584689  0.721886271  0.723253527  2.237329663
# [26] -1.314024990 -0.461653462  1.183512730 -1.199149438 -1.634865774
# [31] -1.964670330 -0.606761036 -0.271513021  0.993863450 -0.765204820
# [36] -0.087541551 -0.974917547 -1.308019597  0.540011408  0.588260331
# [41] -0.584488995 -0.935663721 -2.044052604 -0.540785388  0.603286167
# [46]  0.611568686  0.486046299 -0.611870638 -0.348416804  1.100173087

# %% [markdown]
# `-` 매트릭스로 변경

# %%
dim(A) = c(10,5) 
A
# Out:
#       [,1]       [,2]         [,3]       [,4]        [,5]
#  [1,]  1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890
#  [2,] -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637
#  [3,] -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526
#  [4,]  0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854
#  [5,]  3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862
#  [6,]  1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687
#  [7,]  0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463
#  [8,]  0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706
#  [9,] -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168
# [10,]  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731

# %% [markdown]
# `-` 티블로 변경 (자동으로 V1,...,V5 열의 이름이 지정됨)

# %%
A = as_tibble(A) 
A
# Out:
# Warning message:
# “The `x` argument of `as_tibble.matrix()` must have unique column names if `.name_repair` is omitted as of tibble 2.0.0.
# Using compatibility `.name_repair`.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_lifecycle_warnings()` to see where this warning was generated.”
#    V1         V2           V3         V4          V5
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731

# %% [markdown]
# `-` 컬럼의 이름 확인

# %%
colnames(A)
# Out:
# [1] "V1" "V2" "V3" "V4" "V5"

# %% [markdown]
# `-` 칼럼의 이름을 바꾸고 싶다면?

# %%
colnames(A) = c('X1','X2','X3','X4','X5') 
A
# Out:
#    X1         X2           X3         X4          X5
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731

# %% [markdown]
# ### select()

# %% [markdown]
# `-` 처음 3개의 칼럼과 마지막 1개의 칼럼을 선택하고 싶다면?

# %%
A %>% select(1:3,5)
# Out:
#    X1         X2           X3         X5
# 1   1.0609037  0.277640652 -0.3746345 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297  0.6032862
# 6   1.4849662  1.737383374 -1.3140250  0.6115687
# 7   0.4173023  0.101137345 -0.4616535  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  1.1001731

# %% [markdown]
# `-` 열의 이름을 통하여서도 선택할 수 있음

# %%
A %>% select(X1:X3,X5)
# Out:
#    X1         X2           X3         X5
# 1   1.0609037  0.277640652 -0.3746345 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297  0.6032862
# 6   1.4849662  1.737383374 -1.3140250  0.6115687
# 7   0.4173023  0.101137345 -0.4616535  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  1.1001731

# %% [markdown]
# `-` 열의 이름과 위치인덱스를 혼합하여 사용할 수 있음

# %%
A %>% select(X1:X3, 5)
# Out:
#    X1         X2           X3         X5
# 1   1.0609037  0.277640652 -0.3746345 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297  0.6032862
# 6   1.4849662  1.737383374 -1.3140250  0.6115687
# 7   0.4173023  0.101137345 -0.4616535  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  1.1001731

# %% [markdown]
# `-` 열의 이름과 위치인덱스를 혼합하여 사용할 수 있음 (2)

# %%
A %>% select(1:3, X5)
# Out:
#    X1         X2           X3         X5
# 1   1.0609037  0.277640652 -0.3746345 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297  0.6032862
# 6   1.4849662  1.737383374 -1.3140250  0.6115687
# 7   0.4173023  0.101137345 -0.4616535  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  1.1001731

# %% [markdown]
# `-` 선택한 결과를 다른 변수에 저장가능

# %%
A %>% select(1:3, X5) -> B 
B
# Out:
#    X1         X2           X3         X5
# 1   1.0609037  0.277640652 -0.3746345 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297  0.6032862
# 6   1.4849662  1.737383374 -1.3140250  0.6115687
# 7   0.4173023  0.101137345 -0.4616535  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  1.1001731

# %% [markdown]
# #### select(-c())

# %% [markdown]
# `-` A라는 자료를 다시 살펴보자.

# %%
A
# Out:
#    X1         X2           X3         X4          X5
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731

# %% [markdown]
# `-` 특정열을 제외하고 선택

# %%
A %>% select(-(X1:X3))
# Out:
#    X4          X5
# 1  -1.96467033 -0.5844890
# 2  -0.60676104 -0.9356637
# 3  -0.27151302 -2.0440526
# 4   0.99386345 -0.5407854
# 5  -0.76520482  0.6032862
# 6  -0.08754155  0.6115687
# 7  -0.97491755  0.4860463
# 8  -1.30801960 -0.6118706
# 9   0.54001141 -0.3484168
# 10  0.58826033  1.1001731

# %%
A %>% select(-(1:3))
# Out:
#    X4          X5
# 1  -1.96467033 -0.5844890
# 2  -0.60676104 -0.9356637
# 3  -0.27151302 -2.0440526
# 4   0.99386345 -0.5407854
# 5  -0.76520482  0.6032862
# 6  -0.08754155  0.6115687
# 7  -0.97491755  0.4860463
# 8  -1.30801960 -0.6118706
# 9   0.54001141 -0.3484168
# 10  0.58826033  1.1001731

# %% [markdown]
# #### select(...,start_with())

# %% [markdown]
# `-` 데이터 확인

# %%
A
# Out:
#    X1         X2           X3         X4          X5
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731

# %% [markdown]
# `-` 열의 이름 확인 및 변경

# %%
colnames(A)
# Out:
# [1] "X1" "X2" "X3" "X4" "X5"

# %%
colnames(A)= c('XY1','XY2','XZ1','XZ2','X5')

# %%
A
# Out:
#    XY1        XY2          XZ1        XZ2         X5
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731

# %% [markdown]
# `-` XY로 시작하는 열을 선택

# %%
A %>% select(starts_with('XY'))
# Out:
#    XY1        XY2
# 1   1.0609037  0.277640652
# 2  -1.0505257  0.959482038
# 3  -1.0290604  0.599124995
# 4   0.1055703 -1.369148841
# 5   3.1912967 -0.184630375
# 6   1.4849662  1.737383374
# 7   0.4173023  0.101137345
# 8   0.5343688  0.004699876
# 9  -0.5788625  0.614463660
# 10  0.2178499  0.474925638

# %% [markdown]
# #### select(...,ends_with())

# %% [markdown]
# `-` 데이터확인

# %%
A
# Out:
#    XY1        XY2          XZ1        XZ2         X5
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731

# %% [markdown]
# `-` 2로 끝나는 열을 선택

# %%
A %>% select(ends_with('2'))
# Out:
#    XY2          XZ2
# 1   0.277640652 -1.96467033
# 2   0.959482038 -0.60676104
# 3   0.599124995 -0.27151302
# 4  -1.369148841  0.99386345
# 5  -0.184630375 -0.76520482
# 6   1.737383374 -0.08754155
# 7   0.101137345 -0.97491755
# 8   0.004699876 -1.30801960
# 9   0.614463660  0.54001141
# 10  0.474925638  0.58826033

# %% [markdown]
# #### select(...,contains())

# %% [markdown]
# `-` 데이터확인

# %%
A
# Out:
#    XY1        XY2          XZ1        XZ2         X5
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731

# %% [markdown]
# `-` Z를 포함하는 열을 선택

# %%
A %>% select(contains("Z"))
# Out:
#    XZ1        XZ2
# 1  -0.3746345 -1.96467033
# 2  -0.9435847 -0.60676104
# 3   0.7218863 -0.27151302
# 4   0.7232535  0.99386345
# 5   2.2373297 -0.76520482
# 6  -1.3140250 -0.08754155
# 7  -0.4616535 -0.97491755
# 8   1.1835127 -1.30801960
# 9  -1.1991494  0.54001141
# 10 -1.6348658  0.58826033

# %% [markdown]
# #### select(...,everything())

# %% [markdown]
# `-` 데이터확인

# %%
A
# Out:
#    XY1        XY2          XZ1        XZ2         X5
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731

# %% [markdown]
# `-` Z를 포함하는 열을 앞으로 이동시킴

# %%
A %>% select(contains("Z"),everything())
# Out:
#    XZ1        XZ2         XY1        XY2          X5
# 1  -0.3746345 -1.96467033  1.0609037  0.277640652 -0.5844890
# 2  -0.9435847 -0.60676104 -1.0505257  0.959482038 -0.9356637
# 3   0.7218863 -0.27151302 -1.0290604  0.599124995 -2.0440526
# 4   0.7232535  0.99386345  0.1055703 -1.369148841 -0.5407854
# 5   2.2373297 -0.76520482  3.1912967 -0.184630375  0.6032862
# 6  -1.3140250 -0.08754155  1.4849662  1.737383374  0.6115687
# 7  -0.4616535 -0.97491755  0.4173023  0.101137345  0.4860463
# 8   1.1835127 -1.30801960  0.5343688  0.004699876 -0.6118706
# 9  -1.1991494  0.54001141 -0.5788625  0.614463660 -0.3484168
# 10 -1.6348658  0.58826033  0.2178499  0.474925638  1.1001731

# %% [markdown]
# ### filter()

# %% [markdown]
# `-` 데이터확인

# %%
A
# Out:
#    XY1        XY2          XZ1        XZ2         X5
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731

# %% [markdown]
# `-` X5>0인 행들만 뽑고싶다.

# %%
A %>% filter(X5>0)
# Out:
#   XY1       XY2        XZ1        XZ2         X5
# 1 3.1912967 -0.1846304  2.2373297 -0.76520482 0.6032862
# 2 1.4849662  1.7373834 -1.3140250 -0.08754155 0.6115687
# 3 0.4173023  0.1011373 -0.4616535 -0.97491755 0.4860463
# 4 0.2178499  0.4749256 -1.6348658  0.58826033 1.1001731

# %% [markdown]
# `-` X5>0 이고 XY2>0 인 행들만 뽑고싶다.

# %%
A %>% filter(X5>0 & XY2>0)
# Out:
#   XY1       XY2       XZ1        XZ2         X5
# 1 1.4849662 1.7373834 -1.3140250 -0.08754155 0.6115687
# 2 0.4173023 0.1011373 -0.4616535 -0.97491755 0.4860463
# 3 0.2178499 0.4749256 -1.6348658  0.58826033 1.1001731

# %% [markdown]
# `-` 위의 결과에서 XZ를 포함하는 열을 뽑고싶다.

# %%
A %>% filter(X5>0 & XY2>0) %>% select(contains("XZ"))
# Out:
#   XZ1        XZ2
# 1 -1.3140250 -0.08754155
# 2 -0.4616535 -0.97491755
# 3 -1.6348658  0.58826033

# %% [markdown]
# ### mutate()

# %% [markdown]
# `-` 데이터를 확인

# %%
A
# Out:
#    XY1        XY2          XZ1        XZ2         X5
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731

# %% [markdown]
# `-` 새로운 변수추가

# %%
A %>% mutate(X6=abs(X5))
# Out:
#    XY1        XY2          XZ1        XZ2         X5         X6
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890 0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637 0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526 2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854 0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862 0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687 0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463 0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706 0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168 0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731 1.1001731

# %% [markdown]
# `-` 여러개의 새로운 변수를 추가하는 기능도 있음

# %%
A %>% mutate(X6=abs(X5),Z7=X5**2)
# Out:
#    XY1        XY2          XZ1        XZ2         X5         X6
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890 0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637 0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526 2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854 0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862 0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687 0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463 0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706 0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168 0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731 1.1001731
#    Z7
# 1  0.3416274
# 2  0.8754666
# 3  4.1781510
# 4  0.2924488
# 5  0.3639542
# 6  0.3740163
# 7  0.2362410
# 8  0.3743857
# 9  0.1213943
# 10 1.2103808

# %% [markdown]
# `-` 표준화

# %%
A %>% mutate(X6=abs(X5),Z7=X5**2,Z8=(Z7-mean(Z7))/sd(Z7))
# Out:
#    XY1        XY2          XZ1        XZ2         X5         X6
# 1   1.0609037  0.277640652 -0.3746345 -1.96467033 -0.5844890 0.5844890
# 2  -1.0505257  0.959482038 -0.9435847 -0.60676104 -0.9356637 0.9356637
# 3  -1.0290604  0.599124995  0.7218863 -0.27151302 -2.0440526 2.0440526
# 4   0.1055703 -1.369148841  0.7232535  0.99386345 -0.5407854 0.5407854
# 5   3.1912967 -0.184630375  2.2373297 -0.76520482  0.6032862 0.6032862
# 6   1.4849662  1.737383374 -1.3140250 -0.08754155  0.6115687 0.6115687
# 7   0.4173023  0.101137345 -0.4616535 -0.97491755  0.4860463 0.4860463
# 8   0.5343688  0.004699876  1.1835127 -1.30801960 -0.6118706 0.6118706
# 9  -0.5788625  0.614463660 -1.1991494  0.54001141 -0.3484168 0.3484168
# 10  0.2178499  0.474925638 -1.6348658  0.58826033  1.1001731 1.1001731
#    Z7        Z8
# 1  0.3416274 -0.40625395
# 2  0.8754666  0.03171735
# 3  4.1781510  2.74129914
# 4  0.2924488 -0.44660092
# 5  0.3639542 -0.38793663
# 6  0.3740163 -0.37968154
# 7  0.2362410 -0.49271484
# 8  0.3743857 -0.37937846
# 9  0.1213943 -0.58693717
# 10 1.2103808  0.30648701

# %% [markdown]
# ### group_by()

# %%
sex = c("M","M","M","F","F","F","F")
value = c(1,2,3,10,20,30,40)

# %%
df=tibble(sex=sex,value=value)
df
# Out:
#   sex value
# 1 M    1
# 2 M    2
# 3 M    3
# 4 F   10
# 5 F   20
# 6 F   30
# 7 F   40

# %%
df %>% group_by(sex) %>% summarise(mean_value= mean(value))
# Out:
#   sex mean_value
# 1 F   25
# 2 M    2

# %% [markdown]
# - 그룹별로 묶은다음에 평균을 계산함

# %% [markdown]
# `-` 신기한데? 다른것도 실습해보자.

# %%
df %>% group_by(sex) %>% summarise(sqrt_value= sqrt(value))
# Out:
# `summarise()` has grouped output by 'sex'. You can override using the `.groups` argument.
#   sex sqrt_value
# 1 F   3.162278
# 2 F   4.472136
# 3 F   5.477226
# 4 F   6.324555
# 5 M   1.000000
# 6 M   1.414214
# 7 M   1.732051

# %% [markdown]
# - 이렇게 쓰는게 아니에요!

# %% [markdown]
# `-` `summarise`에 가능한 함수모양은 평균과 같이 $n$차원의 벡터를 입력으로 받고 하나의 스칼라 출력을 주는 함수모양이어야 함

# %%
df %>% group_by(sex) %>% summarise(mean_sqrt_value= mean(sqrt(value)))
# Out:
#   sex mean_sqrt_value
# 1 F   4.859049
# 2 M   1.382088

# %% [markdown]
# - 차라리 이건 가능

# %%
(sqrt(1)+sqrt(2)+sqrt(3)) /3
# Out:
# [1] 1.382088

# %%
(sqrt(10)+sqrt(20)+sqrt(30)+sqrt(40))/4
# Out:
# [1] 4.859049

# %% [markdown]
# `-` 벡터입력, 벡터출력을 하기 위해서는 mutate가 맞아요

# %%
df %>% group_by(sex) %>% mutate(value2= value-mean(value))
# Out:
#   sex value value2
# 1 M    1     -1
# 2 M    2      0
# 3 M    3      1
# 4 F   10    -15
# 5 F   20     -5
# 6 F   30      5
# 7 F   40     15

# %% [markdown]
# - 그룹별로 분리하여 평균을 냄

# %% [markdown]
# `-` 위의 코드는 아래와 동일하다.

# %%
df %>% filter(sex=='M') %>% mutate(value2= value-mean(value))
# Out:
#   sex value value2
# 1 M   1     -1
# 2 M   2      0
# 3 M   3      1

# %%
df %>% filter(sex=='F') %>% mutate(value2= value-mean(value))
# Out:
#   sex value value2
# 1 F   10    -15
# 2 F   20     -5
# 3 F   30      5
# 4 F   40     15

# %%
df %>% filter(sex=='M') %>% mutate(value2= value-mean(value)) -> A1
df %>% filter(sex=='F') %>% mutate(value2= value-mean(value)) -> A2

# %%
A1
# Out:
#   sex value value2
# 1 M   1     -1
# 2 M   2      0
# 3 M   3      1

# %%
A2
# Out:
#   sex value value2
# 1 F   10    -15
# 2 F   20     -5
# 3 F   30      5
# 4 F   40     15

# %% [markdown]
# `-` 두 데이터프레임을 합쳐야한다? 어떻게??

# %%
rbind(A1,A2) # 아몰라.. 매트릭스처럼하자!
# Out:
#   sex value value2
# 1 M    1     -1
# 2 M    2      0
# 3 M    3      1
# 4 F   10    -15
# 5 F   20     -5
# 6 F   30      5
# 7 F   40     15

# %% [markdown]
# - 된다..

# %% [markdown]
# ### NA

# %% [markdown]
# `-` NA 포함되어도 개별연산은 괜찮아요

# %%
x = c(1,2,NA,4,5)
x
# Out:
# [1]  1  2 NA  4  5

# %%
x+1
# Out:
# [1]  2  3 NA  5  6

# %%
x**2
# Out:
# [1]  1  4 NA 16 25

# %% [markdown]
# `-` 그런데 summarise에 쓸 연산은 망가져요

# %%
mean(x)
# Out:
# [1] NA

# %%
max(x)
# Out:
# [1] NA

# %% [markdown]
# `-` 수정을 위해서

# %%
mean(x,na.rm=TRUE) # na remove
# Out:
# [1] 2.333333

# %%
max(x,na.rm=TRUE)
# Out:
# [1] 4

# %% [markdown]
# `-` 데이터프레임에서도 비슷합니다.

# %%
tibble(x=x) %>% mutate(z=x+1)
# Out:
#   x  z
# 1  1  2
# 2  2  3
# 3 NA NA
# 4  4  5

# %%
tibble(x=x) %>% summarise(z=mean(x))
# Out:
#   z
# 1 NA

# %%
tibble(x=x) %>% summarise(z=mean(x,na.rm=TRUE))
# Out:
#   z
# 1 2.333333

# %% [markdown]
# `-` NA를 무조건 없에는게 좋으냐?

# %%
x<- c(1,2,NA,4)
y<- c(1,NA,3,4)
z<- c(NA,2,3,4)
w<- c(1,2,3,NA)

# %%
tibble(x=x,y=y,z=z,w=w)
# Out:
#   x  y  z  w
# 1  1  1 NA  1
# 2  2 NA  2  2
# 3 NA  3  3  3
# 4  4  4  4 NA

# %%
tibble(x=x,y=y,z=z,w=w) %>% mutate(xy=x+y)
# Out:
#   x  y  z  w  xy
# 1  1  1 NA  1  2
# 2  2 NA  2  2 NA
# 3 NA  3  3  3 NA
# 4  4  4  4 NA  8

# %%
tibble(x=x,y=y,z=z,w=w) %>% filter %>% mutate(xy=x+y)
# Out:
#   x  y  z  w  xy
# 1  1  1 NA  1  2
# 2  2 NA  2  2 NA
# 3 NA  3  3  3 NA
# 4  4  4  4 NA  8

# %%
tibble(x=x,y=y,z=z,w=w) %>% filter %>% mutate(xy=x+y) %>% summarise(mean_xy = mean(xy,na.rm=TRUE))
# Out:
#   mean_xy
# 1 5

# %% [markdown]
# - 그래도 살려두면서 쓰는게 낫지 않나? 데이터 하나하나가 소중하니까요!

# %% [markdown]
# `-` 결측치를 살릴까 죽일까?

# %%
x = c(1,2,3,4,NA,5,6,7)
y = c(-1,-2,-3,-4,77,-5,-6,-7)

# %%
is.na(x)
# Out:
# [1] FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE

# %%
tibble(x,y)
# Out:
#   x  y
# 1  1 -1
# 2  2 -2
# 3  3 -3
# 4  4 -4
# 5 NA 77
# 6  5 -5
# 7  6 -6
# 8  7 -7

# %%
tibble(x,y) %>% filter(x>3,x<7)
# Out:
#   x y
# 1 4 -4
# 2 5 -5
# 3 6 -6

# %% [markdown]
# - ?? y=77 은 죄없이 사라짐. 사실 보류이어야 하지 않나? NA는 3보다 크지도 작지도 않고, 7보다 크지도 작지도 않잖아?

# %% [markdown]
# `-` 결측치를 살려두고 싶다.

# %%
tibble(x,y) %>% filter(is.na(x))
# Out:
#   x  y
# 1 NA 77

# %%
tibble(x,y) %>% filter(is.na(x) | (x>3 & x<7))
# Out:
#   x  y
# 1  4 -4
# 2 NA 77
# 3  5 -5
# 4  6 -6

# %% [markdown]
# - 데이터는 소중함

# %% [markdown]
# ### 실습

# %%
library(tidyverse)
#install.packages("nycflights13")
library(nycflights13)

# %%
df = flights
df
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
#        arr_delay carrier flight tailnum origin dest air_time distance hour
# 1       11       UA      1545   N14228  EWR    IAH  227      1400     5
# 2       20       UA      1714   N24211  LGA    IAH  227      1416     5
# 3       33       AA      1141   N619AA  JFK    MIA  160      1089     5
# 4      -18       B6       725   N804JB  JFK    BQN  183      1576     5
# 5      -25       DL       461   N668DN  LGA    ATL  116       762     6
# 6       12       UA      1696   N39463  EWR    ORD  150       719     5
# 7       19       B6       507   N516JB  EWR    FLL  158      1065     6
# 8      -14       EV      5708   N829AS  LGA    IAD   53       229     6
# 9       -8       B6        79   N593JB  JFK    MCO  140       944     6
# 10       8       AA       301   N3ALAA  LGA    ORD  138       733     6
#        minute time_hour
# 1      15     2013-01-01 05:00:00
# 2      29     2013-01-01 05:00:00
# 3      40     2013-01-01 05:00:00
# 4      45     2013-01-01 05:00:00
# 5       0     2013-01-01 06:00:00
# 6      58     2013-01-01 05:00:00
# 7       0     2013-01-01 06:00:00
# 8       0     2013-01-01 06:00:00
# 9       0     2013-01-01 06:00:00
# 10      0     2013-01-01 06:00:00
#  [ reached getOption("max.print") -- omitted 51 rows ]

# %% [markdown]
# `-` 1월1일의 모든항공편을 선택하고싶다.

# %%
df %>% filter(month==1,day==1)
# Out:
#     year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1   2013 1     1   517      515             2         830      819
# 2   2013 1     1   533      529             4         850      830
# 3   2013 1     1   542      540             2         923      850
# 4   2013 1     1   544      545            -1        1004     1022
# 5   2013 1     1   554      600            -6         812      837
# 6   2013 1     1   554      558            -4         740      728
# 7   2013 1     1   555      600            -5         913      854
# 8   2013 1     1   557      600            -3         709      723
# 9   2013 1     1   557      600            -3         838      846
# 10  2013 1     1   558      600            -2         753      745
#     arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1    11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2    20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3    33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4   -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5   -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# 6    12       UA      1696   N39463  EWR    ORD  150       719     5    58
# 7    19       B6       507   N516JB  EWR    FLL  158      1065     6     0
# 8   -14       EV      5708   N829AS  LGA    IAD   53       229     6     0
# 9    -8       B6        79   N593JB  JFK    MCO  140       944     6     0
# 10    8       AA       301   N3ALAA  LGA    ORD  138       733     6     0
#     time_hour
# 1   2013-01-01 05:00:00
# 2   2013-01-01 05:00:00
# 3   2013-01-01 05:00:00
# 4   2013-01-01 05:00:00
# 5   2013-01-01 06:00:00
# 6   2013-01-01 05:00:00
# 7   2013-01-01 06:00:00
# 8   2013-01-01 06:00:00
# 9   2013-01-01 06:00:00
# 10  2013-01-01 06:00:00
#  [ reached getOption("max.print") -- omitted 51 rows ]

# %% [markdown]
# `-` 아래코드와 동일

# %%
filter(df,month==1,day==1)
# Out:
#     year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1   2013 1     1   517      515             2         830      819
# 2   2013 1     1   533      529             4         850      830
# 3   2013 1     1   542      540             2         923      850
# 4   2013 1     1   544      545            -1        1004     1022
# 5   2013 1     1   554      600            -6         812      837
# 6   2013 1     1   554      558            -4         740      728
# 7   2013 1     1   555      600            -5         913      854
# 8   2013 1     1   557      600            -3         709      723
# 9   2013 1     1   557      600            -3         838      846
# 10  2013 1     1   558      600            -2         753      745
#     arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1    11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2    20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3    33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4   -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5   -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# 6    12       UA      1696   N39463  EWR    ORD  150       719     5    58
# 7    19       B6       507   N516JB  EWR    FLL  158      1065     6     0
# 8   -14       EV      5708   N829AS  LGA    IAD   53       229     6     0
# 9    -8       B6        79   N593JB  JFK    MCO  140       944     6     0
# 10    8       AA       301   N3ALAA  LGA    ORD  138       733     6     0
#     time_hour
# 1   2013-01-01 05:00:00
# 2   2013-01-01 05:00:00
# 3   2013-01-01 05:00:00
# 4   2013-01-01 05:00:00
# 5   2013-01-01 06:00:00
# 6   2013-01-01 05:00:00
# 7   2013-01-01 06:00:00
# 8   2013-01-01 06:00:00
# 9   2013-01-01 06:00:00
# 10  2013-01-01 06:00:00
#  [ reached getOption("max.print") -- omitted 51 rows ]

# %% [markdown]
# `-` 11월에 출발하거나 12월에 출발한 항공

# %%
df %>% filter(month==11|month==12)
# Out:
#       year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1     2013 11    1     5      2359             6       352       345
# 2     2013 11    1    35      2250           105       123      2356
# 3     2013 11    1   455       500            -5       641       651
# 4     2013 11    1   539       545            -6       856       827
# 5     2013 11    1   542       545            -3       831       855
# 6     2013 11    1   549       600           -11       912       923
# 7     2013 11    1   550       600           -10       705       659
# 8     2013 11    1   554       600            -6       659       701
# 9     2013 11    1   554       600            -6       826       827
# 10    2013 11    1   554       600            -6       749       751
#       arr_delay carrier flight tailnum origin dest air_time distance hour
# 1       7       B6       745   N568JB  JFK    PSE  205      1617     23
# 2      87       B6      1816   N353JB  JFK    SYR   36       209     22
# 3     -10       US      1895   N192UW  EWR    CLT   88       529      5
# 4      29       UA      1714   N38727  LGA    IAH  229      1416      5
# 5     -24       AA      2243   N5CLAA  JFK    MIA  147      1089      5
# 6     -11       UA       303   N595UA  JFK    SFO  359      2586      6
# 7       6       US      2167   N748UW  LGA    DCA   57       214      6
# 8      -2       US      2134   N742PS  LGA    BOS   40       184      6
# 9      -1       DL       563   N912DE  LGA    ATL  126       762      6
# 10     -2       DL       731   N315NB  LGA    DTW   93       502      6
#       minute time_hour
# 1     59     2013-11-01 23:00:00
# 2     50     2013-11-01 22:00:00
# 3      0     2013-11-01 05:00:00
# 4     45     2013-11-01 05:00:00
# 5     45     2013-11-01 05:00:00
# 6      0     2013-11-01 06:00:00
# 7      0     2013-11-01 06:00:00
# 8      0     2013-11-01 06:00:00
# 9      0     2013-11-01 06:00:00
# 10     0     2013-11-01 06:00:00
#  [ reached getOption("max.print") -- omitted 51 rows ]

# %% [markdown]
# `-` 아래와 동일한 코드

# %%
df %>% filter(month %in% c(11,12))
# Out:
#       year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1     2013 11    1     5      2359             6       352       345
# 2     2013 11    1    35      2250           105       123      2356
# 3     2013 11    1   455       500            -5       641       651
# 4     2013 11    1   539       545            -6       856       827
# 5     2013 11    1   542       545            -3       831       855
# 6     2013 11    1   549       600           -11       912       923
# 7     2013 11    1   550       600           -10       705       659
# 8     2013 11    1   554       600            -6       659       701
# 9     2013 11    1   554       600            -6       826       827
# 10    2013 11    1   554       600            -6       749       751
#       arr_delay carrier flight tailnum origin dest air_time distance hour
# 1       7       B6       745   N568JB  JFK    PSE  205      1617     23
# 2      87       B6      1816   N353JB  JFK    SYR   36       209     22
# 3     -10       US      1895   N192UW  EWR    CLT   88       529      5
# 4      29       UA      1714   N38727  LGA    IAH  229      1416      5
# 5     -24       AA      2243   N5CLAA  JFK    MIA  147      1089      5
# 6     -11       UA       303   N595UA  JFK    SFO  359      2586      6
# 7       6       US      2167   N748UW  LGA    DCA   57       214      6
# 8      -2       US      2134   N742PS  LGA    BOS   40       184      6
# 9      -1       DL       563   N912DE  LGA    ATL  126       762      6
# 10     -2       DL       731   N315NB  LGA    DTW   93       502      6
#       minute time_hour
# 1     59     2013-11-01 23:00:00
# 2     50     2013-11-01 22:00:00
# 3      0     2013-11-01 05:00:00
# 4     45     2013-11-01 05:00:00
# 5     45     2013-11-01 05:00:00
# 6      0     2013-11-01 06:00:00
# 7      0     2013-11-01 06:00:00
# 8      0     2013-11-01 06:00:00
# 9      0     2013-11-01 06:00:00
# 10     0     2013-11-01 06:00:00
#  [ reached getOption("max.print") -- omitted 51 rows ]

# %% [markdown]
# `-` arr_delay<=120 이고 dep_delay<=120 인 항공편을 찾고 싶다. (모두 같은 코드)

# %%
df %>% filter(arr_delay <= 120, dep_delay<=120)
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
#        arr_delay carrier flight tailnum origin dest air_time distance hour
# 1       11       UA      1545   N14228  EWR    IAH  227      1400     5
# 2       20       UA      1714   N24211  LGA    IAH  227      1416     5
# 3       33       AA      1141   N619AA  JFK    MIA  160      1089     5
# 4      -18       B6       725   N804JB  JFK    BQN  183      1576     5
# 5      -25       DL       461   N668DN  LGA    ATL  116       762     6
# 6       12       UA      1696   N39463  EWR    ORD  150       719     5
# 7       19       B6       507   N516JB  EWR    FLL  158      1065     6
# 8      -14       EV      5708   N829AS  LGA    IAD   53       229     6
# 9       -8       B6        79   N593JB  JFK    MCO  140       944     6
# 10       8       AA       301   N3ALAA  LGA    ORD  138       733     6
#        minute time_hour
# 1      15     2013-01-01 05:00:00
# 2      29     2013-01-01 05:00:00
# 3      40     2013-01-01 05:00:00
# 4      45     2013-01-01 05:00:00
# 5       0     2013-01-01 06:00:00
# 6      58     2013-01-01 05:00:00
# 7       0     2013-01-01 06:00:00
# 8       0     2013-01-01 06:00:00
# 9       0     2013-01-01 06:00:00
# 10      0     2013-01-01 06:00:00
#  [ reached getOption("max.print") -- omitted 51 rows ]

# %%
df %>% filter(arr_delay <= 120 &  dep_delay<=120)
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
#        arr_delay carrier flight tailnum origin dest air_time distance hour
# 1       11       UA      1545   N14228  EWR    IAH  227      1400     5
# 2       20       UA      1714   N24211  LGA    IAH  227      1416     5
# 3       33       AA      1141   N619AA  JFK    MIA  160      1089     5
# 4      -18       B6       725   N804JB  JFK    BQN  183      1576     5
# 5      -25       DL       461   N668DN  LGA    ATL  116       762     6
# 6       12       UA      1696   N39463  EWR    ORD  150       719     5
# 7       19       B6       507   N516JB  EWR    FLL  158      1065     6
# 8      -14       EV      5708   N829AS  LGA    IAD   53       229     6
# 9       -8       B6        79   N593JB  JFK    MCO  140       944     6
# 10       8       AA       301   N3ALAA  LGA    ORD  138       733     6
#        minute time_hour
# 1      15     2013-01-01 05:00:00
# 2      29     2013-01-01 05:00:00
# 3      40     2013-01-01 05:00:00
# 4      45     2013-01-01 05:00:00
# 5       0     2013-01-01 06:00:00
# 6      58     2013-01-01 05:00:00
# 7       0     2013-01-01 06:00:00
# 8       0     2013-01-01 06:00:00
# 9       0     2013-01-01 06:00:00
# 10      0     2013-01-01 06:00:00
#  [ reached getOption("max.print") -- omitted 51 rows ]

# %%
df %>% filter(!(arr_delay > 120 | dep_delay > 120))
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
#        arr_delay carrier flight tailnum origin dest air_time distance hour
# 1       11       UA      1545   N14228  EWR    IAH  227      1400     5
# 2       20       UA      1714   N24211  LGA    IAH  227      1416     5
# 3       33       AA      1141   N619AA  JFK    MIA  160      1089     5
# 4      -18       B6       725   N804JB  JFK    BQN  183      1576     5
# 5      -25       DL       461   N668DN  LGA    ATL  116       762     6
# 6       12       UA      1696   N39463  EWR    ORD  150       719     5
# 7       19       B6       507   N516JB  EWR    FLL  158      1065     6
# 8      -14       EV      5708   N829AS  LGA    IAD   53       229     6
# 9       -8       B6        79   N593JB  JFK    MCO  140       944     6
# 10       8       AA       301   N3ALAA  LGA    ORD  138       733     6
#        minute time_hour
# 1      15     2013-01-01 05:00:00
# 2      29     2013-01-01 05:00:00
# 3      40     2013-01-01 05:00:00
# 4      45     2013-01-01 05:00:00
# 5       0     2013-01-01 06:00:00
# 6      58     2013-01-01 05:00:00
# 7       0     2013-01-01 06:00:00
# 8       0     2013-01-01 06:00:00
# 9       0     2013-01-01 06:00:00
# 10      0     2013-01-01 06:00:00
#  [ reached getOption("max.print") -- omitted 51 rows ]

# %% [markdown]
# `-` 변수이름들을 확인하자.

# %%
df %>% colnames
# Out:
#  [1] "year"           "month"          "day"            "dep_time"
#  [5] "sched_dep_time" "dep_delay"      "arr_time"       "sched_arr_time"
#  [9] "arr_delay"      "carrier"        "flight"         "tailnum"
# [13] "origin"         "dest"           "air_time"       "distance"
# [17] "hour"           "minute"         "time_hour"

# %% [markdown]
# `-` 아래도 가능

# %%
df %>% names
# Out:
#  [1] "year"           "month"          "day"            "dep_time"
#  [5] "sched_dep_time" "dep_delay"      "arr_time"       "sched_arr_time"
#  [9] "arr_delay"      "carrier"        "flight"         "tailnum"
# [13] "origin"         "dest"           "air_time"       "distance"
# [17] "hour"           "minute"         "time_hour"

# %% [markdown]
# - 왜 두개가 있을까? (떡밥)

# %% [markdown]
# `-` 변수가 너무 많아서 귀찮음. 몇개만 추리자.
# - year~day 이건 있어야함
# - delay로 끝나는 변수들
# - distance, air_time (delay와 연관이 있을것 같은 변수들)

# %%
df %>% select(year:day, ends_with('delay'), distance, air_time)
# Out:
#        year month day dep_delay arr_delay distance air_time
# 1      2013 1     1    2         11       1400     227
# 2      2013 1     1    4         20       1416     227
# 3      2013 1     1    2         33       1089     160
# 4      2013 1     1   -1        -18       1576     183
# 5      2013 1     1   -6        -25        762     116
# 6      2013 1     1   -4         12        719     150
# 7      2013 1     1   -5         19       1065     158
# 8      2013 1     1   -3        -14        229      53
# 9      2013 1     1   -3         -8        944     140
# 10     2013 1     1   -2          8        733     138
# 11     2013 1     1   -2         -2       1028     149
# 12     2013 1     1   -2         -3       1005     158
# 13     2013 1     1   -2          7       2475     345
# 14     2013 1     1   -2        -14       2565     361
# 15     2013 1     1   -1         31       1389     257
# 16     2013 1     1    0         -4        187      44
# 17     2013 1     1   -1         -8       2227     337
# 18     2013 1     1    0         -7       1076     152
# 19     2013 1     1    0         12        762     134
# 20     2013 1     1    1         -6       1023     147
# 21     2013 1     1   -8         -8       1020     170
# 22     2013 1     1   -3         16        502     105
# 23     2013 1     1   -4        -12       1085     152
# 24     2013 1     1   -4         -8        760     128
# 25     2013 1     1    0        -17       1085     157
# 26     2013 1     1    8         32        719     139
# 27     2013 1     1   11         14       2586     366
# 28     2013 1     1    3          4       1074     175
#  [ reached getOption("max.print") -- omitted 33 rows ]

# %% [markdown]
# `-` 그리고 아래수식을 이용하여 gain과 speed를 계산하자.
# - gain = dep_delay - arr_delay
# - speed = distance / air_time

# %%
df %>% select(year:day, ends_with('delay'), distance, air_time) %>% 
mutate(gain=dep_delay - arr_delay, speed = distance / air_time)
# Out:
#        year month day dep_delay arr_delay distance air_time gain speed
# 1      2013 1     1    2         11       1400     227       -9  6.167401
# 2      2013 1     1    4         20       1416     227      -16  6.237885
# 3      2013 1     1    2         33       1089     160      -31  6.806250
# 4      2013 1     1   -1        -18       1576     183       17  8.612022
# 5      2013 1     1   -6        -25        762     116       19  6.568966
# 6      2013 1     1   -4         12        719     150      -16  4.793333
# 7      2013 1     1   -5         19       1065     158      -24  6.740506
# 8      2013 1     1   -3        -14        229      53       11  4.320755
# 9      2013 1     1   -3         -8        944     140        5  6.742857
# 10     2013 1     1   -2          8        733     138      -10  5.311594
# 11     2013 1     1   -2         -2       1028     149        0  6.899329
# 12     2013 1     1   -2         -3       1005     158        1  6.360759
# 13     2013 1     1   -2          7       2475     345       -9  7.173913
# 14     2013 1     1   -2        -14       2565     361       12  7.105263
# 15     2013 1     1   -1         31       1389     257      -32  5.404669
# 16     2013 1     1    0         -4        187      44        4  4.250000
# 17     2013 1     1   -1         -8       2227     337        7  6.608309
# 18     2013 1     1    0         -7       1076     152        7  7.078947
# 19     2013 1     1    0         12        762     134      -12  5.686567
# 20     2013 1     1    1         -6       1023     147        7  6.959184
# 21     2013 1     1   -8         -8       1020     170        0  6.000000
# 22     2013 1     1   -3         16        502     105      -19  4.780952
#  [ reached getOption("max.print") -- omitted 39 rows ]

# %% [markdown]
# `-` year, month, day로 그룹핑하고 (왜 day만 그룹핑하면 안되는지?) 평균속도와 평균 gain을 계산해보자.

# %%
df %>% 
select(year:day, ends_with('delay'), distance, air_time) %>% 
mutate(gain=dep_delay - arr_delay, speed = distance / air_time) %>% 
group_by(year,month,day) %>% 
summarise(gain_mean=mean(gain),speed_mean=mean(speed))
# Out:
# `summarise()` has grouped output by 'year', 'month'. You can override using the `.groups` argument.
#     year month day gain_mean speed_mean
# 1   2013 1      1  NA        NA
# 2   2013 1      2  NA        NA
# 3   2013 1      3  NA        NA
# 4   2013 1      4  NA        NA
# 5   2013 1      5  NA        NA
# 6   2013 1      6  NA        NA
# 7   2013 1      7  NA        NA
# 8   2013 1      8  NA        NA
# 9   2013 1      9  NA        NA
# 10  2013 1     10  NA        NA
# 11  2013 1     11  NA        NA
# 12  2013 1     12  NA        NA
# 13  2013 1     13  NA        NA
# 14  2013 1     14  NA        NA
# 15  2013 1     15  NA        NA
# 16  2013 1     16  NA        NA
# 17  2013 1     17  NA        NA
# 18  2013 1     18  NA        NA
# 19  2013 1     19  NA        NA
# 20  2013 1     20  NA        NA
# 21  2013 1     21  NA        NA
# 22  2013 1     22  NA        NA
# 23  2013 1     23  NA        NA
# 24  2013 1     24  NA        NA
# 25  2013 1     25  NA        NA
# 26  2013 1     26  NA        NA
# 27  2013 1     27  NA        NA
# 28  2013 1     28  NA        NA
# 29  2013 1     29  NA        NA
# 30  2013 1     30  NA        NA
# ⋮   ⋮    ⋮     ⋮   ⋮         ⋮
# 336 2013 12     2  NA        NA
# 337 2013 12     3  NA        NA
# 338 2013 12     4  NA        NA
# 339 2013 12     5  NA        NA
# 340 2013 12     6  NA        NA
# 341 2013 12     7  NA        NA
# 342 2013 12     8  NA        NA
# 343 2013 12     9  NA        NA
# 344 2013 12    10  NA        NA
#  [ reached getOption("max.print") -- omitted 21 rows ]

# %% [markdown]
# - 헐..

# %%
df %>% 
select(year:day, ends_with('delay'), distance, air_time) %>% 
mutate(gain=dep_delay - arr_delay, speed = distance / air_time) %>% 
group_by(year,month,day) %>% 
summarise(gain_mean=mean(gain,na.rm=TRUE),speed_mean=mean(speed,na.rm=TRUE))
# Out:
# `summarise()` has grouped output by 'year', 'month'. You can override using the `.groups` argument.
#     year month day gain_mean   speed_mean
# 1   2013 1      1  -1.2154031  5.956879
# 2   2013 1      2   0.9849138  6.085977
# 3   2013 1      3   5.1744444  6.163061
# 4   2013 1      4  10.8986784  6.389652
# 5   2013 1      5   7.2580195  6.259174
# 6   2013 1      6   2.9095296  6.146544
# 7   2013 1      7  10.3645161  6.488469
# 8   2013 1      8   5.7858744  6.215331
# 9   2013 1      9   2.5655095  6.021767
# 10  2013 1     10   8.7438105  6.375353
# 11  2013 1     11   7.5954198  6.326487
# 12  2013 1     12  14.6093979  6.613691
# 13  2013 1     13   4.6877323  6.353392
# 14  2013 1     14  -0.8418202  6.018617
# 15  2013 1     15  -0.3019296  5.918271
# 16  2013 1     16  -9.7924971  5.819344
# 17  2013 1     17   1.1923497  5.923112
# 18  2013 1     18   4.9263736  6.207338
# 19  2013 1     19  11.8882265  6.340853
# 20  2013 1     20   3.0640205  6.098927
# 21  2013 1     21   1.5232816  5.911828
# 22  2013 1     22   0.2225989  5.966793
# 23  2013 1     23   3.6925676  6.081496
# 24  2013 1     24   4.1156388  6.305144
# 25  2013 1     25  -5.3469852  6.177677
# 26  2013 1     26   6.4619970  6.342779
# 27  2013 1     27   9.6972705  6.371808
# 28  2013 1     28   5.7794632  6.288730
# 29  2013 1     29   9.1047181  6.297918
# 30  2013 1     30   2.0226131  6.072084
# ⋮   ⋮    ⋮     ⋮   ⋮           ⋮
# 336 2013 12     2    8.6172345 6.538165
# 337 2013 12     3    3.7637306 6.385837
# 338 2013 12     4    5.5354497 6.374694
# 339 2013 12     5    0.7886279 6.315847
# 340 2013 12     6   -4.9424779 6.088300
# 341 2013 12     7   -0.5210210 6.083830
# 342 2013 12     8  -16.0335404 6.015119
# 343 2013 12     9   -7.9688889 5.927017
# 344 2013 12    10  -18.0433018 5.851833
#  [ reached getOption("max.print") -- omitted 21 rows ]
