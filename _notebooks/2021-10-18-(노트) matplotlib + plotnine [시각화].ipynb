# %% [markdown]
# # (노트) matplotlib + plotnine
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - hide: false
# - categories: [시각화]

# %% [markdown]
# ### matplotlib + plotnine

# %%
_ax1=ggfig.axes[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-624-b9abc58df793> in <module>
# ----> 1 _ax1=ggfig.axes[0]
#
# IndexError: list index out of range

# %%
ggfig.delaxes(ggfig.axes[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-625-2cbdb9908201> in <module>
# ----> 1 ggfig.delaxes(ggfig.axes[0])
#
# IndexError: list index out of range

# %%
ggfig

# %%
(ax1,ax2),(ax3,ax4)=ggfig.subplots(2,2)

# %%
ggfig

# %%
ax1.remove()

# %%
ggfig

# %%
ggfig.add_subplot(_ax1)
# Out:
# <AxesSubplot:>

# %%
ggfig

# %%
ggfig.delaxes(_ax1)

# %%
ggfig

# %%
# _ax1.axes=None
# _ax1.bbox=ax1.bbox
# _ax1.callbacks
# _ax1.collections
# _ax1.dataLim 
# _ax1.figbox # _ax1.get_position() 
# _ax1.patch
# _ax1.spines
# _ax1.stale_callback
# _ax1.titleOffsetTrans
# _ax1.transAxes
# _ax1.transData
# _ax1.transLimits
# _ax1.transScale
# _ax1.viewLim
# _ax1.xaxis
# _ax1.yaxis

# %%
_ax1.set_position(ax1.get_position())

# %%
ggfig.add_subplot(_ax1)
# Out:
# <AxesSubplot:>

# %%
ggfig

# %%
ax2.hist([1,2,3,3,4])
# Out:
# (array([1., 0., 0., 1., 0., 0., 2., 0., 0., 1.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
ggfig

# %%
ggfig

# %% [markdown]
# `-` 방법2

# %%
import matplotlib.pyplot as plt

# %%
#import mplcyberpunk
#plt.style.use("cyberpunk")
#plt.style.use("seaborn")

# %%
from plotnine import *

# %%
fig,ax = plt.subplots()

# %%
_ggfig = ggplot()+geom_point(aes(x=[1,2,3],y=[1,2,3]),colour='red')+theme_matplotlib()

# %%
ggfig = _ggfig.draw()

# %%
fig.set_figheight(ggfig.get_figheight())
fig.set_figwidth(ggfig.get_figwidth())
fig.set_dpi(ggfig.get_dpi())

# %%
fig

# %%
ggax = ggfig.axes[0]

# %%
ggax.figure

# %%
ggax.remove()

# %%
ggfig

# %%
ggax
# Out:
# <AxesSubplot:>

# %%
ggax.figure = fig

# %%
fig

# %%
ggax.get_position()
# Out:
# Bbox([[0.125, 0.125], [0.9, 0.88]])

# %%
ax.get_position()
# Out:
# Bbox([[0.125, 0.125], [0.9, 0.88]])

# %%
fig.axes.append(ggax)

# %%
fig.tight_layout()

# %%
ax.remove()

# %%
ax.get_autoscale_on()
# Out:
# True

# %%
fig.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)

# %%
fig

# %% [markdown]
# `-` 방법2

# %%
_fig1 = ggplot()+geom_point(aes(x=[1,2,3],y=[2,3,4]))
_fig2 = ggplot()+geom_point(aes(x=[1,2,3,4],y=[2,3,4,2]),alpha=0.2,size=5)

# %%
_fig1
# Out:
# <ggplot: (8749039932395)>

# %%
_fig2
# Out:
# <ggplot: (8749039936952)>

# %%
fig1=_fig1.draw()
fig2=_fig2.draw()

# %%
ggax1=fig1.axes[0]
ggax2=fig2.axes[0]

# %%
fig1.delaxes(ggax1)
ggax2.remove()
ggax2.figure=fig1

# %%
(ax1,ax2),(ax3,ax4)=fig1.subplots(2,2)

# %%
ax1.remove()
ax4.remove()
ggax1.set_position(ax1.get_position())
ggax2.set_position(ax4.get_position())
fig1.add_axes(ggax1)
fig1.add_axes(ggax2)
# Out:
# <AxesSubplot:>

# %%
fig1.get_gid
