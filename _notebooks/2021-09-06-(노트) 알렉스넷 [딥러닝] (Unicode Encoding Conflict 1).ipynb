# %% [markdown]
# # (노트) 알렉스넷
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - hide: false
# - categories: [딥러닝]

# %% [markdown]
# ### About this doc

# %% [markdown]
# `-` 잡담용

# %% [markdown]
# ### 알렉스넷

# %% [markdown]
# 힌튼: 교수님
#
# 알렉스: 대학원생
#
# 교수님: RBM $\to$ DBN(2006년, 사이언스지) 개발.
# - DBN: 비선형 차원축소 기법

# %% [markdown]
# 나름대로 딥러닝의 골치덩이를 해결했었다고 자신했는데 세상사람들은 관심 X
#
# 당시에는 배프닉의 SVM 모형이 우세함 (커널트릭, 커널기법으로 유명)

# %% [markdown]
# 대학원생: 교수님, 우리가 제안한 모형이 세상문제를 해결할 수 있다는 것을 증명해야 합니다.

# %% [markdown]
# 대회에 한번 나가보죠. (공모전)

# %% [markdown]
# 2010년 시작한 대회: 1등팀 오류율 28%
#
# 2011년 우승한 모델: 1등팀(SVM) 오류율 26%

# %% [markdown]
# ---

# %% [markdown]
# 공모전 준비

# %% [markdown]
# 알렉스: GPU를 쓰자. (제한된 시간에 성능을 내기 위해)

# %% [markdown]
# 오버피팅 문제가 발생
#
# 대학원생2: 드랍아웃개발

# %% [markdown]
# 알렉스: 벤지오 연구실에서 ReLU 함수를 사용하자.

# %% [markdown]
# ----

# %% [markdown]
# 2012년 우승: 알렉스넷 오류율 16%

# %% [markdown]
# 경쟁의 의미가 사라짐
