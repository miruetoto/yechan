# %% [markdown]
# # (노트) mutate 사용법
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - categories: [R]

# %% [markdown]
# ### mutate에 대하여
#
# `-` `mutate`는 새로운 열을 `추가`할 때 유용하게 사용할 수 있다.
#
# `-` 열의 내용을 `update`할때는 그다지 적절하지 않다.
#
# `-` 왜냐하면 열의 일부내용만 `update` 하기 위해서는 오히려 `modify`가 더 적절하다.

# %% [markdown]
# ### 기본사용: x3=x1+x2

# %%
mutate(tb,x3=x1+x2)
# Out:
#    x1 x2         x3
# 1   1  0.5180116 1.518012
# 2   2  0.9744405 2.974441
# 3   3  0.6251501 3.625150
# 4   4 -1.3308200 2.669180
# 5   5 -0.8325119 4.167488
# 6   6 -0.1634481 5.836552
# 7   7  0.5440492 7.544049
# 8   8 -0.4732586 7.526741
# 9   9 -0.3014033 8.698597
# 10 10 -1.1256243 8.874376

# %% [markdown]
# ### 팁1: 결과저장

# %% [markdown]
# `-` `mutate`는 따로 결과가 저장되지는 않음.

# %%
mutate(tb,x3=x1+x2)
# Out:
#    x1 x2         x3
# 1   1  0.5180116 1.518012
# 2   2  0.9744405 2.974441
# 3   3  0.6251501 3.625150
# 4   4 -1.3308200 2.669180
# 5   5 -0.8325119 4.167488
# 6   6 -0.1634481 5.836552
# 7   7  0.5440492 7.544049
# 8   8 -0.4732586 7.526741
# 9   9 -0.3014033 8.698597
# 10 10 -1.1256243 8.874376

# %%
print(tb)
# Out:
# # A tibble: 10 x 2
#       x1     x2
#    <int>  <dbl>
#  1     1  0.518
#  2     2  0.974
#  3     3  0.625
#  4     4 -1.33
#  5     5 -0.833
#  6     6 -0.163
#  7     7  0.544
#  8     8 -0.473
#  9     9 -0.301
# 10    10 -1.13

# %% [markdown]
# `-` 굳이 결과를 저장하고 싶다면 아래와 같은 방법이 있다.

# %%
tb2 <- tb %>% mutate(x3=x1+x2)

# %%
tb2
# Out:
#    x1 x2         x3
# 1   1  0.6980523  1.698052
# 2   2 -0.1266940  1.873306
# 3   3  0.4529776  3.452978
# 4   4  0.5192793  4.519279
# 5   5  0.4563271  5.456327
# 6   6 -1.7494421  4.250558
# 7   7  0.0902628  7.090263
# 8   8 -0.4175539  7.582446
# 9   9  1.1028135 10.102814
# 10 10  0.2276045 10.227604

# %% [markdown]
# ### 팁2: update
#
# `-` 새로운 변수를 추가하지 않고 자기자신에 결과를 업데이트 할 수도 있다.

# %% [markdown]
# `-` 예를들면 `x1+x2`의 계산결과를 `x2`에 update하기 위해서는 아래와 같이 한다.

# %%
tb
# Out:
#    x1 x2
# 1   1  0.6980523
# 2   2 -0.1266940
# 3   3  0.4529776
# 4   4  0.5192793
# 5   5  0.4563271
# 6   6 -1.7494421
# 7   7  0.0902628
# 8   8 -0.4175539
# 9   9  1.1028135
# 10 10  0.2276045

# %%
tb %>% mutate(x2=x1+x2)
# Out:
#    x1 x2
# 1   1  1.698052
# 2   2  1.873306
# 3   3  3.452978
# 4   4  4.519279
# 5   5  5.456327
# 6   6  4.250558
# 7   7  7.090263
# 8   8  7.582446
# 9   9 10.102814
# 10 10 10.227604

# %% [markdown]
# #### 데이터 프레임의 subset만을 `update`하는 방법 ($\star\star\star$)

# %% [markdown]
# ##### **방법1**: `filter(...) %>% mutate(...)` 를 사용
#
# `-` `update`까지는 가능하지만 `save`가 안된다!!! $\to$ 사용할 수 없다.

# %% [markdown]
# ***update***

# %%
tb %>% filter(x1>5, x1<8) %>% mutate(x2=x2+x1)
# Out:
#   x1 x2
# 1 6  5.836552
# 2 7  7.544049

# %% [markdown]
# ***but can't save***

# %%
tb2<-tb
tb2 %>% filter(x1>5, x1<8) <- tb2 %>% filter(x1>5, x1<8) %>% mutate(x2=x2+x1)
# Out:
# Error in tb2 %>% filter(x1 > 5, x1 < 8) <- tb2 %>% filter(x1 > 5, x1 < : could not find function "%>%<-"
# Traceback:

# %% [markdown]
# ##### **방법2**: `더미함수` 와 `mutate` 를 활용하는 방법 (정말 나쁜코딩)

# %% [markdown]
# ***update***

# %%
dum<-function(x,y){
    idx= (x>5 & x<8)
    y[idx]<-x[idx]+y[idx]
    y
} 
tb %>% mutate(x2=dum(x1,x2))
# Out:
#    x1 x2
# 1   1  0.5180116
# 2   2  0.9744405
# 3   3  0.6251501
# 4   4 -1.3308200
# 5   5 -0.8325119
# 6   6  5.8365519
# 7   7  7.5440492
# 8   8 -0.4732586
# 9   9 -0.3014033
# 10 10 -1.1256243

# %% [markdown]
# ***save***

# %%
tb2<- tb %>% mutate(x2=dum(x1,x2))
tb2
# Out:
#    x1 x2
# 1   1  0.5180116
# 2   2  0.9744405
# 3   3  0.6251501
# 4   4 -1.3308200
# 5   5 -0.8325119
# 6   6  5.8365519
# 7   7  7.5440492
# 8   8 -0.4732586
# 9   9 -0.3014033
# 10 10 -1.1256243

# %% [markdown]
# ##### **방법3:** `mutate(...=ifelse(...))`

# %% [markdown]
# `-` 현재 내가 알아낸 방법중에 가장 깔끔한 방법이다!!!

# %% [markdown]
# ***update***

# %%
tb %>% mutate(x2=ifelse(x1>5 & x1<8, x1+x2 ,x2))
# Out:
#    x1 x2
# 1   1  0.5180116
# 2   2  0.9744405
# 3   3  0.6251501
# 4   4 -1.3308200
# 5   5 -0.8325119
# 6   6  5.8365519
# 7   7  7.5440492
# 8   8 -0.4732586
# 9   9 -0.3014033
# 10 10 -1.1256243

# %% [markdown]
# ***save***

# %%
tb2 <- tb %>% mutate(x2=ifelse(x1>5 & x1<8, x1+x2 ,x2))
tb2
# Out:
#    x1 x2
# 1   1  0.5180116
# 2   2  0.9744405
# 3   3  0.6251501
# 4   4 -1.3308200
# 5   5 -0.8325119
# 6   6  5.8365519
# 7   7  7.5440492
# 8   8 -0.4732586
# 9   9 -0.3014033
# 10 10 -1.1256243

# %% [markdown]
# ##### **방법4**: `mutate(...=replace(...))`
#
# `-` 바꾸고 싶은 것이 하나의 `값`이라면 `replace`를 사용해도 무방하다.

# %%
tb %>% mutate(x2=replace(x2, x1>5 & x1<8,100))
# Out:
#    x1 x2
# 1   1   0.5180116
# 2   2   0.9744405
# 3   3   0.6251501
# 4   4  -1.3308200
# 5   5  -0.8325119
# 6   6 100.0000000
# 7   7 100.0000000
# 8   8  -0.4732586
# 9   9  -0.3014033
# 10 10  -1.1256243

# %% [markdown]
# 하지만 아래와 같은 식으로는 변환할 수 없다.

# %%
tb %>% mutate(x2=replace(x2, x1>5 & x1<8,x1+x2))
# Out:
# Warning message:
# “Problem with `mutate()` input `x2`.
# ℹ number of items to replace is not a multiple of replacement length
# ℹ Input `x2` is `replace(x2, x1 > 5 & x1 < 8, x1 + x2)`.”
# Warning message in x[list] <- values:
# “number of items to replace is not a multiple of replacement length”
#    x1 x2
# 1   1  0.5180116
# 2   2  0.9744405
# 3   3  0.6251501
# 4   4 -1.3308200
# 5   5 -0.8325119
# 6   6  1.5180116
# 7   7  2.9744405
# 8   8 -0.4732586
# 9   9 -0.3014033
# 10 10 -1.1256243

# %% [markdown]
# 결국 `mutate(...=replace(...))`으로 구현하고 싶은것은 모두 `mutate(...=ifelse(...))`으로 구현가능하다.

# %%
tb %>% mutate(x2=ifelse(x1>5 & x1<8,100, x2))
# Out:
#    x1 x2
# 1   1   0.5180116
# 2   2   0.9744405
# 3   3   0.6251501
# 4   4  -1.3308200
# 5   5  -0.8325119
# 6   6 100.0000000
# 7   7 100.0000000
# 8   8  -0.4732586
# 9   9  -0.3014033
# 10 10  -1.1256243

# %% [markdown]
# ### 팁3: 참조하면서 생성
#
# `-` `mutate`로 방금 생성한 열을 참조할 수 있음

# %%
mutate(tb,x3=x1+x2,x4=x1-mean(x3))
# Out:
#   x1 x2        x3       x4
# 1  6  4.250558 10.25056 -9.850737
# 2  7  7.090263 14.09026 -8.850737
# 3  8  7.582446 15.58245 -7.850737
# 4  9 10.102814 19.10281 -6.850737
# 5 10 10.227604 20.22760 -5.850737

# %% [markdown]
# ### 팁4: transmute
#
# `-` 생성된결과만 보고 싶다면 `transmute`를 써라.

# %%
transmute(tb,x3=x1+x2,x4=x1-mean(x3))
# Out:
#   x3       x4
# 1 10.25056 -9.850737
# 2 14.09026 -8.850737
# 3 15.58245 -7.850737
# 4 19.10281 -6.850737
# 5 20.22760 -5.850737

# %% [markdown]
# ### 팁5: lag + mutate
#
# `-` `lag`함수와 `mutate`를 쓰면 매우 강력하다. 이유는 `NA`를 잘 처리하기 때문임.

# %%
mutate(tb,x3=lag(x2))
# Out:
#    x1 x2          x3
# 1   1 -0.66774172          NA
# 2   2  0.97955613 -0.66774172
# 3   3 -0.23543652  0.97955613
# 4   4 -0.05123645 -0.23543652
# 5   5 -0.92831697 -0.05123645
# 6   6 -0.24151830 -0.92831697
# 7   7 -2.29371835 -0.24151830
# 8   8  1.84967922 -2.29371835
# 9   9 -0.85967047  1.84967922
# 10 10 -0.28646204 -0.85967047

# %%
mutate(tb,x3=lag(x2),x4=x2-x3)
# Out:
#    x1 x2          x3          x4
# 1   1 -0.66774172          NA         NA
# 2   2  0.97955613 -0.66774172  1.6472979
# 3   3 -0.23543652  0.97955613 -1.2149926
# 4   4 -0.05123645 -0.23543652  0.1842001
# 5   5 -0.92831697 -0.05123645 -0.8770805
# 6   6 -0.24151830 -0.92831697  0.6867987
# 7   7 -2.29371835 -0.24151830 -2.0522001
# 8   8  1.84967922 -2.29371835  4.1433976
# 9   9 -0.85967047  1.84967922 -2.7093497
# 10 10 -0.28646204 -0.85967047  0.5732084

# %% [markdown]
# 차분을 구하기 위해서 아래와 같이 더 간단히 쓸 수도 있다.

# %%
mutate(tb,x3=x2-lag(x2))
# Out:
#    x1 x2          x3
# 1   1 -0.66774172         NA
# 2   2  0.97955613  1.6472979
# 3   3 -0.23543652 -1.2149926
# 4   4 -0.05123645  0.1842001
# 5   5 -0.92831697 -0.8770805
# 6   6 -0.24151830  0.6867987
# 7   7 -2.29371835 -2.0522001
# 8   8  1.84967922  4.1433976
# 9   9 -0.85967047 -2.7093497
# 10 10 -0.28646204  0.5732084

# %% [markdown]
# `-` 참고로 위를 구현하기위해서 `mutate(tb,x3=diff(x2))`와 같이 입력하면 에러가 난다.
#
# `-` 결론: `diff`함수보다 `lag`함수를 활용하여 `NA`를 처리하기에 좋다. 그러니까 `diff`를 쓰지말자.

# %% [markdown]
# ### 팁6: 변화점을 찾을때
# `-` 변화점을 찾을때 `x!=lag(x)`와 같이 활용하면 유용하다.

# %% [markdown]
# 아래와 같이 새로운 데이터셋 `tb2`를 만들자.

# %%
tb2<-as_tibble(cbind(tb,comp=c(0,0,0,0,0,40,40,40,40,40)))
tb2
# Out:
#    x1 x2          comp
# 1   1 -0.66774172  0
# 2   2  0.97955613  0
# 3   3 -0.23543652  0
# 4   4 -0.05123645  0
# 5   5 -0.92831697  0
# 6   6 -0.24151830 40
# 7   7 -2.29371835 40
# 8   8  1.84967922 40
# 9   9 -0.85967047 40
# 10 10 -0.28646204 40

# %% [markdown]
# `tb2`에서 컴프값이 `0`에서 `40`으로 바뀌는 시점에 관심이 있다고 하자.

# %%
mutate(tb2,comp!=lag(comp))
# Out:
#    x1 x2          comp comp != lag(comp)
# 1   1 -0.66774172  0      NA
# 2   2  0.97955613  0   FALSE
# 3   3 -0.23543652  0   FALSE
# 4   4 -0.05123645  0   FALSE
# 5   5 -0.92831697  0   FALSE
# 6   6 -0.24151830 40    TRUE
# 7   7 -2.29371835 40   FALSE
# 8   8  1.84967922 40   FALSE
# 9   9 -0.85967047 40   FALSE
# 10 10 -0.28646204 40   FALSE

# %% [markdown]
# 해당시점의 값들만 뽑아내고 싶다면 아래와 같이 하면 된다.

# %%
filter(tb2,comp!=lag(comp))
# Out:
#   x1 x2         comp
# 1 6  -0.2415183 40
