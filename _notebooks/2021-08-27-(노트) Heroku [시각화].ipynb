# %% [markdown]
# # (노트) Heroku
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - hide: false
# - categories: [시각화]

# %% [markdown]
# https://devcenter.heroku.com/articles/heroku-cli#download-and-install

# %% [markdown]
# sudo snap install --classic heroku

# %% [markdown]
# heroku --version
