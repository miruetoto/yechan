# %% [markdown]
# # (노트) 파이썬 코딩의 기술 독후감
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 신록예찬
# - hide: false
# - categories: [파이썬]

# %%
abc=[(11,),(22,),(33,)]
a,b = abc[0],abc[1]

# %%
id(abc[0])
# Out:
# 139806285920576

# %%
id(a)
# Out:
# 139806287739248

# %%
abc[0].append(777)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 abc[0].append(777)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
id(a)
# Out:
# 139805755854464

# %%
id(abc[0])
# Out:
# 139805755854464

# %%
a
# Out:
# [11, 777]

# %% [markdown]
# ### 튜플

# %% [markdown]
# #### 6. 언패킹

# %% [markdown]
# `-` 튜플언패킹

# %% [markdown]
# `-` 임시변수 없이 값바꿈 -> 소팅알고리즘

# %% [markdown]
# `-` 언패킹은 인덱스의 카운터다

# %% [markdown]
# #### 13. `*`연산자와 언패킹

# %% [markdown]
# `-` 꼭 튜플에 있을 내용은 아닌데 그래도 편하니까

# %% [markdown]
# ### 리스트와 튜플

# %% [markdown]
# #### 11. 슬라이싱

# %% [markdown]
# #### 12. 스트라이드 (인덱싱 고급)

# %% [markdown]
# `-` 스트라이드는 딕셔너리에는 없다.

# %% [markdown]
# `-` 미친기능

# %% [markdown]
# #### 14. key (sort 고급)

# %% [markdown]
# `-` 오름차순: 원소의 인덱스가 커질수록 점점 값이 올라간다.. (커진다)

# %% [markdown]
# `-` key 파라메터를 이용한 정렬

# %% [markdown]
# ### 딕셔너리

# %% [markdown]
# `-` 동적인 정보를 관리할때는 딕셔너리가 훨씬 이상적이다.

# %% [markdown]
# `-` 리스트: 자료를 저장, 생성, 추가, 추출(인덱싱)의 끝판왕 $\to$ 그런데 리스트로도 불완전하다.

# %% [markdown]
# #### 15. 딕셔너리 삽입순서

# %% [markdown]
# `-` 너무어렵당.. 저자의 메시지 파악못함

# %% [markdown]
# `-` 건진것: 3.5이전에는 딕셔너리의 삽입순서를 보장하지 않는다.

# %% [markdown]
# ### 함수

# %% [markdown]
# #### 5. 도우미함수

# %% [markdown]
# `-` 함수를 설명하면서 소개하면 좋을 내용

# %% [markdown]
# ### 반복문, 제어문

# %% [markdown]
# #### 7. enumerate

# %% [markdown]
# #### 8. zip

# %% [markdown]
# #### 9. else

# %% [markdown]
# `-` 이거는 굳이 설명할 필요가 없을것 같다.

# %% [markdown]
# #### 10. 대입식을 사용하여 반복을 피하라.

# %% [markdown]
# `-` 3.8이후에 도입되었음.

# %% [markdown]
# `-` 괜찮다..

# %% [markdown]
# `-` 한번쓰고 버릴변수를 잘 살리는것

# %%
a=('a',1,2,'c')

# %% [markdown]
# 원소의 수와 순서가 고정되어있다.

# %%
lst=[['iu',10,20,30,40],['hodong',10,20,30,40],['guebin',5,10,15,0]]

# %%
sorted(lst)
# Out:
# [['guebin', 5, 10, 15, 0], ['hodong', 10, 20, 30, 40], ['iu', 10, 20, 30, 40]]

# %% [markdown]
# 왜 튜플은 괄호를 생략할수 있을까

# %%
1,2,3,4,5
# Out:
# (1, 2, 3, 4, 5)
